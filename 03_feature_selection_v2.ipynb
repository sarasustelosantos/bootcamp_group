# %% [markdown]
# <div class="alert alert-block alert-success">
# <a id='explore'>
# <font color = '#006400'>
#
# # 1. Intro </font>
# </a>
#
# Import Libraries, Data and define Cluster scenarios.
#
# </div>
# ## `MetaData`
# - __CustomerID__: A unique ID that identifies each customer
#
# __`DEMOGRAPHICS:`__
# - __Age__: Customer's current age in years
# - __Under 30__: A flag indicating if customer is under 30 (1) or above (0)
# - __Senior Citizen__: A flag indicating if customer is 65 or older (1) or not (0)
# - __Gender_Male__: A flag indicating if customer is male (1) or female (0)
# - __Dependents__: A flag indicating if customer has dependents (1) or not (0)
# - __Number of Dependents__: Indicates number of dependents living with the customer
# - __Married__: A flag indicating if customer is married (1) or not (0)
#
# __`LOCATION & POPULATION DATA:`__ Country: US; State: California
# - __City__: The city of the customer's primary residence
# - __Zip Code__:
# - __Lat Long__: The combined latitude and longitude of the customer's primary residence
# - __Latitude__: The latitude of the customer's primary residence
# - __Longitude__: The longitude of the customer's primary residence
# - __Population__: A current population estimate for the entire Zip Code area
# - __Density_High__: A flag indicating if the area the customer lives has high population density
# - __Density_Low__: A flag indicating if the area the customer lives has low population density
# - If both are zero, then density is medium
#
# __`SERVICES:`__
# - __Phone Service__: subscribes to home phone service (1) or not
# - __Internet Service__: subscribes to internet servie (1) or not
# - __Online Security__: subscribes to an additional online security service (1) or not
# - __Online Backup__: subscribes to an additional online backup service (1) or not
# - __Multiple Lines__: subscribes to multiple telephone lines with the company (1) or not
# - __Device Protection Plan__: subscribes to an additional device protection plan for their internet equipment (1) or not
# - __Premium Tech Support__: subscribes to an additional technical support plan with reduced wait times (1) or not
# - __Unlimited Data__: paid an additional monthly fee to have unlimited data downloads/uploads (1) or not
# - __Internet Type_Cable__: subscribes with internet cable (1) or not
# - __Internet Type_DSL__: subscribes with DSL (1) or not
# - __Internet Type_Fiber Optic__: subscribles with DSL (1) or not
#
# __`STREAMING:`__ No fee associated, is if uses the internet service to stream services from a third provider
# - __Streaming TV__: uses streaming for TV programing
# - __Streaming Movies__: uses streaming for movies
# - __Streaming Music__: uses streaming for music
#
# __`TENURE & CONTRACT:`__
# - __Tenure in Months__: Total amount of months that the customer has been with the company
# - __Tenure Category__: 0 if customer joined this quarter, 1 if joined > 3 - 18 m, 2 if joined > 18 - 36 m, 3 if joined > 36 - 54 m, 4 if joined  54 - 72 m
# - __Contract__: -"month-to-month" is 1, "one year" is 2, "two year" is 3
#
# __`PAYMENT PREFERENCES:`__
# - __Paperless Billing__: has chosen paperless billing (1) or not (0)
# - __Payment Method_Bank Withdrawal__: pays their bill with bank withdrawl (1) or not (0)
# - __Payment Method_Credit Card__: pays their bill with credit card (1) or not (0)
# - If both are zero then it pays with mailed check
#
# __`REFERRALS AND OFFERS:`__
# - __Referred a Friend__:
# - __Number of Referrals__:
# - __Offer_Offer A, Offer_Offer B, Offer_Offer C, Offer_Offer D, Offer_Offer E__: A flag indicating the last marketing offer the customer accepted (1) or not (0)
#
# __`PROFITABILITY:`__
# - __Total Revenue__: Total Charges + Extra Data Charges + Long Distance Charges - Refunds
# - __Total Charges__: Customer's total charges at the end of the quarter
# - __Total Refunds__: Customer's total refunds at the end of the quarter
# - __Monthly Charge__: Customer's current total monthly charge for all their services from the company
# - __Total Extra Data Charges__: Charges for extra data downloads above those specified in their plan
# - __Total Long Distance Charges__: Charges for long distance above those specified in their plan
# - __Avg Monthly Long Distance Charges__: Average long distance charges
#
# __`STATUS:`__
# - __New Customer__: Is a new customer, i.e. joined this quarter (1) or not (0)
# - __Churn Label__: 1 if the customer left the company this quarter or 0 if remained
# - __Churn Score__: A value from 0-100 calculated using the predictive tool IBM SPSS Modeler, incorporating factors known to cause churn. The higher, the more likely the customer will churn
# - __Churn Category_Attitude, Churn Category_Competitor, Churn Category_Dissatisfaction, Churn Category_Price__: Churn category's flag (1)
# - __Churn Reason__: A customer's specific reason for leaving the company. Directly related to Churn Category but more descriptive
# - __Satisfaction Score__: A customer's overall satisfaction rating of the company from 1 (very unsatisfied) to 5 (very satisfied)
# - __Engagement Score__: Calculated score based on the number of services a customer has subscribed to. The more services, it adds up +1. Varies between 1 and 7
# - __CLTV__: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.

# %% [markdown]
# <a id='toc'></a>
#
# ## <font color='darkseagreen'> Table of Contents </font>
#
# >* [1. Data Collection](#import)<br>
# >* [2. Data Exploration](#explore) <br>
# >* [3. Data Pre-processing (before split)](#before_split) <br>
# >* [4. Data Split](#split) <br>
# >* [5. Feature Selection](#feature) <br>
# >* [6. Feature Decision](#decision) <br>
# >* [7. Modelling](#modelling) <br>

# %% [markdown]
# ***
# <div class="alert alert-block alert-success">
# <a id='import'>
# <font color = '#006400'>
#
# # 1. Data Collection </font>
# </a>
#
# </div>
#
# Importing Libraries, Data Extraction and Merging datasets, as well as defining the training (historical data) and the test (predictive) sets.

# %% [markdown]
# ## 1.1. Import libraries

# %%
import os
import glob
import pandas as pd 
import numpy as np 
import datetime
import warnings
import matplotlib.pyplot as plt 
import seaborn as sns
from math import ceil
from sklearn.preprocessing import MinMaxScaler 
from sklearn.impute import KNNImputer 
from sklearn.cluster import KMeans
import scipy   
from scipy.cluster import hierarchy
from IPython.display import Markdown 
from sklearn.cluster import DBSCAN 
from sklearn.metrics import silhouette_samples, silhouette_score 
from pprint import pprint 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.impute import KNNImputer
from sklearn.impute import KNNImputer
from scipy.stats import spearmanr
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from scipy import stats
from sklearn.feature_selection import f_classif
from scipy.stats import chi2_contingency
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.impute import KNNImputer

from sklearn.impute import KNNImputer
from scipy import stats
from sklearn.feature_selection import f_classif
from scipy.stats import chi2_contingency
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

############################################ FEATURE SELECTION ############################################
import scipy.stats as stats
from scipy.stats import chi2_contingency # filter method
from sklearn.feature_selection import RFE # wrapper method
from sklearn.feature_selection import RFECV # wrapper method
from sklearn.linear_model import LogisticRegression #(This is one possible model to apply inside RFE)
from sklearn.linear_model import LassoCV # embedded method
from sklearn.tree import DecisionTreeClassifier # embedded method
from sklearn.model_selection import StratifiedKFold

# ignoring warnings
warnings.filterwarnings('ignore')

# setting visual theme
sns.set_theme(style = 'white', palette = None)
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier


import time
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### 1.2. Import data

# %%
df = pd.read_csv("data/processed/df_preprocessed.csv")
df.set_index('Customer ID', inplace = True)

# %% [markdown]
# ### 1.3. Check for duplicates
# __`Duplicates`__ Drop any duplicate rows present in the dataframe with the method `drop_duplicates()`

# %%
df.shape
# Out:
# (7043, 59)

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (7043, 59)

# %% [markdown]
# ***
# [BACK TO TOC](#toc)
#
# <div class="alert alert-block alert-success">
# <a id='explore'>
# <font color = '#006400'>
#
# # 2. Data Exploration </font>
# </a>
#
# </div>
#
# Understand the structure of the data and provide the first impressions of patterns, relations and errors.

# %% [markdown]
# ### 2.1. Basic info and statistics

# %%
import pandas as pd

def df_info(data): 
    '''
    Returns a dataframe of .info() method, instead of its usual design
    
    Args: 
        data (panda dataframe) - data to analyse
    Returns: 
        pandas dataframe
    '''
    
    tab_info = pd.DataFrame(data.dtypes).T.rename(index={0:'Column type'})
    tab_info = pd.concat([tab_info, pd.DataFrame(data.isna().sum()).T.rename(index={0:'Count for missing values'})])
    tab_info = pd.concat([tab_info, pd.DataFrame(data.isna().sum() / len(data)*100).T.rename(index={0:'Missing values (in %)'})])
    tab_info = tab_info.T.join(data.describe().T).fillna('-')
    
    return tab_info

# Example usage:
# display(df_info(df).style)

# Checking train and test shapes
print(f'\n\n\033[1mTrain set has {df.shape[1]} features with data from {df.shape[0]} Clients.\n',
      f'\nTest set has {df.shape[1]} features (doesn\'t have target) with data from {df.shape[0]} Clients.')
# Out:
# Train set has 59 features with data from 7043 Clients.
#
# Test set has 59 features (doesn't have target) with data from 7043 Clients.

# %% [markdown]
# __For qualitative features__:

# %%
df.describe(include='O').T
# Out:
#              count unique                            top freq
# City          7043   1106                    Los Angeles  293
# Churn Reason  1869     20  Competitor had better devices  313

# %% [markdown]
# ### 2.2. Further exploration

# %% [markdown]
# __Skewness and Kurtosis__

# %%
# Compute skewness and kurtosis on numeric variables only
num_cols = df.select_dtypes(include=np.number).columns
tab_info4 = pd.DataFrame(df[num_cols].skew(), columns=['Skewness'])
tab_info5 = pd.DataFrame(df[num_cols].kurtosis(), columns=['Kurtosis'])
tab_info2 = pd.concat([tab_info4,tab_info5])
tab_info2
# Out:
#                          Skewness  Kurtosis
# Age                      0.162186       NaN
# Under 30                 1.508777       NaN
# Senior Citizen           1.833633       NaN
# Married                  0.067922       NaN
# Dependents               1.276686       NaN
# ...                           ...       ...
# Density_High                  NaN -1.540640
# Density_Low                   NaN -1.479143
# Contract_Month-to-Month       NaN -1.998038
# Contract_One Year             NaN -0.173223
# Contract_Two Year             NaN -0.894553
#
# [114 rows x 2 columns]

# %% [markdown]
# __Categorical Variables - Check levels/possible values__

# %%
# Check unique values
df['Churn Reason'].value_counts()
# Out:
# Churn Reason
# Competitor had better devices                313
# Competitor made better offer                 311
# Attitude of support person                   220
# Don't know                                   130
# Competitor offered more data                 117
# Competitor offered higher download speeds    100
# Attitude of service provider                  94
# Price too high                                78
# Product dissatisfaction                       77
# Network reliability                           72
# Long distance charges                         64
# Service dissatisfaction                       63
# Moved                                         46
# Extra data charges                            39
# Limited range of services                     37
# Poor expertise of online support              31
# Lack of affordable download/upload speed      30
# Lack of self-service on Website               29
# Poor expertise of phone support               12
# Deceased                                       6
# Name: count, dtype: int64

# %% [markdown]
# [BACK TO TOC](#toc)
#
# ### 2.3. Visual Exploration

# %%
pd.set_option('display.max_columns', None)
df.head(3)
# Out:
#                   Age  Under 30  Senior Citizen  Married  Dependents  \
# Customer ID
# 8779-QRDMV   0.967213         0               1        0           0
# 7495-OOKFY   0.901639         0               1        1           1
# 1658-BYGOY   0.852459         0               1        0           1
#
#              Number of Dependents         City  Referred a Friend  \
# Customer ID
# 8779-QRDMV               0.000000  Los Angeles                  0
# 7495-OOKFY               0.111111  Los Angeles                  1
# 1658-BYGOY               0.333333  Los Angeles                  0
#
#              Number of Referrals  Tenure in Months  Tenure Category  \
# Customer ID
# 8779-QRDMV              0.000000          0.000000             0.00
# 7495-OOKFY              0.090909          0.098592             0.25
# 1658-BYGOY              0.000000          0.239437             0.50
#
#              Phone Service  Avg Monthly Long Distance Charges  Multiple Lines  \
# Customer ID
# 8779-QRDMV               0                           0.000000               0
# 7495-OOKFY               1                           0.977195               1
# 1658-BYGOY               1                           0.226645               1
#
#              Internet Service  Avg Monthly GB Download  Online Security  \
# Customer ID
# 8779-QRDMV                  1                 0.094118                0
# 7495-OOKFY                  1                 0.200000                0
# 1658-BYGOY                  1                 0.611765                0
#
#              Online Backup  Device Protection Plan  Premium Tech Support  \
# Customer ID
# 8779-QRDMV               0                       1                     0
# 7495-OOKFY               1                       0                     0
# 1658-BYGOY               0                       0                     0
#
#              Streaming TV  Streaming Movies  Streaming Music  Unlimited Data  \
# Customer ID
# 8779-QRDMV              0                 1                0               0
# 7495-OOKFY              0                 0                0               1
# 1658-BYGOY              1                 1                1               1
#
#              Paperless Billing  Monthly Charge  Total Charges  Total Refunds  \
# Customer ID
# 8779-QRDMV                   1        0.212935       0.002406       0.000000
# 7495-OOKFY                   1        0.620896       0.070909       0.000000
# 1658-BYGOY                   1        0.768159       0.200063       0.916047
#
#              Total Extra Data Charges  Total Long Distance Charges  \
# Customer ID
# 8779-QRDMV                   0.133333                     0.000000
# 7495-OOKFY                   0.000000                     0.109630
# 1658-BYGOY                   0.000000                     0.057211
#
#              Total Revenue  Satisfaction Score  New Customer  Churn Label  \
# Customer ID
# 8779-QRDMV        0.003202                0.50             0            1
# 7495-OOKFY        0.083855                0.50             0            1
# 1658-BYGOY        0.158013                0.25             0            1
#
#              Churn Score      CLTV                  Churn Reason  Population  \
# Customer ID
# 8779-QRDMV      0.945055  0.762731  Competitor offered more data    0.652488
# 7495-OOKFY      0.703297  0.733600  Competitor made better offer    0.528687
# 1658-BYGOY      0.835165  0.261508  Competitor made better offer    0.451422
#
#              Engagement Score  Gender_Male  Offer_Offer A  Offer_Offer B  \
# Customer ID
# 8779-QRDMV           0.142857            1              0              0
# 7495-OOKFY           0.571429            0              0              0
# 1658-BYGOY           0.428571            1              0              0
#
#              Offer_Offer C  Offer_Offer D  Offer_Offer E  Internet Type_Cable  \
# Customer ID
# 8779-QRDMV               0              0              0                    0
# 7495-OOKFY               0              0              1                    0
# 1658-BYGOY               0              1              0                    0
#
#              Internet Type_DSL  Internet Type_Fiber Optic  \
# Customer ID
# 8779-QRDMV                   1                          0
# 7495-OOKFY                   0                          1
# 1658-BYGOY                   0                          1
#
#              Payment Method_Bank Withdrawal  Payment Method_Credit Card  \
# Customer ID
# 8779-QRDMV                                1                           0
# 7495-OOKFY                                0                           1
# 1658-BYGOY                                1                           0
#
#              Churn Category_Attitude  Churn Category_Competitor  \
# Customer ID
# 8779-QRDMV                         0                          1
# 7495-OOKFY                         0                          1
# 1658-BYGOY                         0                          1
#
#              Churn Category_Dissatisfaction  Churn Category_Price  \
# Customer ID
# 8779-QRDMV                                0                     0
# 7495-OOKFY                                0                     0
# 1658-BYGOY                                0                     0
#
#              Density_High  Density_Low  Contract_Month-to-Month  \
# Customer ID
# 8779-QRDMV              1            0                        1
# 7495-OOKFY              1            0                        1
# 1658-BYGOY              1            0                        1
#
#              Contract_One Year  Contract_Two Year
# Customer ID
# 8779-QRDMV                   0                  0
# 7495-OOKFY                   0                  0
# 1658-BYGOY                   0                  0

# %%
# Group by Monthly Charge and count the number of clients for each Churn Label
line_data = df.groupby(['Monthly Charge', 'Churn Label']).size().unstack()

# Plot the line graph with custom colors
line_data.plot(kind='line', figsize=(8, 4), color=['#D9D9D9', '#B0C726'])

# Set labels and title
plt.xlabel('Monthly Charge')
plt.ylabel('Number of Clients')
plt.title('Number of Clients by Monthly Charge and Churn Label')

# Customize legend labels and colors
legend_labels = ['Not Churn', 'Churn']
plt.legend(legend_labels, title='Churn Label', loc='upper right')

plt.savefig('outputs/Number of Clients by Monthly Charge and Churn Label.png', bbox_inches='tight', transparent=True)
# Show the plot
plt.show()

# %%
# Group by Monthly Charge and count the number of clients for each Churn Label
line_data = df.groupby(['Total Revenue', 'Churn Label']).size().unstack()

# Plot the line graph with custom colors
line_data.plot(kind='line', figsize=(8, 4), color=['#D9D9D9', '#B0C726'])

# Set labels and title
plt.xlabel('Total Revenue')
plt.ylabel('Number of Clients')
plt.title('Number of Clients by Total Revenue and Churn Label')

# Customize legend labels and colors
legend_labels = ['Not Churn', 'Churn']
plt.legend(legend_labels, title='Churn Label', loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# __Spearman correlation between numerical variables:__

# %% [markdown]
# ***
# [BACK TO TOC](#toc)
#
# ### 2.4. Outliers

# %% [markdown]
# **Outliers: IQR approach**
# > * The IQR method states that values locating outside the interval **[Q1 - 1.5 * IQR, Q1 + 1.5 * IQR] are outliers**
# > * Because the data is sensitive, only extreme values with IQR test will be considered for this test __by using a criterion of 3__
# > * The 3(IQR) criterion tells us that any observation that falls outside the decision range is considered an extreme outlier
# > * Percentage of remaining data after outlier removal with IQR method when criterion is 3: 63.04 % of remaining data

# %%
# Identify numeric columns excluding binary variables
numeric_cols = df.select_dtypes(include=[np.number]).columns
non_binary_cols = [col for col in numeric_cols if len(df[col].unique()) > 2]

# Calculate the interquartile range for each non-binary numeric variable
q1 = df[non_binary_cols].quantile(0.25)
q3 = df[non_binary_cols].quantile(0.75)
iqr = q3 - q1

# Calculate the lower and upper bounds for each non-binary variable
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Identify outliers for each non-binary variable
outliers = ((df[non_binary_cols] < lower_bound) | (df[non_binary_cols] > upper_bound))

# Count outliers for each non-binary variable
outliers_count = outliers.sum()

# Exclude columns with only 1 or 0 outliers and are binary
outliers_count_filtered = outliers_count[(outliers_count > 1) & (outliers_count < len(df) - 1)]

# Display only non-binary columns with more than 1 and less than (len(data) - 1) outliers
print(outliers_count_filtered)
# Out:
# Number of Dependents           1627
# Number of Referrals             676
# Avg Monthly GB Download         362
# Total Refunds                   525
# Total Extra Data Charges        728
# Total Long Distance Charges     196
# Total Revenue                    21
# Satisfaction Score              922
# Population                       57
# dtype: int64

# %%
# Determine the number of subplots needed
num_plots = len(outliers_count_filtered.index)
num_cols = 4
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

# Create subplots with boxplots in a 4x4 grid
fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 8))

# Flatten the axes array to make it easier to iterate
axes = axes.flatten()

# Iterate through each variable with outliers
for i, col in enumerate(outliers_count_filtered.index):
    if col in df.columns:
        sns.boxplot(x=df[col], ax=axes[i])
        axes[i].set_title(f'{col}')
    else:
        print(f"Column '{col}' not found in the DataFrame.")

# Remove any empty subplots
for j in range(num_plots, num_cols * num_rows):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
def check_IQR_outliers(data, criterion, mode='data'):
    '''
    Detects outliers by generating a decision range based on a criterion (threshold) 
    and locating values that don't fall within this range. 
    Can return the dataframe without the outliers or the percentage of remaining data
    after outlier removal or the values considered as outliers for each column by 
    changing the parameter 'mode' (data as default)
    
    Args: 
        data (pandas.core.frame.DataFrame) : set of data 
        criterion (int) : IQR multiplier, the higher, the larger the decision range
        mode (str): 'data' to get dataframe without outliers 'perc' to check percentage
                     or 'values' to check values
        
    Returns:
        Dataframe without 
        Print with percentage of remaining data after outlier removal or
        index and values that fall outside the decision range (outliers)
    '''
    if mode == 'data':
        # Select only numeric columns
        numeric_data = data.select_dtypes(include=np.number)
        
        Q1 = numeric_data.quantile(0.25)
        Q3 = numeric_data.quantile(0.75)
        IQR = Q3 - Q1
        lower_lim = Q1 - criterion * IQR
        upper_lim = Q3 + criterion * IQR

        # Use boolean indexing to get the rows without outliers
        outliers = data[~((numeric_data < lower_lim) | (numeric_data > upper_lim)).any(axis=1)]

        return outliers
        
    elif mode == 'perc':
        print('\n\033[1mPercentage of remaining data after outlier removal with IQR method:\033[0m\n')
        # Select only numeric columns
        numeric_data = data.select_dtypes(include=np.number)
        
        Q1 = numeric_data.quantile(0.25)
        Q3 = numeric_data.quantile(0.75)
        IQR = Q3 - Q1
        lower_lim = Q1 - criterion * IQR
        upper_lim = Q3 + criterion * IQR

        # Use boolean indexing to get the rows without outliers
        outliers = data[~((numeric_data < lower_lim) | (numeric_data > upper_lim)).any(axis=1)]

        remaining_percentage = 100 * len(outliers) / len(data)
        print(f'\033[1m{round(remaining_percentage, 3)} %\033[0m of remaining data after IQR method outlier removal, when criterion is {criterion}')

    else:
        print('\n\n\033[1mOutlier Values:\033[0m\n')
        for col in data.select_dtypes(np.number).columns:
            Q1 = data[col].quantile(0.25)
            Q3 = data[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_lim = Q1 - criterion * IQR
            upper_lim = Q3 + criterion * IQR

            outliers = data[(data[col] > upper_lim) | (data[col] < lower_lim)][col]
            print(f'Outlier values in \033[1m{col}\033[0m:\n')
            for idx, val in outliers.items():
                print(f'Value from Client {idx}: \033[1m', round(val, 2), '\033[0m\n')

# checking outlier values
check_IQR_outliers(data=df, criterion=3, mode='value')

# checking percentage of remaining data
check_IQR_outliers(data=df, criterion=3, mode='perc')
# Out:
# Outlier Values:
#
# Outlier values in Age:
#
# Outlier values in Under 30:
#
# Value from Client 9237-HQITU:  1
#
# Value from Client 7892-POOKP:  1
#
# Value from Client 4190-MFLUW:  1
#
# Value from Client 1066-JKSGK:  1
#
# Value from Client 8665-UTDHZ:  1
#
# Value from Client 8773-HHUOZ:  1
#
# Value from Client 3192-NQECA:  1
#
# Value from Client 0404-SWRVG:  1
#
# Value from Client 6207-WIOLX:  1
#
# Value from Client 0867-MKZVY:  1
#
# Value from Client 1875-QIVME:  1
#
# Value from Client 0691-JVSYA:  1
#
# Value from Client 1024-GUALD:  1
#
# Value from Client 7841-TZDMQ:  1
#
# Value from Client 2232-DMLXU:  1
#
# Value from Client 1251-KRREG:  1
#
# Value from Client 4484-GLZOU:  1
#
# Value from Client 6390-DSAZX:  1
#
# Value from Client 0122-OAHPZ:  1
#
# Value from Client 6680-NENYN:  1
#
# Value from Client 0219-YTZUE:  1
#
# Value from Client 0259-GBZSH:  1
#
# Value from Client 6905-NIQIN:  1
#
# Value from Client 0578-SKVMF:  1
#
# Value from Client 9063-ZGTUY:  1
#
# Value from Client 7752-XUSCI:  1
#
# Value from Client 0880-TKATG:  1
#
# Value from Client 3583-EKAPL:  1
#
# Value from Client 0447-BEMNG:  1
#
# Value from Client 0388-EOPEX:  1
#
# Value from Client 8397-MVTAZ:  1
#
# Value from Client 6986-IJDHX:  1
#
# Value from Client 3627-FHKBK:  1
#
# Value from Client 4765-OXPPD:  1
#
# Value from Client 1009-IRMNA:  1
#
# Value from Client 7207-RMRDB:  1
#
# Value from Client 0195-IESCP:  1
#
# Value from Client 2024-BASKD:  1
#
# Value from Client 3276-HDUEG:  1
#
# Value from Client 0822-GAVAP:  1
#
# Value from Client 5896-NPFWW:  1
#
# Value from Client 1029-QFBEN:  1
#
# Value from Client 1589-AGTLK:  1
#
# Value from Client 6439-GTPCA:  1
#
# Value from Client 2037-XJFUP:  1
#
# Value from Client 1820-TQVEV:  1
#
# Value from Client 2239-JALAW:  1
#
# Value from Client 4853-RULSV:  1
#
# Value from Client 0115-TFERT:  1
#
# Value from Client 3104-OWCGK:  1
#
# Value from Client 3027-ZTDHO:  1
#
# Value from Client 3313-QKNKB:  1
#
# Value from Client 9734-YWGEX:  1
#
# Value from Client 9448-REEVD:  1
#
# Value from Client 3842-IYKUE:  1
#
# Value from Client 6993-OHLXR:  1
#
# Value from Client 3863-IUBJR:  1
#
# Value from Client 6941-PMGEP:  1
#
# Value from Client 0376-YMCJC:  1
#
# Value from Client 4361-BKAXE:  1
#
# Value from Client 8824-RWFXJ:  1
#
# Value from Client 4081-DYXAV:  1
#
# Value from Client 0927-LCSMG:  1
#
# Value from Client 5673-FSSMF:  1
#
# Value from Client 6358-LYNGM:  1
#
# Value from Client 2833-SLKDQ:  1
#
# Value from Client 7993-PYKOF:  1
#
# Value from Client 7831-QGOXH:  1
#
# Value from Client 3838-OZURD:  1
#
# Value from Client 3249-ZPQRG:  1
#
# Value from Client 7721-JXEAW:  1
#
# Value from Client 4704-ERYFC:  1
#
# Value from Client 6240-EURKS:  1
#
# Value from Client 6960-HVYXR:  1
#
# Value from Client 1571-SAVHK:  1
#
# Value from Client 2951-QOQTK:  1
#
# Value from Client 4763-PGDPO:  1
#
# Value from Client 5394-SVGJV:  1
#
# Value from Client 9851-QXEEQ:  1
#
# Value from Client 3186-BAXNB:  1
#
# Value from Client 2929-QNSRW:  1
#
# Value from Client 3331-HQDTW:  1
#
# Value from Client 7963-GQRMY:  1
#
# Value from Client 4423-YLHDV:  1
#
# Value from Client 4116-TZAQJ:  1
#
# Value from Client 7530-HDYDS:  1
#
# Value from Client 5922-ABDVO:  1
#
# Value from Client 0621-TWIEM:  1
#
# Value from Client 1612-EOHDH:  1
#
# Value from Client 7054-LGEQW:  1
#
# Value from Client 3143-ILDAL:  1
#
# Value from Client 6651-AZVTJ:  1
#
# Value from Client 9614-RMGHA:  1
#
# Value from Client 7615-ESMYF:  1
#
# Value from Client 8565-CLBZW:  1
#
# Value from Client 0224-HJAPT:  1
#
# Value from Client 6845-RGTYS:  1
#
# Value from Client 7065-YUNRY:  1
#
# Value from Client 3753-TSEMP:  1
#
# Value from Client 6173-ITPWD:  1
#
# Value from Client 9734-UYXQI:  1
#
# Value from Client 2189-UXTKY:  1
#
# Value from Client 6356-ELRKD:  1
#
# Value from Client 8945-MUQUF:  1
#
# Value from Client 0524-IAVZO:  1
#
# Value from Client 2737-YNGYW:  1
#
# Value from Client 2506-CLAKW:  1
#
# Value from Client 0320-JDNQG:  1
#
# Value from Client 4307-KTUMW:  1
#
# Value from Client 3870-MQAMG:  1
#
# Value from Client 4800-CZMPC:  1
#
# Value from Client 5136-KCKGI:  1
#
# Value from Client 3722-WPXTK:  1
#
# Value from Client 2929-ERCFZ:  1
#
# Value from Client 8835-VSDSE:  1
#
# Value from Client 7089-IVVAZ:  1
#
# Value from Client 2636-OHFMN:  1
#
# Value from Client 9206-GVPEQ:  1
#
# Value from Client 3707-GNWHM:  1
#
# Value from Client 0137-OCGAB:  1
#
# Value from Client 4588-YBNIB:  1
#
# Value from Client 5028-GZLDO:  1
#
# Value from Client 6877-TJMBR:  1
#
# Value from Client 6769-DCQLI:  1
#
# Value from Client 2725-KXXWT:  1
#
# Value from Client 8348-HFYIV:  1
#
# Value from Client 7341-LXCAF:  1
#
# Value from Client 7598-UAASY:  1
#
# Value from Client 7938-OUHIO:  1
#
# Value from Client 5624-BQSSA:  1
#
# Value from Client 2691-NZETQ:  1
#
# Value from Client 7209-JCUDS:  1
#
# Value from Client 3763-GCZHZ:  1
#
# Value from Client 2002-MZHWP:  1
#
# Value from Client 7508-MYBOG:  1
#
# Value from Client 1428-GTBJJ:  1
#
# Value from Client 2386-LAHRK:  1
#
# Value from Client 0516-WJVXC:  1
#
# Value from Client 3523-QRQLL:  1
#
# Value from Client 8806-EAGWC:  1
#
# Value from Client 5828-AVIPD:  1
#
# Value from Client 0697-ZMSWS:  1
#
# Value from Client 6347-DCUIK:  1
#
# Value from Client 9124-LHCJQ:  1
#
# Value from Client 3658-KIBGF:  1
#
# Value from Client 4585-HETAI:  1
#
# Value from Client 4918-QLLIW:  1
#
# Value from Client 7274-RTAPZ:  1
#
# Value from Client 3834-XUIFC:  1
#
# Value from Client 7587-RZNME:  1
#
# Value from Client 9474-PHLYD:  1
#
# Value from Client 2165-VOEGB:  1
#
# Value from Client 7594-RQHXR:  1
#
# Value from Client 7541-YLXCL:  1
#
# Value from Client 8722-NGNBH:  1
#
# Value from Client 3656-TKRVZ:  1
#
# Value from Client 2612-RANWT:  1
#
# Value from Client 5899-MQZZL:  1
#
# Value from Client 6038-GCYEC:  1
#
# Value from Client 0968-GSIKN:  1
#
# Value from Client 2645-QTLMB:  1
#
# Value from Client 5960-WPXQM:  1
#
# Value from Client 8260-NGFNY:  1
#
# Value from Client 2930-UOTMB:  1
#
# Value from Client 3932-CMDTD:  1
#
# Value from Client 3594-UVONA:  1
#
# Value from Client 4817-VYYWS:  1
#
# Value from Client 5759-RCVCB:  1
#
# Value from Client 3815-SLMEF:  1
#
# Value from Client 4587-VVTOX:  1
#
# Value from Client 2565-JSLRY:  1
#
# Value from Client 3677-TNKIO:  1
#
# Value from Client 3415-TAILE:  1
#
# Value from Client 7239-HZZCX:  1
#
# Value from Client 7665-TOALD:  1
#
# Value from Client 2777-PHDEI:  1
#
# Value from Client 0746-JTRFU:  1
#
# Value from Client 4628-CTTLA:  1
#
# Value from Client 2748-MYRVK:  1
#
# Value from Client 4088-YLDSU:  1
#
# Value from Client 3066-RRJIO:  1
#
# Value from Client 2150-UWTFY:  1
#
# Value from Client 2157-MXBJS:  1
#
# Value from Client 1043-YCUTE:  1
#
# Value from Client 1226-UDFZR:  1
#
# Value from Client 4489-SNOJF:  1
#
# Value from Client 6996-KNSML:  1
#
# Value from Client 8642-GVWRF:  1
#
# Value from Client 3400-ESFUW:  1
#
# Value from Client 9039-RBEEE:  1
#
# Value from Client 0137-UDEUO:  1
#
# Value from Client 4925-LMHOK:  1
#
# Value from Client 2037-SGXHH:  1
#
# Value from Client 4806-KEXQR:  1
#
# Value from Client 7083-YNSKY:  1
#
# Value from Client 7434-SHXLS:  1
#
# Value from Client 2013-SGDXK:  1
#
# Value from Client 0378-TOVMS:  1
#
# Value from Client 0318-QUUOB:  1
#
# Value from Client 5520-FVEWJ:  1
#
# Value from Client 5572-ZDXHY:  1
#
# Value from Client 3440-JPSCL:  1
#
# Value from Client 3540-RZJYU:  1
#
# Value from Client 0883-EIBTI:  1
#
# Value from Client 5729-KLZAR:  1
#
# Value from Client 1582-RAFML:  1
#
# Value from Client 1678-FYZOW:  1
#
# Value from Client 6532-YLWSI:  1
#
# Value from Client 5174-RNGBH:  1
#
# Value from Client 2568-OIADY:  1
#
# Value from Client 1193-RTSLK:  1
#
# Value from Client 1565-RHDJD:  1
#
# Value from Client 3765-JXVKY:  1
#
# Value from Client 7330-WZLNC:  1
#
# Value from Client 2612-RRIDN:  1
#
# Value from Client 3669-LVWZB:  1
#
# Value from Client 9239-ZBZZV:  1
#
# Value from Client 9692-TUSXH:  1
#
# Value from Client 3744-ZRRDZ:  1
#
# Value from Client 8563-IIOXK:  1
#
# Value from Client 5980-NOPLP:  1
#
# Value from Client 0947-IDHRQ:  1
#
# Value from Client 2983-ZANRP:  1
#
# Value from Client 7845-URHJN:  1
#
# Value from Client 5366-IJEQJ:  1
#
# Value from Client 6682-QJDGB:  1
#
# Value from Client 3049-SOLAY:  1
#
# Value from Client 2082-OJVTK:  1
#
# Value from Client 2894-QOJRX:  1
#
# Value from Client 3521-SYVOR:  1
#
# Value from Client 9050-QLROH:  1
#
# Value from Client 0877-SDMBN:  1
#
# Value from Client 9637-EIHEQ:  1
#
# Value from Client 2362-IBOOY:  1
#
# Value from Client 7503-ZGUZJ:  1
#
# Value from Client 6142-VSJQO:  1
#
# Value from Client 3803-KMQFW:  1
#
# Value from Client 1794-HBQTJ:  1
#
# Value from Client 4818-DRBQT:  1
#
# Value from Client 1493-AMTIE:  1
#
# Value from Client 6821-BUXUX:  1
#
# Value from Client 0231-LXVAP:  1
#
# Value from Client 3244-DCJWY:  1
#
# Value from Client 1984-FCOWB:  1
#
# Value from Client 6108-OQZDQ:  1
#
# Value from Client 0363-QJVFX:  1
#
# Value from Client 8042-JVNFH:  1
#
# Value from Client 2237-ZFSMY:  1
#
# Value from Client 4548-SDBKE:  1
#
# Value from Client 8066-POXGX:  1
#
# Value from Client 9102-IAYHT:  1
#
# Value from Client 4361-JEIVL:  1
#
# Value from Client 2202-CUYXZ:  1
#
# Value from Client 6261-RCVNS:  1
#
# Value from Client 7951-QKZPL:  1
#
# Value from Client 1522-VVDMG:  1
#
# Value from Client 9185-TQCVP:  1
#
# Value from Client 8063-RJYNF:  1
#
# Value from Client 0687-ZVTHB:  1
#
# Value from Client 9661-ACXBS:  1
#
# Value from Client 4250-ZBWLV:  1
#
# Value from Client 1555-DJEQW:  1
#
# Value from Client 6338-AVWCY:  1
#
# Value from Client 4523-WXCEF:  1
#
# Value from Client 9249-FXSCK:  1
#
# Value from Client 5493-SDRDQ:  1
#
# Value from Client 6776-TLWOI:  1
#
# Value from Client 8650-RHRKE:  1
#
# Value from Client 2867-UIMSS:  1
#
# Value from Client 8111-RKSPX:  1
#
# Value from Client 2575-GFSOE:  1
#
# Value from Client 2842-JTCCU:  1
#
# Value from Client 6956-SMUCM:  1
#
# Value from Client 9053-JZFKV:  1
#
# Value from Client 9250-WYPLL:  1
#
# Value from Client 1842-EZJMK:  1
#
# Value from Client 0702-PGIBZ:  1
#
# Value from Client 5889-LFOLL:  1
#
# Value from Client 8708-XPXHZ:  1
#
# Value from Client 6876-ADESB:  1
#
# Value from Client 0520-FDVVT:  1
#
# Value from Client 3315-TOTBP:  1
#
# Value from Client 1309-BXVOQ:  1
#
# Value from Client 4488-PSYCG:  1
#
# Value from Client 0023-XUOPT:  1
#
# Value from Client 7242-QZLXF:  1
#
# Value from Client 4576-CSAJH:  1
#
# Value from Client 1000-AJSLD:  1
#
# Value from Client 9259-PACGQ:  1
#
# Value from Client 2810-FTLEM:  1
#
# Value from Client 2737-WFVYW:  1
#
# Value from Client 8676-TRMJS:  1
#
# Value from Client 9451-LPGOO:  1
#
# Value from Client 0402-CQAJN:  1
#
# Value from Client 7603-USHJS:  1
#
# Value from Client 3926-CUQZX:  1
#
# Value from Client 1041-RXHRA:  1
#
# Value from Client 1450-SKCVI:  1
#
# Value from Client 6502-MJQAE:  1
#
# Value from Client 6394-MFYNG:  1
#
# Value from Client 4745-LSPLO:  1
#
# Value from Client 2108-XWMPY:  1
#
# Value from Client 5482-NUPNA:  1
#
# Value from Client 0639-TSIQW:  1
#
# Value from Client 7469-LKBCI:  1
#
# Value from Client 5129-JLPIS:  1
#
# Value from Client 3638-WEABW:  1
#
# Value from Client 6865-JZNKO:  1
#
# Value from Client 6572-ADKRS:  1
#
# Value from Client 9867-JCZSP:  1
#
# Value from Client 5948-UJZLF:  1
#
# Value from Client 7639-LIAYI:  1
#
# Value from Client 1215-FIGMP:  1
#
# Value from Client 7410-OIEDU:  1
#
# Value from Client 0731-EBJQB:  1
#
# Value from Client 8108-UXRQN:  1
#
# Value from Client 1862-QRWPE:  1
#
# Value from Client 6380-ARCEH:  1
#
# Value from Client 6728-DKUCO:  1
#
# Value from Client 1091-SOZGA:  1
#
# Value from Client 6497-TILVL:  1
#
# Value from Client 7219-TLZHO:  1
#
# Value from Client 3774-VBNXY:  1
#
# Value from Client 1679-JRFBR:  1
#
# Value from Client 3077-RSNTJ:  1
#
# Value from Client 9167-APMXZ:  1
#
# Value from Client 2907-ILJBN:  1
#
# Value from Client 5947-SGKCL:  1
#
# Value from Client 3712-PKXZA:  1
#
# Value from Client 6582-OIVSP:  1
#
# Value from Client 8167-GJLRN:  1
#
# Value from Client 7100-FQPRV:  1
#
# Value from Client 9178-JHUVJ:  1
#
# Value from Client 6168-YBYNP:  1
#
# Value from Client 3645-DEYGF:  1
#
# Value from Client 1347-KTTTA:  1
#
# Value from Client 4709-LKHYG:  1
#
# Value from Client 6496-JDSSB:  1
#
# Value from Client 6778-JFCMK:  1
#
# Value from Client 6341-JVQGF:  1
#
# Value from Client 0945-TSONX:  1
#
# Value from Client 0959-WHOKV:  1
#
# Value from Client 4075-JFPGR:  1
#
# Value from Client 3675-YDUPJ:  1
#
# Value from Client 4111-BNXIF:  1
#
# Value from Client 4130-MZLCC:  1
#
# Value from Client 0314-TKOSI:  1
#
# Value from Client 2080-SRCDE:  1
#
# Value from Client 9577-WJVCQ:  1
#
# Value from Client 3727-OWVYD:  1
#
# Value from Client 1557-EMYVT:  1
#
# Value from Client 5027-YOCXN:  1
#
# Value from Client 7982-VCELR:  1
#
# Value from Client 7520-HQWJU:  1
#
# Value from Client 8966-SNIZF:  1
#
# Value from Client 5160-UXJED:  1
#
# Value from Client 8984-EYLLL:  1
#
# Value from Client 9069-LGEUL:  1
#
# Value from Client 6862-CQUMB:  1
#
# Value from Client 7156-MXBJE:  1
#
# Value from Client 5973-EJGDP:  1
#
# Value from Client 4686-GEFRM:  1
#
# Value from Client 5249-QYHEX:  1
#
# Value from Client 8734-DKSTZ:  1
#
# Value from Client 4360-PNRQB:  1
#
# Value from Client 6048-NJXHX:  1
#
# Value from Client 4980-URKXC:  1
#
# Value from Client 5168-MSWXT:  1
#
# Value from Client 4785-FCIFB:  1
#
# Value from Client 0942-KOWSM:  1
#
# Value from Client 6614-VBEGU:  1
#
# Value from Client 2996-XAUVF:  1
#
# Value from Client 1304-BCCFO:  1
#
# Value from Client 3649-JPUGY:  1
#
# Value from Client 5736-YEJAX:  1
#
# Value from Client 8535-SFUTN:  1
#
# Value from Client 3482-ABPKK:  1
#
# Value from Client 0913-XWSCN:  1
#
# Value from Client 4234-XTNEA:  1
#
# Value from Client 5844-QVTAT:  1
#
# Value from Client 5394-MEITZ:  1
#
# Value from Client 2560-PPCHE:  1
#
# Value from Client 1352-HNSAW:  1
#
# Value from Client 1982-FEBTD:  1
#
# Value from Client 2654-VBVPB:  1
#
# Value from Client 7343-EOBEU:  1
#
# Value from Client 7319-VENRZ:  1
#
# Value from Client 5846-NEQVZ:  1
#
# Value from Client 6967-QIQRV:  1
#
# Value from Client 0308-IVGOK:  1
#
# Value from Client 9548-LIGTA:  1
#
# Value from Client 5150-LJNSR:  1
#
# Value from Client 8752-IMQOS:  1
#
# Value from Client 0795-LAFGP:  1
#
# Value from Client 0459-SPZHJ:  1
#
# Value from Client 5172-MIGPM:  1
#
# Value from Client 5839-SUYVZ:  1
#
# Value from Client 6516-NKQBO:  1
#
# Value from Client 0516-UXRMT:  1
#
# Value from Client 3003-CMDUU:  1
#
# Value from Client 5016-IBERQ:  1
#
# Value from Client 8404-VLQFB:  1
#
# Value from Client 2391-IPLOP:  1
#
# Value from Client 3030-ZKIWL:  1
#
# Value from Client 5533-RJFTJ:  1
#
# Value from Client 0214-JHPFW:  1
#
# Value from Client 0078-XZMHT:  1
#
# Value from Client 8338-QIUNR:  1
#
# Value from Client 7596-ZYWBB:  1
#
# Value from Client 3014-WJKSM:  1
#
# Value from Client 9661-JALZV:  1
#
# Value from Client 5575-TPIZQ:  1
#
# Value from Client 4697-LUPSU:  1
#
# Value from Client 8434-VGEQQ:  1
#
# Value from Client 6786-OBWQR:  1
#
# Value from Client 7564-GHCVB:  1
#
# Value from Client 1173-NOEYG:  1
#
# Value from Client 6647-ZEDXT:  1
#
# Value from Client 2521-NPUZR:  1
#
# Value from Client 4018-PPNDW:  1
#
# Value from Client 9477-LGWQI:  1
#
# Value from Client 3115-CZMZD:  1
#
# Value from Client 0139-IVFJG:  1
#
# Value from Client 0030-FNXPP:  1
#
# Value from Client 4718-DHSMV:  1
#
# Value from Client 7817-OMJNA:  1
#
# Value from Client 8823-RLPWL:  1
#
# Value from Client 3758-CKOQL:  1
#
# Value from Client 9871-ELEYA:  1
#
# Value from Client 4257-GAESD:  1
#
# Value from Client 2040-OBMLJ:  1
#
# Value from Client 3807-XHCJH:  1
#
# Value from Client 2798-NYLMZ:  1
#
# Value from Client 3551-GAEGL:  1
#
# Value from Client 3196-NVXLZ:  1
#
# Value from Client 6092-QZVPP:  1
#
# Value from Client 0422-OHQHQ:  1
#
# Value from Client 7408-OFWXJ:  1
#
# Value from Client 8374-UULRV:  1
#
# Value from Client 1573-LGXBA:  1
#
# Value from Client 3050-GBUSH:  1
#
# Value from Client 7945-HLKEA:  1
#
# Value from Client 5170-PTRKA:  1
#
# Value from Client 0048-LUMLS:  1
#
# Value from Client 8975-SKGRX:  1
#
# Value from Client 2267-FPIMA:  1
#
# Value from Client 1051-GEJLJ:  1
#
# Value from Client 4694-PHWFW:  1
#
# Value from Client 0835-JKADZ:  1
#
# Value from Client 6024-RUGGH:  1
#
# Value from Client 7471-WNSUF:  1
#
# Value from Client 8942-DBMHZ:  1
#
# Value from Client 4301-VVZKA:  1
#
# Value from Client 7567-ECMCM:  1
#
# Value from Client 8388-FYNPZ:  1
#
# Value from Client 0556-FJEGU:  1
#
# Value from Client 6461-PPAXN:  1
#
# Value from Client 3318-ISQFQ:  1
#
# Value from Client 1106-HRLKZ:  1
#
# Value from Client 2483-XSSMZ:  1
#
# Value from Client 9046-JBFWA:  1
#
# Value from Client 9108-EQPNQ:  1
#
# Value from Client 7277-KAMWT:  1
#
# Value from Client 2545-LXYVJ:  1
#
# Value from Client 3234-VKACU:  1
#
# Value from Client 8917-FAEMR:  1
#
# Value from Client 0929-HYQEW:  1
#
# Value from Client 3422-WJOYD:  1
#
# Value from Client 8146-QQKZH:  1
#
# Value from Client 3524-WQDSG:  1
#
# Value from Client 8590-YFFQO:  1
#
# Value from Client 8659-IOOPU:  1
#
# Value from Client 1338-CECEE:  1
#
# Value from Client 4712-UYOOI:  1
#
# Value from Client 7363-QTBIW:  1
#
# Value from Client 4159-NAAIX:  1
#
# Value from Client 9397-TZSHA:  1
#
# Value from Client 1459-QNFQT:  1
#
# Value from Client 9330-DHBFL:  1
#
# Value from Client 0098-BOWSO:  1
#
# Value from Client 2208-NQBCT:  1
#
# Value from Client 0774-IFUVM:  1
#
# Value from Client 2446-ZKVAF:  1
#
# Value from Client 3522-CDKHF:  1
#
# Value from Client 4189-NAKJS:  1
#
# Value from Client 5562-BETPV:  1
#
# Value from Client 0887-WBJVH:  1
#
# Value from Client 3916-NRPAP:  1
#
# Value from Client 8967-SZQAS:  1
#
# Value from Client 8944-AILEF:  1
#
# Value from Client 5542-NKVRU:  1
#
# Value from Client 5370-IIVVL:  1
#
# Value from Client 6789-HJBWG:  1
#
# Value from Client 6791-YBNAK:  1
#
# Value from Client 0013-MHZWF:  1
#
# Value from Client 4291-SHSBH:  1
#
# Value from Client 6980-IMXXE:  1
#
# Value from Client 0784-GTUUK:  1
#
# Value from Client 2294-DMMUS:  1
#
# Value from Client 3055-MJDSB:  1
#
# Value from Client 9068-VPWQQ:  1
#
# Value from Client 0319-QZTCO:  1
#
# Value from Client 0668-OGMHD:  1
#
# Value from Client 9992-UJOEL:  1
#
# Value from Client 6625-UTXEW:  1
#
# Value from Client 8780-IHCRN:  1
#
# Value from Client 1257-SXUXQ:  1
#
# Value from Client 5095-ETBRJ:  1
#
# Value from Client 4821-WQOYN:  1
#
# Value from Client 4389-UEFCZ:  1
#
# Value from Client 9968-FFVVH:  1
#
# Value from Client 3022-BEXHZ:  1
#
# Value from Client 9795-SHUHB:  1
#
# Value from Client 9277-JOOMO:  1
#
# Value from Client 0114-RSRRW:  1
#
# Value from Client 3910-MRQOY:  1
#
# Value from Client 7537-RBWEA:  1
#
# Value from Client 3733-LSYCE:  1
#
# Value from Client 7690-KPNCU:  1
#
# Value from Client 0536-BGFMZ:  1
#
# Value from Client 2625-TRCZQ:  1
#
# Value from Client 7130-YXBRO:  1
#
# Value from Client 9272-LSVYH:  1
#
# Value from Client 8039-ACLPL:  1
#
# Value from Client 1934-MKPXS:  1
#
# Value from Client 8714-CTZJW:  1
#
# Value from Client 5678-VFNEQ:  1
#
# Value from Client 5302-BDJNT:  1
#
# Value from Client 8785-CJSHH:  1
#
# Value from Client 6510-UPNKS:  1
#
# Value from Client 7677-SJJJK:  1
#
# Value from Client 5514-YQENT:  1
#
# Value from Client 3211-AAPKX:  1
#
# Value from Client 8445-DNBAE:  1
#
# Value from Client 8681-ICONS:  1
#
# Value from Client 1866-OBPNR:  1
#
# Value from Client 8605-ITULD:  1
#
# Value from Client 6416-YJTTB:  1
#
# Value from Client 3195-TQDZX:  1
#
# Value from Client 3128-YOVTD:  1
#
# Value from Client 5724-BIDBU:  1
#
# Value from Client 1769-GRUIK:  1
#
# Value from Client 7427-AUFPY:  1
#
# Value from Client 7898-PDWQE:  1
#
# Value from Client 2924-KHUVI:  1
#
# Value from Client 6184-DYUOB:  1
#
# Value from Client 0640-YJTPY:  1
#
# Value from Client 7876-DNYAP:  1
#
# Value from Client 5522-NYKPB:  1
#
# Value from Client 0799-DDIHE:  1
#
# Value from Client 5014-WUQMG:  1
#
# Value from Client 2720-FVBQP:  1
#
# Value from Client 8246-SHFGA:  1
#
# Value from Client 5816-JMLGY:  1
#
# Value from Client 3584-WKTTW:  1
#
# Value from Client 5035-BVCXS:  1
#
# Value from Client 1371-OJCEK:  1
#
# Value from Client 2351-RRBUE:  1
#
# Value from Client 2851-MMUTZ:  1
#
# Value from Client 2967-MXRAV:  1
#
# Value from Client 4163-KIUHY:  1
#
# Value from Client 1171-TYKUR:  1
#
# Value from Client 9659-QEQSY:  1
#
# Value from Client 5405-ZMYXQ:  1
#
# Value from Client 0793-TWELN:  1
#
# Value from Client 0274-JKUJR:  1
#
# Value from Client 1696-MZVAU:  1
#
# Value from Client 6961-MJKBO:  1
#
# Value from Client 8158-WPEZG:  1
#
# Value from Client 6435-SRWBJ:  1
#
# Value from Client 9964-WBQDJ:  1
#
# Value from Client 6303-KFWSL:  1
#
# Value from Client 0404-AHASP:  1
#
# Value from Client 0106-GHRQR:  1
#
# Value from Client 3768-VHXQO:  1
#
# Value from Client 3963-RYFNS:  1
#
# Value from Client 2243-FNMMI:  1
#
# Value from Client 4193-IBKSW:  1
#
# Value from Client 5377-NDTOU:  1
#
# Value from Client 2474-LCNUE:  1
#
# Value from Client 2178-PMGCJ:  1
#
# Value from Client 7492-TAFJD:  1
#
# Value from Client 7860-KSUGX:  1
#
# Value from Client 0817-HSUSE:  1
#
# Value from Client 7554-AKDQF:  1
#
# Value from Client 0794-YVSGE:  1
#
# Value from Client 1839-UMACK:  1
#
# Value from Client 8356-WUAOJ:  1
#
# Value from Client 9350-ZXYJC:  1
#
# Value from Client 8958-JPTRR:  1
#
# Value from Client 3173-WSSUE:  1
#
# Value from Client 1098-KFQEC:  1
#
# Value from Client 9359-JANWS:  1
#
# Value from Client 3279-DYZQM:  1
#
# Value from Client 3946-JEWRQ:  1
#
# Value from Client 0463-WZZKO:  1
#
# Value from Client 5832-EXGTT:  1
#
# Value from Client 0754-EEBDC:  1
#
# Value from Client 8232-UTFOZ:  1
#
# Value from Client 6637-KYRCV:  1
#
# Value from Client 5356-CSVSQ:  1
#
# Value from Client 2801-NISEI:  1
#
# Value from Client 7696-CFTAT:  1
#
# Value from Client 2018-QKYGT:  1
#
# Value from Client 2792-VPPET:  1
#
# Value from Client 7409-JURKQ:  1
#
# Value from Client 3247-MHJKM:  1
#
# Value from Client 0854-UYHZD:  1
#
# Value from Client 7243-LCGGZ:  1
#
# Value from Client 8735-IJJEG:  1
#
# Value from Client 0564-MUUQK:  1
#
# Value from Client 5619-PTMIK:  1
#
# Value from Client 5846-QFDFI:  1
#
# Value from Client 4445-KWOKW:  1
#
# Value from Client 3511-APPBJ:  1
#
# Value from Client 7967-HYCDE:  1
#
# Value from Client 5447-WZAFP:  1
#
# Value from Client 7892-QVYKW:  1
#
# Value from Client 9675-ICXCT:  1
#
# Value from Client 0602-DDUML:  1
#
# Value from Client 9993-LHIEB:  1
#
# Value from Client 2546-KZAAT:  1
#
# Value from Client 9720-JJJOR:  1
#
# Value from Client 8100-HZZLJ:  1
#
# Value from Client 3546-GHEAE:  1
#
# Value from Client 2538-OIMXF:  1
#
# Value from Client 5346-BZCHP:  1
#
# Value from Client 5153-RTHKF:  1
#
# Value from Client 3061-BCKYI:  1
#
# Value from Client 7228-PAQPD:  1
#
# Value from Client 2911-WDXMV:  1
#
# Value from Client 4547-FZJWE:  1
#
# Value from Client 0842-IWYCP:  1
#
# Value from Client 7607-QKKTJ:  1
#
# Value from Client 0673-IGUQO:  1
#
# Value from Client 4123-FCVCB:  1
#
# Value from Client 8311-UEUAB:  1
#
# Value from Client 4010-YLMVT:  1
#
# Value from Client 6288-CHQJB:  1
#
# Value from Client 1391-UBDAR:  1
#
# Value from Client 1345-GKDZZ:  1
#
# Value from Client 0248-IPDFW:  1
#
# Value from Client 7978-DKUQH:  1
#
# Value from Client 7101-HRBLJ:  1
#
# Value from Client 6635-CPNUN:  1
#
# Value from Client 3995-WFCSM:  1
#
# Value from Client 4195-PNGZS:  1
#
# Value from Client 9891-NQDBD:  1
#
# Value from Client 8548-AWOFC:  1
#
# Value from Client 6296-DDOOR:  1
#
# Value from Client 7951-VRDVK:  1
#
# Value from Client 4815-YOSUK:  1
#
# Value from Client 3298-QEICA:  1
#
# Value from Client 5242-UOWHD:  1
#
# Value from Client 6479-SZPLM:  1
#
# Value from Client 9917-KWRBE:  1
#
# Value from Client 2212-LYASK:  1
#
# Value from Client 4957-TIALW:  1
#
# Value from Client 3126-WQMGH:  1
#
# Value from Client 9239-GZHZE:  1
#
# Value from Client 8963-JLGJT:  1
#
# Value from Client 7401-JIXNM:  1
#
# Value from Client 4947-DSMXK:  1
#
# Value from Client 3324-OIRTO:  1
#
# Value from Client 8499-BRXTD:  1
#
# Value from Client 9154-QDGTH:  1
#
# Value from Client 9367-OIUXP:  1
#
# Value from Client 6770-UAYGJ:  1
#
# Value from Client 2266-SJNAT:  1
#
# Value from Client 3113-IWHLC:  1
#
# Value from Client 1552-AAGRX:  1
#
# Value from Client 2683-JXWQQ:  1
#
# Value from Client 8739-XNIKG:  1
#
# Value from Client 3981-QSVQI:  1
#
# Value from Client 9251-WNSOD:  1
#
# Value from Client 7989-AWGEH:  1
#
# Value from Client 6993-YGFJV:  1
#
# Value from Client 9314-QDMDW:  1
#
# Value from Client 7649-PHJVR:  1
#
# Value from Client 3787-TRIAL:  1
#
# Value from Client 1226-JZNKR:  1
#
# Value from Client 7176-WIONM:  1
#
# Value from Client 5197-PYEPU:  1
#
# Value from Client 6619-RPLQZ:  1
#
# Value from Client 6901-GOGZG:  1
#
# Value from Client 9621-OUPYD:  1
#
# Value from Client 8982-NHAVY:  1
#
# Value from Client 3893-JRNFS:  1
#
# Value from Client 2171-UDMFD:  1
#
# Value from Client 9802-CAQUT:  1
#
# Value from Client 1357-MVDOZ:  1
#
# Value from Client 5968-HYJRZ:  1
#
# Value from Client 7140-ADSMJ:  1
#
# Value from Client 2230-XTUWL:  1
#
# Value from Client 7641-TQFHN:  1
#
# Value from Client 0679-TDGAK:  1
#
# Value from Client 6585-WCEWR:  1
#
# Value from Client 9668-PUGNU:  1
#
# Value from Client 9565-AXSMR:  1
#
# Value from Client 0784-ZQJZX:  1
#
# Value from Client 3133-PZNSR:  1
#
# Value from Client 4826-DXMUP:  1
#
# Value from Client 7175-NTIXE:  1
#
# Value from Client 2882-DDZPG:  1
#
# Value from Client 3547-LQRIK:  1
#
# Value from Client 5380-XPJNZ:  1
#
# Value from Client 2266-FUBDZ:  1
#
# Value from Client 8237-ULIXL:  1
#
# Value from Client 1051-EQPZR:  1
#
# Value from Client 5849-ASHZJ:  1
#
# Value from Client 3096-YXENJ:  1
#
# Value from Client 6384-VMJHP:  1
#
# Value from Client 1790-NESIO:  1
#
# Value from Client 1550-EENBN:  1
#
# Value from Client 7799-DSEWS:  1
#
# Value from Client 8766-PAFNE:  1
#
# Value from Client 9953-ZMKSM:  1
#
# Value from Client 7665-NKLAV:  1
#
# Value from Client 4727-MCYZG:  1
#
# Value from Client 5639-NTUPK:  1
#
# Value from Client 6242-SGYTS:  1
#
# Value from Client 4531-AUZNK:  1
#
# Value from Client 4191-XOVOM:  1
#
# Value from Client 1872-EBWSC:  1
#
# Value from Client 5213-TWWJU:  1
#
# Value from Client 5472-CVMDX:  1
#
# Value from Client 8150-QUDFX:  1
#
# Value from Client 1697-LYYYX:  1
#
# Value from Client 9640-ZSLDC:  1
#
# Value from Client 5996-DAOQL:  1
#
# Value from Client 6838-YAUVY:  1
#
# Value from Client 0484-JPBRU:  1
#
# Value from Client 7274-CGTOD:  1
#
# Value from Client 4636-TVXVG:  1
#
# Value from Client 3518-PZXZQ:  1
#
# Value from Client 9086-YJYXS:  1
#
# Value from Client 7909-FIOIY:  1
#
# Value from Client 1194-SPVSP:  1
#
# Value from Client 9534-NSXEM:  1
#
# Value from Client 8929-KSWIH:  1
#
# Value from Client 3572-UOLYZ:  1
#
# Value from Client 2770-NSVDG:  1
#
# Value from Client 4860-YZGZM:  1
#
# Value from Client 7037-MTYVW:  1
#
# Value from Client 4016-BJKTZ:  1
#
# Value from Client 6584-VQMYT:  1
#
# Value from Client 2790-XUYMV:  1
#
# Value from Client 3904-UKFRE:  1
#
# Value from Client 6484-LATFU:  1
#
# Value from Client 1699-UOTXU:  1
#
# Value from Client 5993-JSUWV:  1
#
# Value from Client 3097-FQTVJ:  1
#
# Value from Client 7299-GNVPL:  1
#
# Value from Client 9743-DQKQW:  1
#
# Value from Client 1215-VFYVK:  1
#
# Value from Client 9371-BITHB:  1
#
# Value from Client 6838-HVLXG:  1
#
# Value from Client 0233-FTHAV:  1
#
# Value from Client 9512-PHSMG:  1
#
# Value from Client 7244-KXYZN:  1
#
# Value from Client 8347-GDTMP:  1
#
# Value from Client 2187-PKZAY:  1
#
# Value from Client 9830-ECLEN:  1
#
# Value from Client 6505-OZNPG:  1
#
# Value from Client 0953-LGOVU:  1
#
# Value from Client 1936-CZAKF:  1
#
# Value from Client 9453-PATOS:  1
#
# Value from Client 5322-ZSMZY:  1
#
# Value from Client 5312-IRCFR:  1
#
# Value from Client 4526-EXKKN:  1
#
# Value from Client 3345-JHUEO:  1
#
# Value from Client 2674-MIAHT:  1
#
# Value from Client 0258-NOKBL:  1
#
# Value from Client 1163-VIPRI:  1
#
# Value from Client 9443-JUBUO:  1
#
# Value from Client 0397-ZXWQF:  1
#
# Value from Client 6295-OSINB:  1
#
# Value from Client 2239-CFOUJ:  1
#
# Value from Client 4770-UEZOX:  1
#
# Value from Client 2160-GPFXD:  1
#
# Value from Client 1498-NHTLT:  1
#
# Value from Client 1402-PTHGN:  1
#
# Value from Client 0238-WHBIQ:  1
#
# Value from Client 8512-WIWYV:  1
#
# Value from Client 1406-PUQVY:  1
#
# Value from Client 9114-AAFQH:  1
#
# Value from Client 1728-BQDMA:  1
#
# Value from Client 5117-ZSMHQ:  1
#
# Value from Client 6465-GSRCL:  1
#
# Value from Client 1777-JYQPJ:  1
#
# Value from Client 5680-LQOGP:  1
#
# Value from Client 1898-JSNDC:  1
#
# Value from Client 6569-KTMDU:  1
#
# Value from Client 3148-AOIQT:  1
#
# Value from Client 3181-VTHOE:  1
#
# Value from Client 4567-AKPIA:  1
#
# Value from Client 7901-HXJVA:  1
#
# Value from Client 7968-QUXNS:  1
#
# Value from Client 2452-SNHFZ:  1
#
# Value from Client 3629-WEAAM:  1
#
# Value from Client 2253-KPMNB:  1
#
# Value from Client 1345-ZUKID:  1
#
# Value from Client 2603-HVKCG:  1
#
# Value from Client 5148-ORICT:  1
#
# Value from Client 4893-GYUJU:  1
#
# Value from Client 7682-AZNDK:  1
#
# Value from Client 5501-TVMGM:  1
#
# Value from Client 3810-DVDQQ:  1
#
# Value from Client 8205-VSLRB:  1
#
# Value from Client 3890-RTCMS:  1
#
# Value from Client 3717-FDJFU:  1
#
# Value from Client 3665-JATSN:  1
#
# Value from Client 7966-YOTQW:  1
#
# Value from Client 7711-YIJWC:  1
#
# Value from Client 8902-ZEOVF:  1
#
# Value from Client 1085-LDWAM:  1
#
# Value from Client 9143-CANJF:  1
#
# Value from Client 9194-GFVOI:  1
#
# Value from Client 1403-LKLIK:  1
#
# Value from Client 9122-UMROB:  1
#
# Value from Client 4232-JGKIY:  1
#
# Value from Client 4203-QGNZA:  1
#
# Value from Client 1640-PLFMP:  1
#
# Value from Client 4616-EWBNJ:  1
#
# Value from Client 8871-JLMHM:  1
#
# Value from Client 3474-BAFSJ:  1
#
# Value from Client 3865-ZFZIB:  1
#
# Value from Client 1855-AGAWH:  1
#
# Value from Client 2696-RZVZW:  1
#
# Value from Client 1474-JUWSM:  1
#
# Value from Client 0621-TSSMU:  1
#
# Value from Client 7234-KMNRQ:  1
#
# Value from Client 9052-DHNKM:  1
#
# Value from Client 5578-NKCXI:  1
#
# Value from Client 5950-AAAGJ:  1
#
# Value from Client 6447-EGDIV:  1
#
# Value from Client 3272-VUHPV:  1
#
# Value from Client 6719-FGEDO:  1
#
# Value from Client 1877-HKBQX:  1
#
# Value from Client 0428-AXXLJ:  1
#
# Value from Client 0326-VDYXE:  1
#
# Value from Client 0436-TWFFZ:  1
#
# Value from Client 9576-SYUHJ:  1
#
# Value from Client 7339-POGZN:  1
#
# Value from Client 9257-AZMTZ:  1
#
# Value from Client 4682-BLBUC:  1
#
# Value from Client 2916-BQZLN:  1
#
# Value from Client 4558-CGYCZ:  1
#
# Value from Client 2368-GAKKQ:  1
#
# Value from Client 3785-KTYSH:  1
#
# Value from Client 9028-LIHRP:  1
#
# Value from Client 6897-RWMUB:  1
#
# Value from Client 5171-EPLKN:  1
#
# Value from Client 2227-JRSJX:  1
#
# Value from Client 9847-HNVGP:  1
#
# Value from Client 6506-EYCNH:  1
#
# Value from Client 2560-QTSBS:  1
#
# Value from Client 7860-UXCRM:  1
#
# Value from Client 2292-XQWSV:  1
#
# Value from Client 9643-YBLUR:  1
#
# Value from Client 8734-FNWVH:  1
#
# Value from Client 2623-DRYAM:  1
#
# Value from Client 9987-LUTYD:  1
#
# Value from Client 4488-KQFDT:  1
#
# Value from Client 5693-PIPCS:  1
#
# Value from Client 0491-KAPQG:  1
#
# Value from Client 8039-EQPIM:  1
#
# Value from Client 3209-ZPKFI:  1
#
# Value from Client 3569-JFODW:  1
#
# Value from Client 0396-UKGAI:  1
#
# Value from Client 5186-EJEGL:  1
#
# Value from Client 2203-GHNWN:  1
#
# Value from Client 9419-IPPBE:  1
#
# Value from Client 0174-QRVVY:  1
#
# Value from Client 2259-OUUSZ:  1
#
# Value from Client 4633-MKHYU:  1
#
# Value from Client 1353-GHZOS:  1
#
# Value from Client 6473-ULUHT:  1
#
# Value from Client 7688-AWMDX:  1
#
# Value from Client 7244-QWYHG:  1
#
# Value from Client 2150-WLKUW:  1
#
# Value from Client 7159-FVYPK:  1
#
# Value from Client 4821-SJHJV:  1
#
# Value from Client 2103-ZRXFN:  1
#
# Value from Client 6352-GIGGQ:  1
#
# Value from Client 3635-QQRQD:  1
#
# Value from Client 2926-JEJJC:  1
#
# Value from Client 9822-WMWVG:  1
#
# Value from Client 1548-ARAGG:  1
#
# Value from Client 0412-UCCNP:  1
#
# Value from Client 8617-ENBDS:  1
#
# Value from Client 3537-HPKQT:  1
#
# Value from Client 4742-TXUEX:  1
#
# Value from Client 9631-XEYKE:  1
#
# Value from Client 1335-MXCSE:  1
#
# Value from Client 2386-OWURY:  1
#
# Value from Client 7973-DZRKH:  1
#
# Value from Client 9602-WCXPI:  1
#
# Value from Client 8573-JGCZW:  1
#
# Value from Client 9504-YAZWB:  1
#
# Value from Client 9065-ZCPQX:  1
#
# Value from Client 3213-VVOLG:  1
#
# Value from Client 6870-ECSHE:  1
#
# Value from Client 8747-UDCOI:  1
#
# Value from Client 9169-BSVIN:  1
#
# Value from Client 6872-HXFNF:  1
#
# Value from Client 1194-HVAIF:  1
#
# Value from Client 9862-KJTYK:  1
#
# Value from Client 4922-CVPDX:  1
#
# Value from Client 7340-KEFQE:  1
#
# Value from Client 7392-YYPYJ:  1
#
# Value from Client 2176-OSJUV:  1
#
# Value from Client 9348-YVOMK:  1
#
# Value from Client 4521-YEEHE:  1
#
# Value from Client 3824-RHKVR:  1
#
# Value from Client 5989-AXPUC:  1
#
# Value from Client 1755-FZQEC:  1
#
# Value from Client 7964-YESJC:  1
#
# Value from Client 9702-AIUJO:  1
#
# Value from Client 8851-RAGOV:  1
#
# Value from Client 4797-MIWUM:  1
#
# Value from Client 4495-LHSSK:  1
#
# Value from Client 9861-PDSZP:  1
#
# Value from Client 7404-JLKQG:  1
#
# Value from Client 8915-NNTRC:  1
#
# Value from Client 2541-YGPKE:  1
#
# Value from Client 6194-HBGQN:  1
#
# Value from Client 7634-WSWDB:  1
#
# Value from Client 6023-GSSXW:  1
#
# Value from Client 4006-HKYHO:  1
#
# Value from Client 3727-JEZTU:  1
#
# Value from Client 8143-ETQTI:  1
#
# Value from Client 4256-ZWTZI:  1
#
# Value from Client 4054-CUMIA:  1
#
# Value from Client 6762-QVYJO:  1
#
# Value from Client 8152-VETUR:  1
#
# Value from Client 0757-WCUUZ:  1
#
# Value from Client 1629-DQQVB:  1
#
# Value from Client 4872-VXRIL:  1
#
# Value from Client 5606-AMZBO:  1
#
# Value from Client 5640-CAXOA:  1
#
# Value from Client 2235-EZAIK:  1
#
# Value from Client 3847-BAERP:  1
#
# Value from Client 2476-YGEFM:  1
#
# Value from Client 6624-JDRDS:  1
#
# Value from Client 5214-NLTIT:  1
#
# Value from Client 3345-PBBFH:  1
#
# Value from Client 2190-PHBHR:  1
#
# Value from Client 2650-GYRYL:  1
#
# Value from Client 7184-LRUUR:  1
#
# Value from Client 4632-XJMEX:  1
#
# Value from Client 8670-MEFCP:  1
#
# Value from Client 3079-BCHLN:  1
#
# Value from Client 2969-VAPYH:  1
#
# Value from Client 5049-MUBWG:  1
#
# Value from Client 1194-BHJYC:  1
#
# Value from Client 0906-QVPMS:  1
#
# Value from Client 8620-RJPZN:  1
#
# Value from Client 2642-MAWLJ:  1
#
# Value from Client 2428-ZMCTB:  1
#
# Value from Client 6963-KQYQB:  1
#
# Value from Client 3146-JTQHR:  1
#
# Value from Client 0017-IUDMW:  1
#
# Value from Client 8706-HRADD:  1
#
# Value from Client 9955-QOPOY:  1
#
# Value from Client 9031-ZVQPT:  1
#
# Value from Client 9027-YFHQJ:  1
#
# Value from Client 5345-BMKWB:  1
#
# Value from Client 0565-JUPYD:  1
#
# Value from Client 9732-EQMWY:  1
#
# Value from Client 2121-JAFOM:  1
#
# Value from Client 2167-FQSTQ:  1
#
# Value from Client 2692-PFYTJ:  1
#
# Value from Client 6821-JPCDC:  1
#
# Value from Client 9135-HSWOC:  1
#
# Value from Client 5811-IWXYM:  1
#
# Value from Client 1506-YJTYT:  1
#
# Value from Client 6288-LBEAR:  1
#
# Value from Client 6873-UDNLD:  1
#
# Value from Client 0958-YHXGP:  1
#
# Value from Client 4194-FJARJ:  1
#
# Value from Client 4302-ZYFEL:  1
#
# Value from Client 1518-OMDIK:  1
#
# Value from Client 0595-ITUDF:  1
#
# Value from Client 7998-ZLXWN:  1
#
# Value from Client 5018-GWURO:  1
#
# Value from Client 4781-ZXYGU:  1
#
# Value from Client 9896-UYMIE:  1
#
# Value from Client 0853-NWIFK:  1
#
# Value from Client 8212-CRQXP:  1
#
# Value from Client 2520-SGTTA:  1
#
# Value from Client 5868-YTYKS:  1
#
# Value from Client 0377-JBKKT:  1
#
# Value from Client 5215-LNLDJ:  1
#
# Value from Client 0257-KXZGU:  1
#
# Value from Client 1307-ATKGB:  1
#
# Value from Client 2824-DXNKN:  1
#
# Value from Client 6217-TOWGS:  1
#
# Value from Client 1544-JJMYL:  1
#
# Value from Client 4636-JGAAI:  1
#
# Value from Client 5951-AOFIH:  1
#
# Value from Client 3891-NLXJB:  1
#
# Value from Client 0577-WHMEV:  1
#
# Value from Client 3716-LRGXK:  1
#
# Value from Client 7821-DPRQE:  1
#
# Value from Client 2001-EWBQU:  1
#
# Value from Client 8410-BGQXN:  1
#
# Value from Client 8242-JSVBO:  1
#
# Value from Client 9541-ZPSEA:  1
#
# Value from Client 7975-JMZNT:  1
#
# Value from Client 3120-FAZKD:  1
#
# Value from Client 5006-MXVRN:  1
#
# Value from Client 3530-VWVGU:  1
#
# Value from Client 3633-CDBUW:  1
#
# Value from Client 0103-CSITQ:  1
#
# Value from Client 6578-KRMAW:  1
#
# Value from Client 1945-XISKS:  1
#
# Value from Client 1100-DDVRV:  1
#
# Value from Client 7216-KAOID:  1
#
# Value from Client 5339-TJFEK:  1
#
# Value from Client 2252-ISRNH:  1
#
# Value from Client 1866-DIOQZ:  1
#
# Value from Client 0825-CPPQH:  1
#
# Value from Client 9084-OAYKL:  1
#
# Value from Client 2853-CWQFQ:  1
#
# Value from Client 3007-FDPEA:  1
#
# Value from Client 3680-CTHUH:  1
#
# Value from Client 1202-KKGFU:  1
#
# Value from Client 1852-XEMDW:  1
#
# Value from Client 9426-SXNHE:  1
#
# Value from Client 1269-FOYWN:  1
#
# Value from Client 9895-VFOXH:  1
#
# Value from Client 5701-ZIKJE:  1
#
# Value from Client 5032-MIYKT:  1
#
# Value from Client 5172-RKOCB:  1
#
# Value from Client 6743-HHQPF:  1
#
# Value from Client 6616-AALSR:  1
#
# Value from Client 1791-PQHBB:  1
#
# Value from Client 8741-LQOBK:  1
#
# Value from Client 8082-GHXOP:  1
#
# Value from Client 8218-FFJDS:  1
#
# Value from Client 0345-XMMUG:  1
#
# Value from Client 0463-TXOAK:  1
#
# Value from Client 7508-DQAKK:  1
#
# Value from Client 3556-BVQGL:  1
#
# Value from Client 3154-HMWUU:  1
#
# Value from Client 1052-QJIBV:  1
#
# Value from Client 9298-WGMRW:  1
#
# Value from Client 3088-LHEFH:  1
#
# Value from Client 6116-RFVHN:  1
#
# Value from Client 8884-FEEWR:  1
#
# Value from Client 3125-RAHBV:  1
#
# Value from Client 8224-KDLKN:  1
#
# Value from Client 1043-UXOVO:  1
#
# Value from Client 7402-PWYJJ:  1
#
# Value from Client 7501-VTYLJ:  1
#
# Value from Client 9814-AOUDH:  1
#
# Value from Client 2284-VFLKH:  1
#
# Value from Client 5734-EJKXG:  1
#
# Value from Client 9695-IDRZR:  1
#
# Value from Client 8631-WUXGY:  1
#
# Value from Client 5906-DVAPM:  1
#
# Value from Client 6654-QGBZZ:  1
#
# Value from Client 5641-DMBFJ:  1
#
# Value from Client 9200-NLNPD:  1
#
# Value from Client 4654-GGUII:  1
#
# Value from Client 0584-BJQGZ:  1
#
# Value from Client 0902-XKXPN:  1
#
# Value from Client 5177-RVZNU:  1
#
# Value from Client 1337-BOZWO:  1
#
# Value from Client 0899-LIIBW:  1
#
# Value from Client 2359-KLTEK:  1
#
# Value from Client 2673-ZALNP:  1
#
# Value from Client 9184-GALIL:  1
#
# Value from Client 4393-RYCRE:  1
#
# Value from Client 3162-ZJZFU:  1
#
# Value from Client 3521-MNKLV:  1
#
# Value from Client 8639-NHQEI:  1
#
# Value from Client 3720-DBRWL:  1
#
# Value from Client 4994-OBRSZ:  1
#
# Value from Client 7839-NUIAA:  1
#
# Value from Client 5966-EMAZU:  1
#
# Value from Client 8180-AKMJV:  1
#
# Value from Client 9975-SKRNR:  1
#
# Value from Client 3682-YEUWS:  1
#
# Value from Client 7088-FBAWU:  1
#
# Value from Client 2303-PJYHN:  1
#
# Value from Client 9795-VOWON:  1
#
# Value from Client 6527-PZFPV:  1
#
# Value from Client 9593-CVZKR:  1
#
# Value from Client 5236-XMZJY:  1
#
# Value from Client 4827-DPADN:  1
#
# Value from Client 5846-ABOBJ:  1
#
# Value from Client 0567-XRHCU:  1
#
# Value from Client 0052-DCKON:  1
#
# Value from Client 9367-TCUYN:  1
#
# Value from Client 0254-FNMCI:  1
#
# Value from Client 1848-LBZHY:  1
#
# Value from Client 4815-TUMEQ:  1
#
# Value from Client 4092-OFQZS:  1
#
# Value from Client 2821-WARNZ:  1
#
# Value from Client 2507-QZPQS:  1
#
# Value from Client 7074-STDCN:  1
#
# Value from Client 0363-SVHYR:  1
#
# Value from Client 6591-QGOYB:  1
#
# Value from Client 9070-BCKQP:  1
#
# Value from Client 8541-QVFKM:  1
#
# Value from Client 9258-CNWAC:  1
#
# Value from Client 6374-AFWOX:  1
#
# Value from Client 5317-FLPJF:  1
#
# Value from Client 4903-CNOZC:  1
#
# Value from Client 7267-FRMJW:  1
#
# Value from Client 7622-NXQZR:  1
#
# Value from Client 8092-NLTGF:  1
#
# Value from Client 4801-KFYKL:  1
#
# Value from Client 3472-OAOOR:  1
#
# Value from Client 2252-JHJGE:  1
#
# Value from Client 7813-TKCVO:  1
#
# Value from Client 3021-VLNRJ:  1
#
# Value from Client 5982-PSMKW:  1
#
# Value from Client 7096-ZNBZI:  1
#
# Value from Client 7245-JMTTQ:  1
#
# Value from Client 6202-JVYEU:  1
#
# Value from Client 6502-KUGLL:  1
#
# Value from Client 3511-BFTJW:  1
#
# Value from Client 4060-LDNLU:  1
#
# Value from Client 3589-PPVKW:  1
#
# Value from Client 3858-XHYJO:  1
#
# Value from Client 6261-LHRTG:  1
#
# Value from Client 7841-FCRQD:  1
#
# Value from Client 5115-GZDEL:  1
#
# Value from Client 2495-KZNFB:  1
#
# Value from Client 2027-DNKIV:  1
#
# Value from Client 0394-YONDK:  1
#
# Value from Client 9708-KFDBY:  1
#
# Value from Client 2242-MFOTG:  1
#
# Value from Client 1941-HOSAM:  1
#
# Value from Client 2535-PBCGC:  1
#
# Value from Client 1470-PSXNM:  1
#
# Value from Client 2498-XLDZR:  1
#
# Value from Client 8731-WBBMB:  1
#
# Value from Client 7901-IIDQV:  1
#
# Value from Client 2690-DVRVK:  1
#
# Value from Client 1270-XKUCC:  1
#
# Value from Client 5583-EJXRD:  1
#
# Value from Client 2580-ASVVY:  1
#
# Value from Client 4254-QPEDE:  1
#
# Value from Client 6283-GITPX:  1
#
# Value from Client 5375-XLDOF:  1
#
# Value from Client 6559-PDZLR:  1
#
# Value from Client 8992-OBVDG:  1
#
# Value from Client 4724-WXVWF:  1
#
# Value from Client 5701-GUXDC:  1
#
# Value from Client 9227-YBAXE:  1
#
# Value from Client 9860-LISIZ:  1
#
# Value from Client 5320-BRKGK:  1
#
# Value from Client 6229-UOLQL:  1
#
# Value from Client 8124-NZVGJ:  1
#
# Value from Client 5118-MUEYH:  1
#
# Value from Client 5057-RKGLH:  1
#
# Value from Client 8910-ICHIU:  1
#
# Value from Client 9715-WZCLW:  1
#
# Value from Client 9715-SBVSU:  1
#
# Value from Client 7929-SKFGK:  1
#
# Value from Client 4998-IKFSE:  1
#
# Value from Client 7879-CGSFV:  1
#
# Value from Client 7432-FFVAR:  1
#
# Value from Client 7109-MFBYV:  1
#
# Value from Client 1832-PEUTS:  1
#
# Value from Client 0580-PIQHM:  1
#
# Value from Client 9289-LBQVU:  1
#
# Value from Client 3458-IDMFK:  1
#
# Value from Client 0221-NAUXK:  1
#
# Value from Client 3002-WQZWT:  1
#
# Value from Client 3374-TTZTK:  1
#
# Value from Client 2676-OXPPQ:  1
#
# Value from Client 3703-TTEPD:  1
#
# Value from Client 2799-TSLAG:  1
#
# Value from Client 1757-TCATG:  1
#
# Value from Client 2892-GESUL:  1
#
# Value from Client 8034-RYTVV:  1
#
# Value from Client 5044-LRQAQ:  1
#
# Value from Client 1716-LSAMB:  1
#
# Value from Client 5919-VCZYM:  1
#
# Value from Client 8838-GPHZP:  1
#
# Value from Client 6918-UMQCG:  1
#
# Value from Client 6339-DKLMK:  1
#
# Value from Client 1492-KGETH:  1
#
# Value from Client 9432-VOFYX:  1
#
# Value from Client 3301-VKTGC:  1
#
# Value from Client 9115-YQHGA:  1
#
# Value from Client 8963-MQVYN:  1
#
# Value from Client 2458-EOMRE:  1
#
# Value from Client 1222-LRYKO:  1
#
# Value from Client 7502-BNYGS:  1
#
# Value from Client 5666-MBJPT:  1
#
# Value from Client 0674-GCDXG:  1
#
# Value from Client 4396-KLSEH:  1
#
# Value from Client 3566-CAAYU:  1
#
# Value from Client 4475-NVTLU:  1
#
# Value from Client 9386-LDCZR:  1
#
# Value from Client 9585-KKMFD:  1
#
# Value from Client 4537-DKTAL:  1
#
# Value from Client 8903-XEBGX:  1
#
# Value from Client 9648-BCHKM:  1
#
# Value from Client 8707-HOEDG:  1
#
# Value from Client 9251-AWQGT:  1
#
# Value from Client 7989-VCQOH:  1
#
# Value from Client 9730-DRTMJ:  1
#
# Value from Client 4686-UXDML:  1
#
# Value from Client 1116-FRYVH:  1
#
# Value from Client 3407-JMJQQ:  1
#
# Value from Client 8645-KOMJQ:  1
#
# Value from Client 9761-XUJWD:  1
#
# Value from Client 7401-RUBNK:  1
#
# Value from Client 0980-PVMRC:  1
#
# Value from Client 1555-HAPSU:  1
#
# Value from Client 2419-FSORS:  1
#
# Value from Client 8132-YPVBX:  1
#
# Value from Client 6754-LZUKA:  1
#
# Value from Client 9066-QRSDU:  1
#
# Value from Client 5321-NTRKC:  1
#
# Value from Client 9958-MEKUC:  1
#
# Value from Client 9114-VEPUF:  1
#
# Value from Client 8241-JUIQO:  1
#
# Value from Client 5093-FEGLU:  1
#
# Value from Client 2296-DKZFP:  1
#
# Value from Client 6603-YRDCJ:  1
#
# Value from Client 6131-JLWZM:  1
#
# Value from Client 0269-XFESX:  1
#
# Value from Client 8277-RVRSV:  1
#
# Value from Client 7054-ENNGU:  1
#
# Value from Client 9402-CXWPL:  1
#
# Value from Client 0856-NAOES:  1
#
# Value from Client 6156-UZDLF:  1
#
# Value from Client 9500-WBGRP:  1
#
# Value from Client 6625-IUTTT:  1
#
# Value from Client 0068-FIGTF:  1
#
# Value from Client 1840-BIUOG:  1
#
# Value from Client 9418-RUKPH:  1
#
# Value from Client 5816-QVHRX:  1
#
# Value from Client 4430-YHXGG:  1
#
# Value from Client 3585-YNADK:  1
#
# Value from Client 6828-HMKWP:  1
#
# Value from Client 5656-JAMLX:  1
#
# Value from Client 3462-BJQQA:  1
#
# Value from Client 9503-XJUME:  1
#
# Value from Client 5917-HBSDW:  1
#
# Value from Client 0956-ACVZC:  1
#
# Value from Client 2325-NBPZG:  1
#
# Value from Client 4482-FTFFX:  1
#
# Value from Client 8859-DZTGQ:  1
#
# Value from Client 9714-EDSUC:  1
#
# Value from Client 4079-ULGFR:  1
#
# Value from Client 2516-XSJKX:  1
#
# Value from Client 6599-SFQVE:  1
#
# Value from Client 4458-KVRBJ:  1
#
# Value from Client 6013-BHCAW:  1
#
# Value from Client 0401-WDBXM:  1
#
# Value from Client 3387-PLKUI:  1
#
# Value from Client 8085-MSNLK:  1
#
# Value from Client 9691-HKOVS:  1
#
# Value from Client 9881-VCZEP:  1
#
# Value from Client 0690-SRQID:  1
#
# Value from Client 9114-DPSIA:  1
#
# Value from Client 5438-QMDDL:  1
#
# Value from Client 1228-ZLNBX:  1
#
# Value from Client 7609-NRNCA:  1
#
# Value from Client 9638-JIQYA:  1
#
# Value from Client 3726-TBHQT:  1
#
# Value from Client 5010-IPEAQ:  1
#
# Value from Client 0725-CXOTM:  1
#
# Value from Client 4377-VDHYI:  1
#
# Value from Client 6981-TDRFT:  1
#
# Value from Client 8033-VCZGH:  1
#
# Value from Client 4718-WXBGI:  1
#
# Value from Client 5716-LIBJC:  1
#
# Value from Client 2988-QRAJY:  1
#
# Value from Client 7328-ZJAJO:  1
#
# Value from Client 1090-PYKCI:  1
#
# Value from Client 2279-AXJJK:  1
#
# Value from Client 3417-TSCIC:  1
#
# Value from Client 6725-TPKJO:  1
#
# Value from Client 1599-MMYRQ:  1
#
# Value from Client 6394-HHHZM:  1
#
# Value from Client 0665-XHDJU:  1
#
# Value from Client 6549-BTYPG:  1
#
# Value from Client 9374-YOLBJ:  1
#
# Value from Client 4636-OLWOE:  1
#
# Value from Client 7435-ZNUYY:  1
#
# Value from Client 2812-ENYMO:  1
#
# Value from Client 2717-HVIZY:  1
#
# Value from Client 3422-GALYP:  1
#
# Value from Client 2890-WFBHU:  1
#
# Value from Client 0186-CAERR:  1
#
# Value from Client 5872-OEQNH:  1
#
# Value from Client 8946-BFWSG:  1
#
# Value from Client 0547-HURJB:  1
#
# Value from Client 6603-QWSPR:  1
#
# Value from Client 1929-ZCBHE:  1
#
# Value from Client 4129-LYCOI:  1
#
# Value from Client 2081-KJSQF:  1
#
# Value from Client 3407-QGWLG:  1
#
# Value from Client 3214-IYUUQ:  1
#
# Value from Client 8778-LMWTJ:  1
#
# Value from Client 0848-SOMKO:  1
#
# Value from Client 1535-VTJOQ:  1
#
# Value from Client 1952-DVVSW:  1
#
# Value from Client 6656-GULJQ:  1
#
# Value from Client 9853-JFZDU:  1
#
# Value from Client 3258-ZKPAI:  1
#
# Value from Client 6728-CZFEI:  1
#
# Value from Client 2999-AANRQ:  1
#
# Value from Client 8221-EQDGL:  1
#
# Value from Client 2995-YWTCD:  1
#
# Value from Client 5084-OOVCJ:  1
#
# Value from Client 9529-OFXHY:  1
#
# Value from Client 2478-EEWWM:  1
#
# Value from Client 2233-TXSIU:  1
#
# Value from Client 9494-MRNYX:  1
#
# Value from Client 3985-HOYPM:  1
#
# Value from Client 6576-FBXOJ:  1
#
# Value from Client 4310-KEDTB:  1
#
# Value from Client 2676-ISHSF:  1
#
# Value from Client 4753-PADAS:  1
#
# Value from Client 7781-EWARA:  1
#
# Value from Client 1353-LJWEM:  1
#
# Value from Client 1794-SWWKL:  1
#
# Value from Client 9332-GYWLO:  1
#
# Value from Client 1635-HDGFT:  1
#
# Value from Client 8050-XGRVL:  1
#
# Value from Client 5012-YSPJJ:  1
#
# Value from Client 6728-VOIFY:  1
#
# Value from Client 2159-TURXX:  1
#
# Value from Client 3795-CAWEX:  1
#
# Value from Client 5647-URDKA:  1
#
# Value from Client 2229-DPMBI:  1
#
# Value from Client 3898-BSJYF:  1
#
# Value from Client 7696-AMHOD:  1
#
# Value from Client 6813-GZQCG:  1
#
# Value from Client 8317-BVKSO:  1
#
# Value from Client 0083-PIVIK:  1
#
# Value from Client 8690-UPCZI:  1
#
# Value from Client 8404-FYDIB:  1
#
# Value from Client 1074-WVEVG:  1
#
# Value from Client 9979-RGMZT:  1
#
# Value from Client 4747-LCAQL:  1
#
# Value from Client 8722-PRFDV:  1
#
# Value from Client 2832-KJCRD:  1
#
# Value from Client 4075-WKNIU:  1
#
# Value from Client 5274-XHAKY:  1
#
# Value from Client 8561-NMTBD:  1
#
# Value from Client 5161-XEUVX:  1
#
# Value from Client 8292-FRFZQ:  1
#
# Value from Client 7895-VONWT:  1
#
# Value from Client 8107-RZLNV:  1
#
# Value from Client 3733-ZEECP:  1
#
# Value from Client 4342-HFXWS:  1
#
# Value from Client 7315-WYOAW:  1
#
# Value from Client 5666-CYCYZ:  1
#
# Value from Client 6365-HITVU:  1
#
# Value from Client 4114-QMKVN:  1
#
# Value from Client 0970-QXPXW:  1
#
# Value from Client 9572-WUKSB:  1
#
# Value from Client 3640-JQGJG:  1
#
# Value from Client 3174-RKMOW:  1
#
# Value from Client 8725-JEDFD:  1
#
# Value from Client 6668-CNMFP:  1
#
# Value from Client 7009-LGECI:  1
#
# ...
#
# Value from Client 4644-OBGFZ:  1
#
# Value from Client 6480-YAGIY:  1
#
# Value from Client 0307-BCOPK:  1
#
# Value from Client 5016-LIPDW:  1
#
# Value from Client 6481-LXPWL:  1
#
# Value from Client 7919-ZODZZ:  1
#
# Value from Client 0565-JUPYD:  1
#
# Value from Client 5269-NRGDP:  1
#
# Value from Client 6195-MELTI:  1
#
# Value from Client 5198-HQAEN:  1
#
# Value from Client 2819-GWENI:  1
#
# Value from Client 3572-UUHRS:  1
#
# Value from Client 6821-JPCDC:  1
#
# Value from Client 5811-IWXYM:  1
#
# Value from Client 7596-LDUXP:  1
#
# Value from Client 1131-ALZWV:  1
#
# Value from Client 9134-WYRVP:  1
#
# Value from Client 9732-OUYRN:  1
#
# Value from Client 5808-TOTXO:  1
#
# Value from Client 4369-NYSCF:  1
#
# Value from Client 6333-YDVLT:  1
#
# Value from Client 5324-KTGCG:  1
#
# Value from Client 6992-TKNYO:  1
#
# Value from Client 4302-ZYFEL:  1
#
# Value from Client 6253-WRFHY:  1
#
# Value from Client 8680-CGLTP:  1
#
# Value from Client 8430-TWCBX:  1
#
# Value from Client 8200-KLNYW:  1
#
# Value from Client 3372-CDXFJ:  1
#
# Value from Client 7632-YUTXB:  1
#
# Value from Client 9896-UYMIE:  1
#
# Value from Client 0853-NWIFK:  1
#
# Value from Client 6980-CDGFC:  1
#
# Value from Client 1088-CNNKB:  1
#
# Value from Client 1930-BZLHI:  1
#
# Value from Client 8042-RNLKO:  1
#
# Value from Client 1544-JJMYL:  1
#
# Value from Client 6874-SGLHU:  1
#
# Value from Client 8652-YHIYU:  1
#
# Value from Client 3606-SBKRY:  1
#
# Value from Client 0667-NSRGI:  1
#
# Value from Client 6893-ODYYE:  1
#
# Value from Client 6937-GCDGQ:  1
#
# Value from Client 4116-IQRFR:  1
#
# Value from Client 8259-DZLIZ:  1
#
# Value from Client 0967-BMLBD:  1
#
# Value from Client 2830-LEWOA:  1
#
# Value from Client 8327-WKMIE:  1
#
# Value from Client 3633-CDBUW:  1
#
# Value from Client 0103-CSITQ:  1
#
# Value from Client 7305-ZWMAJ:  1
#
# Value from Client 7216-KAOID:  1
#
# Value from Client 5944-UGLLK:  1
#
# Value from Client 2252-ISRNH:  1
#
# Value from Client 1866-DIOQZ:  1
#
# Value from Client 8375-KVTHK:  1
#
# Value from Client 3709-OIJEA:  1
#
# Value from Client 1897-RCFUM:  1
#
# Value from Client 2432-TFSMK:  1
#
# Value from Client 1834-ABKHQ:  1
#
# Value from Client 2519-TWKFS:  1
#
# Value from Client 3680-CTHUH:  1
#
# Value from Client 1269-FOYWN:  1
#
# Value from Client 3178-CIFOT:  1
#
# Value from Client 4530-NDRKU:  1
#
# Value from Client 5985-TBABQ:  1
#
# Value from Client 0980-FEXWF:  1
#
# Value from Client 9509-MPYOD:  1
#
# Value from Client 0961-ZWLVI:  1
#
# Value from Client 5871-DGTXZ:  1
#
# Value from Client 7550-WIQVA:  1
#
# Value from Client 7544-ZVIKX:  1
#
# Value from Client 9356-AXGMP:  1
#
# Value from Client 3556-BVQGL:  1
#
# Value from Client 7581-EBBOU:  1
#
# Value from Client 5073-RZGBK:  1
#
# Value from Client 8748-HFWBO:  1
#
# Value from Client 0723-FDLAY:  1
#
# Value from Client 8884-FEEWR:  1
#
# Value from Client 3125-RAHBV:  1
#
# Value from Client 0373-AIVNJ:  1
#
# Value from Client 1682-VCOIO:  1
#
# Value from Client 3569-VLDHH:  1
#
# Value from Client 1064-FBXNK:  1
#
# Value from Client 2878-DHMIN:  1
#
# Value from Client 7762-ONLJY:  1
#
# Value from Client 5795-BKOYE:  1
#
# Value from Client 7402-PWYJJ:  1
#
# Value from Client 2284-VFLKH:  1
#
# Value from Client 3807-BPOMJ:  1
#
# Value from Client 5734-EJKXG:  1
#
# Value from Client 6729-FZWSY:  1
#
# Value from Client 5906-DVAPM:  1
#
# Value from Client 9200-NLNPD:  1
#
# Value from Client 4654-GGUII:  1
#
# Value from Client 6478-HRRCZ:  1
#
# Value from Client 8510-BBWMU:  1
#
# Value from Client 1360-XFJMR:  1
#
# Value from Client 5177-RVZNU:  1
#
# Value from Client 8190-ZTQFB:  1
#
# Value from Client 0931-MHTEM:  1
#
# Value from Client 0440-UEDAI:  1
#
# Value from Client 1337-BOZWO:  1
#
# Value from Client 3950-VPYJB:  1
#
# Value from Client 9475-NNDGC:  1
#
# Value from Client 5825-XJOCM:  1
#
# Value from Client 6848-YLDFR:  1
#
# Value from Client 4973-RLZVI:  1
#
# Value from Client 2673-ZALNP:  1
#
# Value from Client 4393-RYCRE:  1
#
# Value from Client 9746-MDMBK:  1
#
# Value from Client 5966-EMAZU:  1
#
# Value from Client 5566-SOEZD:  1
#
# Value from Client 0930-EHUZA:  1
#
# Value from Client 9795-VOWON:  1
#
# Value from Client 6527-PZFPV:  1
#
# Value from Client 1439-LCGVL:  1
#
# Value from Client 0052-DCKON:  1
#
# Value from Client 2073-QBVBI:  1
#
# Value from Client 6617-WLBQC:  1
#
# Value from Client 1401-FTHFQ:  1
#
# Value from Client 4815-TUMEQ:  1
#
# Value from Client 4092-OFQZS:  1
#
# Value from Client 1561-BWHIN:  1
#
# Value from Client 6094-ZIVKX:  1
#
# Value from Client 8050-WYBND:  1
#
# Value from Client 2821-WARNZ:  1
#
# Value from Client 9402-ROUMJ:  1
#
# Value from Client 8779-YIQQA:  1
#
# Value from Client 8966-OIQHG:  1
#
# Value from Client 6266-QHOJZ:  1
#
# Value from Client 7269-JISCY:  1
#
# Value from Client 6421-SZVEM:  1
#
# Value from Client 4903-CNOZC:  1
#
# Value from Client 3850-OKINF:  1
#
# Value from Client 6408-OTUBZ:  1
#
# Value from Client 5204-HMGYF:  1
#
# Value from Client 3727-OVPRY:  1
#
# Value from Client 8294-UIMBA:  1
#
# Value from Client 8109-YUOHE:  1
#
# Value from Client 2252-JHJGE:  1
#
# Value from Client 7105-BENQF:  1
#
# Value from Client 7813-TKCVO:  1
#
# Value from Client 4350-ZTLPI:  1
#
# Value from Client 3823-KYNQY:  1
#
# Value from Client 3021-VLNRJ:  1
#
# Value from Client 7245-JMTTQ:  1
#
# Value from Client 6050-IJRHS:  1
#
# Value from Client 6202-JVYEU:  1
#
# Value from Client 2923-ARZLG:  1
#
# Value from Client 2282-YGNOR:  1
#
# Value from Client 5376-PCKNB:  1
#
# Value from Client 3858-XHYJO:  1
#
# Value from Client 7025-IWFHT:  1
#
# Value from Client 7841-FCRQD:  1
#
# Value from Client 2056-EVGZL:  1
#
# Value from Client 7753-USQYQ:  1
#
# Value from Client 7661-CPURM:  1
#
# Value from Client 4560-WQAQW:  1
#
# Value from Client 4274-DRSQT:  1
#
# Value from Client 2027-DNKIV:  1
#
# Value from Client 2725-IWWBA:  1
#
# Value from Client 6574-MCOEH:  1
#
# Value from Client 3642-GKTCT:  1
#
# Value from Client 1334-PDUKM:  1
#
# Value from Client 0756-MPZRL:  1
#
# Value from Client 2242-MFOTG:  1
#
# Value from Client 8745-PVESG:  1
#
# Value from Client 1470-PSXNM:  1
#
# Value from Client 7718-UPSKJ:  1
#
# Value from Client 1448-CYWKC:  1
#
# Value from Client 7901-IIDQV:  1
#
# Value from Client 2690-DVRVK:  1
#
# Value from Client 0334-ZFJSR:  1
#
# Value from Client 4565-EVZMJ:  1
#
# Value from Client 3327-YBAKM:  1
#
# Value from Client 5032-USPKF:  1
#
# Value from Client 9495-REDIY:  1
#
# Value from Client 5701-GUXDC:  1
#
# Value from Client 2495-TTHBQ:  1
#
# Value from Client 9229-RQABD:  1
#
# Value from Client 6284-KMNUF:  1
#
# Value from Client 6229-UOLQL:  1
#
# Value from Client 8124-NZVGJ:  1
#
# Value from Client 5627-TVBPP:  1
#
# Value from Client 2589-AYCRP:  1
#
# Value from Client 8910-ICHIU:  1
#
# Value from Client 4097-YODCF:  1
#
# Value from Client 8961-QDZZJ:  1
#
# Value from Client 5995-WWKKG:  1
#
# Value from Client 7879-CGSFV:  1
#
# Value from Client 7432-FFVAR:  1
#
# Value from Client 0580-PIQHM:  1
#
# Value from Client 1696-HXOWK:  1
#
# Value from Client 3026-ATZYV:  1
#
# Value from Client 9289-LBQVU:  1
#
# Value from Client 6933-FHBZC:  1
#
# Value from Client 0221-NAUXK:  1
#
# Value from Client 9770-KXGQU:  1
#
# Value from Client 5519-TEEUH:  1
#
# Value from Client 1757-TCATG:  1
#
# Value from Client 4776-XSKYQ:  1
#
# Value from Client 5753-QQWPW:  1
#
# Value from Client 8034-RYTVV:  1
#
# Value from Client 1333-PBMXB:  1
#
# Value from Client 6546-OPBBH:  1
#
# Value from Client 9127-QRZMH:  1
#
# Value from Client 9644-KVCNC:  1
#
# Value from Client 2137-DQMEV:  1
#
# Value from Client 4632-PAOYU:  1
#
# Value from Client 6072-NUQCB:  1
#
# Value from Client 9107-UKCKY:  1
#
# Value from Client 1492-KGETH:  1
#
# Value from Client 4163-HFTUK:  1
#
# Value from Client 8859-YSTWS:  1
#
# Value from Client 1998-VHJHK:  1
#
# Value from Client 4508-OEBEY:  1
#
# Value from Client 6051-PTVNS:  1
#
# Value from Client 2877-VDUER:  1
#
# Value from Client 6586-PSJOX:  1
#
# Value from Client 9705-ZJBCG:  1
#
# Value from Client 9670-BPNXF:  1
#
# Value from Client 3301-VKTGC:  1
#
# Value from Client 4423-JWZJN:  1
#
# Value from Client 7452-FOLON:  1
#
# Value from Client 2320-TZRRH:  1
#
# Value from Client 4942-VZZOM:  1
#
# Value from Client 6047-SUHPR:  1
#
# Value from Client 1121-QSIVB:  1
#
# Value from Client 8318-LCNBW:  1
#
# Value from Client 5915-DGNVC:  1
#
# Value from Client 6260-XLACS:  1
#
# Value from Client 2896-TBNBE:  1
#
# Value from Client 9386-LDCZR:  1
#
# Value from Client 5619-XZZKR:  1
#
# Value from Client 0983-TATYJ:  1
#
# Value from Client 5602-BVFMK:  1
#
# Value from Client 2325-WINES:  1
#
# Value from Client 9730-DRTMJ:  1
#
# Value from Client 5847-MXBEO:  1
#
# Value from Client 1183-CANVH:  1
#
# Value from Client 8679-LZBMD:  1
#
# Value from Client 6252-DFGTK:  1
#
# Value from Client 1722-LDZJS:  1
#
# Value from Client 1752-OZXFY:  1
#
# Value from Client 9066-QRSDU:  1
#
# Value from Client 6933-VLYFX:  1
#
# Value from Client 6754-WKSHP:  1
#
# Value from Client 2862-JVEOY:  1
#
# Value from Client 1534-OULXE:  1
#
# Value from Client 9391-YZEJW:  1
#
# Value from Client 9114-VEPUF:  1
#
# Value from Client 8241-JUIQO:  1
#
# Value from Client 3410-MHHUM:  1
#
# Value from Client 8909-BOLNL:  1
#
# Value from Client 3229-USWAR:  1
#
# Value from Client 0269-XFESX:  1
#
# Value from Client 8277-RVRSV:  1
#
# Value from Client 9402-CXWPL:  1
#
# Value from Client 5343-SGUBI:  1
#
# Value from Client 6156-UZDLF:  1
#
# Value from Client 0068-FIGTF:  1
#
# Value from Client 1840-BIUOG:  1
#
# Value from Client 9711-FJTBX:  1
#
# Value from Client 7163-OCEQI:  1
#
# Value from Client 5975-BAICR:  1
#
# Value from Client 7049-GKVZY:  1
#
# Value from Client 3721-CNZHX:  1
#
# Value from Client 3585-YNADK:  1
#
# Value from Client 9503-XJUME:  1
#
# Value from Client 6736-DHUQI:  1
#
# Value from Client 2724-FJDYW:  1
#
# Value from Client 4451-RWASJ:  1
#
# Value from Client 0956-ACVZC:  1
#
# Value from Client 0440-MOGPM:  1
#
# Value from Client 0020-JDNXP:  1
#
# Value from Client 7353-YOWFP:  1
#
# Value from Client 8008-ESFLK:  1
#
# Value from Client 4487-ZYJZK:  1
#
# Value from Client 8331-ZXFOE:  1
#
# Value from Client 7325-ENZFI:  1
#
# Value from Client 1397-XKKWR:  1
#
# Value from Client 8097-OMULG:  1
#
# Value from Client 6096-EGVTU:  1
#
# Value from Client 5081-NWSUP:  1
#
# Value from Client 2580-ATZSQ:  1
#
# Value from Client 9691-HKOVS:  1
#
# Value from Client 8319-QBEHW:  1
#
# Value from Client 4700-UBQMV:  1
#
# Value from Client 7356-AYNJP:  1
#
# Value from Client 7445-WMRBW:  1
#
# Value from Client 0080-EMYVY:  1
#
# Value from Client 7609-NRNCA:  1
#
# Value from Client 0623-EJQEG:  1
#
# Value from Client 7153-CHRBV:  1
#
# Value from Client 6198-PNNSZ:  1
#
# Value from Client 5774-QPLTF:  1
#
# Value from Client 3069-SSVSN:  1
#
# Value from Client 5857-XRECV:  1
#
# Value from Client 0725-CXOTM:  1
#
# Value from Client 4377-VDHYI:  1
#
# Value from Client 4937-QPZPO:  1
#
# Value from Client 6981-TDRFT:  1
#
# Value from Client 8033-VCZGH:  1
#
# Value from Client 5716-LIBJC:  1
#
# Value from Client 2868-LLSKM:  1
#
# Value from Client 1090-PYKCI:  1
#
# Value from Client 3417-TSCIC:  1
#
# Value from Client 1042-HFUCW:  1
#
# Value from Client 6537-OTKMY:  1
#
# Value from Client 1599-MMYRQ:  1
#
# Value from Client 8821-KVZKQ:  1
#
# Value from Client 0042-JVWOJ:  1
#
# Value from Client 2330-PQGDQ:  1
#
# Value from Client 8597-CTXVJ:  1
#
# Value from Client 4759-PXTAN:  1
#
# Value from Client 0824-VWDPO:  1
#
# Value from Client 8409-WQJUX:  1
#
# Value from Client 9746-UGFAC:  1
#
# Value from Client 4636-OLWOE:  1
#
# Value from Client 4685-ERGHK:  1
#
# Value from Client 5003-OKNNK:  1
#
# Value from Client 0489-WMEMG:  1
#
# Value from Client 7435-ZNUYY:  1
#
# Value from Client 2812-ENYMO:  1
#
# Value from Client 2890-WFBHU:  1
#
# Value from Client 0327-WFZSY:  1
#
# Value from Client 0864-FVJNJ:  1
#
# Value from Client 0186-CAERR:  1
#
# Value from Client 5872-OEQNH:  1
#
# Value from Client 8845-LWKGE:  1
#
# Value from Client 0691-NIKRI:  1
#
# Value from Client 3736-BLEPA:  1
#
# Value from Client 1929-ZCBHE:  1
#
# Value from Client 2696-ECXKC:  1
#
# Value from Client 0902-RFHOF:  1
#
# Value from Client 3214-IYUUQ:  1
#
# Value from Client 3587-PMCOY:  1
#
# Value from Client 8608-OZTLB:  1
#
# Value from Client 1952-DVVSW:  1
#
# Value from Client 6994-FGRHH:  1
#
# Value from Client 4000-VGMQP:  1
#
# Value from Client 2680-XKKNJ:  1
#
# Value from Client 6728-CZFEI:  1
#
# Value from Client 3653-NCRDJ:  1
#
# Value from Client 8224-UAXBZ:  1
#
# Value from Client 2486-WYVVE:  1
#
# Value from Client 1422-DGUBX:  1
#
# Value from Client 8668-KNZTI:  1
#
# Value from Client 9746-YKGXB:  1
#
# Value from Client 3926-YZVVX:  1
#
# Value from Client 6332-FBZRI:  1
#
# Value from Client 0254-WWRKD:  1
#
# Value from Client 8782-NUUOL:  1
#
# Value from Client 2233-TXSIU:  1
#
# Value from Client 0872-CASZJ:  1
#
# Value from Client 2599-CZABP:  1
#
# Value from Client 4544-RXFMG:  1
#
# Value from Client 0859-YGKFW:  1
#
# Value from Client 1150-FTQGN:  1
#
# Value from Client 1177-XZBJL:  1
#
# Value from Client 2911-IJORQ:  1
#
# Value from Client 3985-HOYPM:  1
#
# Value from Client 6576-FBXOJ:  1
#
# Value from Client 4753-PADAS:  1
#
# Value from Client 7781-EWARA:  1
#
# Value from Client 4184-VODJZ:  1
#
# Value from Client 2834-JKOOW:  1
#
# Value from Client 5203-XEHAX:  1
#
# Value from Client 8050-XGRVL:  1
#
# Value from Client 6728-VOIFY:  1
#
# Value from Client 8969-PRHFK:  1
#
# Value from Client 0661-KQHNK:  1
#
# Value from Client 9801-NOSHQ:  1
#
# Value from Client 2188-SXWVT:  1
#
# Value from Client 1094-BKOSX:  1
#
# Value from Client 3898-BSJYF:  1
#
# Value from Client 7696-AMHOD:  1
#
# Value from Client 9617-UDPEU:  1
#
# Value from Client 4955-VCWBI:  1
#
# Value from Client 3205-MXZRA:  1
#
# Value from Client 0083-PIVIK:  1
#
# Value from Client 8690-UPCZI:  1
#
# Value from Client 8822-KNBHV:  1
#
# Value from Client 1074-WVEVG:  1
#
# Value from Client 9979-RGMZT:  1
#
# Value from Client 5474-LAMUQ:  1
#
# Value from Client 3468-DRVQJ:  1
#
# Value from Client 1122-YJBCS:  1
#
# Value from Client 4816-OKWNX:  1
#
# Value from Client 3315-IKYZQ:  1
#
# Value from Client 0898-XCGTF:  1
#
# Value from Client 8249-THVEC:  1
#
# Value from Client 0048-PIHNL:  1
#
# Value from Client 6810-VCAEX:  1
#
# Value from Client 4480-MBMLB:  1
#
# Value from Client 4186-ZBUEW:  1
#
# Value from Client 9388-ZEYVT:  1
#
# Value from Client 0305-SQECB:  1
#
# Value from Client 8561-NMTBD:  1
#
# Value from Client 8292-FRFZQ:  1
#
# Value from Client 8080-POTJR:  1
#
# Value from Client 6906-MPARY:  1
#
# Value from Client 0516-OOHAR:  1
#
# Value from Client 9912-OMZDS:  1
#
# Value from Client 7103-IPXPJ:  1
#
# Value from Client 4342-HFXWS:  1
#
# Value from Client 1272-ILHFG:  1
#
# Value from Client 6500-JVEGC:  1
#
# Value from Client 5245-VDBUR:  1
#
# Value from Client 8469-SNFFH:  1
#
# Value from Client 2144-ESWKO:  1
#
# Value from Client 4114-QMKVN:  1
#
# Value from Client 9845-QOMAD:  1
#
# Value from Client 6668-CNMFP:  1
#
# Value from Client 5681-LLOEI:  1
#
# Value from Client 7964-ZRKKG:  1
#
# Value from Client 5546-QUERU:  1
#
# Value from Client 8738-JOKAR:  1
#
# Value from Client 0657-DOGUM:  1
#
# Value from Client 5297-MDOIR:  1
#
# Value from Client 6341-AEVKX:  1
#
# Value from Client 7470-DYNOE:  1
#
# Value from Client 1545-ACTAS:  1
#
# Value from Client 1956-YIFGE:  1
#
# Value from Client 2925-MXLSX:  1
#
# Value from Client 9609-BENEA:  1
#
# Value from Client 8213-TAZPM:  1
#
# Value from Client 7619-PLRLP:  1
#
# Value from Client 6508-NJYRO:  1
#
# Value from Client 5306-BVTKJ:  1
#
# Value from Client 2371-KFUOG:  1
#
# Value from Client 2758-RNWXS:  1
#
# Value from Client 2405-LBMUW:  1
#
# Value from Client 2898-MRKPI:  1
#
# Value from Client 2750-BJLSB:  1
#
# Value from Client 3648-GZPHF:  1
#
# Value from Client 1024-KPRBB:  1
#
# Value from Client 1264-FUHCX:  1
#
# Value from Client 6598-KELSS:  1
#
# Value from Client 0422-UXFAP:  1
#
# Value from Client 6967-PEJLL:  1
#
# Value from Client 1389-WNUIB:  1
#
# Value from Client 0218-QNVAS:  1
#
# Value from Client 0804-YGEQV:  1
#
# Value from Client 0052-YNYOT:  1
#
# Value from Client 9347-AERRL:  1
#
# Value from Client 7203-OYKCT:  1
#
# Value from Client 7750-EYXWZ:  1
#
# Value from Client 6840-RESVB:  1
#
# Value from Client 2234-XADUH:  1
#
# Outlier values in Contract_Two Year:
#
#
# Percentage of remaining data after outlier removal with IQR method:
#
# 3.379 % of remaining data after IQR method outlier removal, when criterion is 3

# %% [markdown]
# **Outliers: Conclusion**
#
# Percentages of Data kept after outlier removal for each test: <p>
# > * __IQR:__ 3.379 % when criterion is 3
#
# Not Removing any outliers for now

# %% [markdown]
# [BACK TO TOC](#toc)
#
# <div class="alert alert-block alert-success">
# <a id='before_split'>
# <font color = '#006400'>
#
# # 3. Data Pre Processing (before Split) </font>
# </a>
#
# </div>

# %% [markdown]
# **Drop Categorical Variables**
# > 1 - __Churn Reason__ - Does not have predictive power<p>
# > 2 - __City__ - Does not have predictive power<p>

# %%
#df.drop('City', axis = 1, inplace = True)
#df.drop('Churn Reason', axis = 1, inplace = True)
df.drop('Churn Category_Attitude', axis = 1, inplace = True)
df.drop('Churn Category_Competitor', axis = 1, inplace = True)
df.drop('Churn Category_Dissatisfaction', axis = 1, inplace = True)
df.drop('Churn Category_Price', axis = 1, inplace = True)
df.drop('New Customer', axis = 1, inplace = True)

# %% [markdown]
# [BACK TO TOC](#toc)
#
# <div class="alert alert-block alert-success">
# <a id='split'>
# <font color = '#006400'>
#
# # 4. Data Split </font>
# </a>
#
# </div>
#
# __Data is divided into two or more subsets.__ When working with test data, which represents unseen data to the models, it is important to follow certain guidelines to avoid data leakage and ensure reliable model performance:<br>
# * __`Data Imputation:`__ Techniques like mean, median, mode, z-score standardization, and other imputation methods should be applied after the train-test split. This ensures that any imputation is performed only on the training data and does not incorporate information from the test set. Data leakage occurs when the training data contains information about the target variable that would not be available during real-world predictions, leading to overestimated performance.
# * __`Train-Test Split:`__ The dataset should be split into a training set and a holdout test set. In this case, __80% of the data will be used for training models, while the remaining 20% will be set aside for validation.__ The data should be randomly shuffled before the split to avoid any bias. This __randomization__ ensures that the order of the samples does not impact the split. Additionally, __stratification__ should be applied to maintain the same proportion of classes in both the training and test sets as in the original dataset. This ensures that the model is trained and evaluated on representative data.
#
# Given the size of the Dataset we are going to use __`K-Fold Cross-Validation`__ to split our data.
# Create a new instance of StratifiedKFold named as `skf`, with the following hyperparameters:
# > - n_splits = 5
# > - random_state = 99
# > - shuffle = True

# %% [markdown]
# **K-Fold Cross-Validation:**

# %%
skf = StratifiedKFold(n_splits = 5, random_state = 99, shuffle = True)

X = df.drop('Churn Label', axis = 1)
y = df['Churn Label'].copy()

# %% [markdown]
# ***
# ***
# [BACK TO TOC](#toc)
#
#
# ### 5.3 Feature Selection

# %% [markdown]
# ## Filter Methods
# Rank features or feature subsets independently of the predictor (classifier)<p>
#
# Filter methods are generally used as preprocessing steps, and their selection is independent of any machine learning algorithm. Features are instead selected based on their scores in various statistical tests to determine their correlation with the outcome variable, which is subjective. Since it's a classification problem it'll be applied the following filter methods:
#
# > * __Chi-Square__ - `For categorical data`. The 𝜒2 test is used in statistics to test the independence of two events. More specifically in feature selection it's used to test whether the occurrence of a specific term and the occurrence of a specific class are independent.<p>
# > * __Kendall's Correlation Coeffificnet__ - Correlation is a measure of the linear relationship of 2 or more variables. The logic behind using correlation for feature selection is that the good variables are highly correlated with the target. Furthermore, variables should be correlated with the target but should be uncorrelated among themselves. It'll be used the Kendall's Coefficient since it's a non-parametric test that it'll be applied to numerical input values and categorical output, the threshold will be +/- 0.50<p>
# > * __ANOVA__ - `For one variable being numeric and one categorical` - Such as numerical input variables and a classification target variable in a classification task. <p>
# > * __Variance__ - `For continous, ordinal and binary data`. Use variance to understand if our numerical data and ordinal data is constant or quasi-constant. <p>

# %% [markdown]
# <a class="anchor" id="6th-bullet">
#
# #### __`Chi-Square (Filter Method) - For categorical data`__
#
# We are going to use chi-square to understand which categorical variables should we keep. <br>
# </a>

# %%
def apply_chisquare(X, y, var, alpha=0.05):
    dfObserved = pd.crosstab(y, X)
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)
    if p < alpha:
        result = "IMPORTANT"
    else:
        result = "NOT IMPORTANT"
    return result

def select_best_cat_features(X, y):
    count = 1

    # Create an empty DataFrame to store results
    results_df = pd.DataFrame(index=range(1, 6), columns=X.select_dtypes(include='object').columns)

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        # Check which categorical features to use using chi-square
        X_train_cat = X_train.select_dtypes(include='object').copy()
        for var in X_train_cat:
            result = apply_chisquare(X_train_cat[var], y_train, var)
            results_df.at[count, var] = result

        count += 1

    # Print the final table with the title in the first column
    results_df.index.name = 'Split'
    print(results_df)

select_best_cat_features(X, y)
# Out:
#             City   Churn Reason
# Split
# 1      IMPORTANT  NOT IMPORTANT
# 2      IMPORTANT  NOT IMPORTANT
# 3      IMPORTANT  NOT IMPORTANT
# 4      IMPORTANT  NOT IMPORTANT
# 5      IMPORTANT  NOT IMPORTANT

# %% [markdown]
# #### What can we conclude?
#
# | Predictor | Chi-Square | What to do? (One possible way to "solve")|
# | --- | --- | --- |
# | City | 5 Yes 0 No | Keep |
# | Churn Reason | 0 YES & 5 NO | Remove|
#
#
# Keep "City" and Remove "Churn Reason"

# %%
def apply_chisquare(X, y, var, alpha=0.05):
    dfObserved = pd.crosstab(y, X)
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)
    if p < alpha:
        result = "IMPORTANT"
    else:
        result = "NOT IMPORTANT"
    return result

def select_best_cat_features(X, y):
    count = 1

    # Create an empty DataFrame to store results
    results_df = pd.DataFrame(index=range(1, 6), columns=X.columns)

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        # Check which categorical features to use using chi-square
        X_train_cat = X_train.copy()
        for var in X_train_cat:
            result = apply_chisquare(X_train_cat[var], y_train, var)
            results_df.at[count, var] = result

        count += 1

    # Print the final table with the title in the first column
    results_df.index.name = 'Split'
    return results_df

select_best_cat_features(X, y)
# Out:
#              Age   Under 30 Senior Citizen    Married Dependents  \
# Split
# 1      IMPORTANT  IMPORTANT      IMPORTANT  IMPORTANT  IMPORTANT
# 2      IMPORTANT  IMPORTANT      IMPORTANT  IMPORTANT  IMPORTANT
# 3      IMPORTANT  IMPORTANT      IMPORTANT  IMPORTANT  IMPORTANT
# 4      IMPORTANT  IMPORTANT      IMPORTANT  IMPORTANT  IMPORTANT
# 5      IMPORTANT  IMPORTANT      IMPORTANT  IMPORTANT  IMPORTANT
#
#       Number of Dependents Referred a Friend Number of Referrals  \
# Split
# 1                IMPORTANT         IMPORTANT           IMPORTANT
# 2                IMPORTANT         IMPORTANT           IMPORTANT
# 3                IMPORTANT         IMPORTANT           IMPORTANT
# 4                IMPORTANT         IMPORTANT           IMPORTANT
# 5                IMPORTANT         IMPORTANT           IMPORTANT
#
#       Tenure in Months Tenure Category  Phone Service  \
# Split
# 1            IMPORTANT       IMPORTANT  NOT IMPORTANT
# 2            IMPORTANT       IMPORTANT  NOT IMPORTANT
# 3            IMPORTANT       IMPORTANT  NOT IMPORTANT
# 4            IMPORTANT       IMPORTANT  NOT IMPORTANT
# 5            IMPORTANT       IMPORTANT  NOT IMPORTANT
#
#       Avg Monthly Long Distance Charges Multiple Lines Internet Service  \
# Split
# 1                         NOT IMPORTANT      IMPORTANT        IMPORTANT
# 2                         NOT IMPORTANT      IMPORTANT        IMPORTANT
# 3                         NOT IMPORTANT      IMPORTANT        IMPORTANT
# 4                         NOT IMPORTANT      IMPORTANT        IMPORTANT
# 5                         NOT IMPORTANT      IMPORTANT        IMPORTANT
#
#       Avg Monthly GB Download Online Security Online Backup  \
# Split
# 1                   IMPORTANT       IMPORTANT     IMPORTANT
# 2                   IMPORTANT       IMPORTANT     IMPORTANT
# 3                   IMPORTANT       IMPORTANT     IMPORTANT
# 4                   IMPORTANT       IMPORTANT     IMPORTANT
# 5                   IMPORTANT       IMPORTANT     IMPORTANT
#
#       Device Protection Plan Premium Tech Support Streaming TV  \
# Split
# 1                  IMPORTANT            IMPORTANT    IMPORTANT
# 2                  IMPORTANT            IMPORTANT    IMPORTANT
# 3                  IMPORTANT            IMPORTANT    IMPORTANT
# 4                  IMPORTANT            IMPORTANT    IMPORTANT
# 5                  IMPORTANT            IMPORTANT    IMPORTANT
#
#       Streaming Movies Streaming Music Unlimited Data Paperless Billing  \
# Split
# 1            IMPORTANT       IMPORTANT      IMPORTANT         IMPORTANT
# 2            IMPORTANT       IMPORTANT      IMPORTANT         IMPORTANT
# 3            IMPORTANT       IMPORTANT      IMPORTANT         IMPORTANT
# 4            IMPORTANT       IMPORTANT      IMPORTANT         IMPORTANT
# 5            IMPORTANT       IMPORTANT      IMPORTANT         IMPORTANT
#
#       Monthly Charge  Total Charges  Total Refunds Total Extra Data Charges  \
# Split
# 1          IMPORTANT  NOT IMPORTANT  NOT IMPORTANT                IMPORTANT
# 2          IMPORTANT  NOT IMPORTANT  NOT IMPORTANT                IMPORTANT
# 3          IMPORTANT  NOT IMPORTANT  NOT IMPORTANT                IMPORTANT
# 4          IMPORTANT  NOT IMPORTANT  NOT IMPORTANT                IMPORTANT
# 5          IMPORTANT  NOT IMPORTANT  NOT IMPORTANT                IMPORTANT
#
#       Total Long Distance Charges  Total Revenue Satisfaction Score  \
# Split
# 1                   NOT IMPORTANT  NOT IMPORTANT          IMPORTANT
# 2                   NOT IMPORTANT  NOT IMPORTANT          IMPORTANT
# 3                   NOT IMPORTANT  NOT IMPORTANT          IMPORTANT
# 4                   NOT IMPORTANT  NOT IMPORTANT          IMPORTANT
# 5                   NOT IMPORTANT  NOT IMPORTANT          IMPORTANT
#
#       Churn Score           CLTV Population Engagement Score    Gender_Male  \
# Split
# 1       IMPORTANT  NOT IMPORTANT  IMPORTANT        IMPORTANT  NOT IMPORTANT
# 2       IMPORTANT  NOT IMPORTANT  IMPORTANT        IMPORTANT  NOT IMPORTANT
# 3       IMPORTANT  NOT IMPORTANT  IMPORTANT        IMPORTANT  NOT IMPORTANT
# 4       IMPORTANT  NOT IMPORTANT  IMPORTANT        IMPORTANT  NOT IMPORTANT
# 5       IMPORTANT  NOT IMPORTANT  IMPORTANT        IMPORTANT  NOT IMPORTANT
#
#       Offer_Offer A Offer_Offer B  Offer_Offer C  Offer_Offer D Offer_Offer E  \
# Split
# 1         IMPORTANT     IMPORTANT  NOT IMPORTANT  NOT IMPORTANT     IMPORTANT
# 2         IMPORTANT     IMPORTANT  NOT IMPORTANT  NOT IMPORTANT     IMPORTANT
# 3         IMPORTANT     IMPORTANT      IMPORTANT  NOT IMPORTANT     IMPORTANT
# 4         IMPORTANT     IMPORTANT  NOT IMPORTANT  NOT IMPORTANT     IMPORTANT
# 5         IMPORTANT     IMPORTANT  NOT IMPORTANT  NOT IMPORTANT     IMPORTANT
#
#       Internet Type_Cable Internet Type_DSL Internet Type_Fiber Optic  \
# Split
# 1           NOT IMPORTANT         IMPORTANT                 IMPORTANT
# 2           NOT IMPORTANT         IMPORTANT                 IMPORTANT
# 3           NOT IMPORTANT         IMPORTANT                 IMPORTANT
# 4           NOT IMPORTANT         IMPORTANT                 IMPORTANT
# 5           NOT IMPORTANT         IMPORTANT                 IMPORTANT
#
#       Payment Method_Bank Withdrawal Payment Method_Credit Card Density_High  \
# Split
# 1                          IMPORTANT                  IMPORTANT    IMPORTANT
# 2                          IMPORTANT                  IMPORTANT    IMPORTANT
# 3                          IMPORTANT                  IMPORTANT    IMPORTANT
# 4                          IMPORTANT                  IMPORTANT    IMPORTANT
# 5                          IMPORTANT                  IMPORTANT    IMPORTANT
#
#          Density_Low Contract_Month-to-Month Contract_One Year  \
# Split
# 1      NOT IMPORTANT               IMPORTANT         IMPORTANT
# 2          IMPORTANT               IMPORTANT         IMPORTANT
# 3          IMPORTANT               IMPORTANT         IMPORTANT
# 4      NOT IMPORTANT               IMPORTANT         IMPORTANT
# 5          IMPORTANT               IMPORTANT         IMPORTANT
#
#       Contract_Two Year
# Split
# 1             IMPORTANT
# 2             IMPORTANT
# 3             IMPORTANT
# 4             IMPORTANT
# 5             IMPORTANT

# %%
X = X.drop(['Churn Reason'], axis = 1)

# %%
def filter_fs_df(X, y, skf):
    '''
    Returns a dataframe with the Kendall's Correlation, ANOVA and Chi-Square applied to the input data
    
    Args:
        X (pandas.dataframe) - Variables
        y (pandas.dataframe) - Target
        skf (object) - StratifiedKFold instance

    Returns: 
        pandas.dataframe
    '''
    df = pd.DataFrame()
    df['Features'] = X.columns

    kendall_feat_count = {}  # Dictionary to store counts for Kendall's Correlation
    anova_feat_count = {}  # Dictionary to store counts for ANOVA
    chi_feat_count = {}  # Dictionary to store counts for Chi-Square
    
    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]
        
        # Select numerical and categorical features
        X_train_num = X_train.select_dtypes(include=[np.number])
        X_train_cat = X_train.select_dtypes(include=['object', 'category', 'bool', 'int'])

        # Apply Kendall's correlation for numerical features
        for col in X_train_num:
            if abs(stats.kendalltau(X_train_num[col], y_train)[0]) > .5:
                if col in kendall_feat_count:
                    kendall_feat_count[col] += 1
                else:
                    kendall_feat_count[col] = 1
        
        # Apply ANOVA for numerical features
        for col in X_train_num:
            fvalue, pvalue = f_classif(X_train_num[[col]], y_train)
            if pvalue[0] < 0.05:
                if col in anova_feat_count:
                    anova_feat_count[col] += 1
                else:
                    anova_feat_count[col] = 1

        # Apply Chi-Square for categorical features
        for col in X_train_cat:
            chi_check = pd.crosstab(y_train, X_train_cat[col]) 
            chi2, p, dof, expected = chi2_contingency(chi_check.values)
            if p < .05:
                if col in chi_feat_count:
                    chi_feat_count[col] += 1
                else:
                    chi_feat_count[col] = 1

    df['Kendall_Significant_Count'] = df['Features'].apply(lambda x: kendall_feat_count[x] if x in kendall_feat_count else 0)
    df['Filter_Kendall'] = df['Kendall_Significant_Count'].apply(lambda x: 'Keep' if x > 3 else 'Discard')
    df.loc[df['Features'].apply(lambda x: X[x].dtypes not in [np.number, np.float64, np.int64]), 'Filter_Kendall'] = '-'
    
    df['ANOVA_Significant_Count'] = df['Features'].apply(lambda x: anova_feat_count[x] if x in anova_feat_count else 0)
    df['Filter_ANOVA'] = df['ANOVA_Significant_Count'].apply(lambda x: 'Keep' if x > 3 else 'Discard')
    df.loc[df['Features'].apply(lambda x: X[x].dtypes not in [np.number, np.float64, np.int64]), 'Filter_ANOVA'] = '-'
    
    df['CHI2_Significant_Count'] = df['Features'].apply(lambda x: chi_feat_count[x] if x in chi_feat_count else 0)
    df['Filter_CHI2'] = df['CHI2_Significant_Count'].apply(lambda x: 'Keep' if x > 3 else 'Discard')
    df.loc[df['Features'].apply(lambda x: X[x].dtypes in ['object', 'category', 'bool', 'int']), 'Filter_CHI2'] = '-'

    
    return df

# Prepare StratifiedKFold instance
skf = StratifiedKFold(n_splits = 5, random_state = 99, shuffle = True)

filtered = filter_fs_df(X, y, skf)
filtered.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_00cc9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00cc9_level0_col0" class="col_heading level0 col0" >Features</th>
#       <th id="T_00cc9_level0_col1" class="col_heading level0 col1" >Kendall_Significant_Count</th>
#       <th id="T_00cc9_level0_col2" class="col_heading level0 col2" >Filter_Kendall</th>
#       <th id="T_00cc9_level0_col3" class="col_heading level0 col3" >ANOVA_Significant_Count</th>
#       <th id="T_00cc9_level0_col4" class="col_heading level0 col4" >Filter_ANOVA</th>
#       <th id="T_00cc9_level0_col5" class="col_heading level0 col5" >CHI2_Significant_Count</th>
#       <th id="T_00cc9_level0_col6" class="col_heading level0 col6" >Filter_CHI2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00cc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00cc9_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_00cc9_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_00cc9_row0_col2" class="data row0 col2" >Discard</td>
#       <td id="T_00cc9_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_00cc9_row0_col4" class="data row0 col4" >Keep</td>
#       <td id="T_00cc9_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_00cc9_row0_col6" class="data row0 col6" >Discard</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00cc9_row1_col0" class="data row1 col0" >Under 30</td>
#       <td id="T_00cc9_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_00cc9_row1_col2" class="data row1 col2" >Discard</td>
#       <td id="T_00cc9_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_00cc9_row1_col4" class="data row1 col4" >Keep</td>
#       <td id="T_00cc9_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_00cc9_row1_col6" class="data row1 col6" >Keep</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00cc9_row2_col0" class="data row2 col0" >Senior Citizen</td>
#       <td id="T_00cc9_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_00cc9_row2_col2" class="data row2 col2" >Discard</td>
#       <td id="T_00cc9_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_00cc9_row2_col4" class="data row2 col4" >Keep</td>
#       <td id="T_00cc9_row2_col5" class="data row2 col5" >5</td>
#       <td id="T_00cc9_row2_col6" class="data row2 col6" >Keep</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00cc9_row3_col0" class="data row3 col0" >Married</td>
#       <td id="T_00cc9_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_00cc9_row3_col2" class="data row3 col2" >Discard</td>
#       <td id="T_00cc9_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_00cc9_row3_col4" class="data row3 col4" >Keep</td>
#       <td id="T_00cc9_row3_col5" class="data row3 col5" >5</td>
#       <td id="T_00cc9_row3_col6" class="data row3 col6" >Keep</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00cc9_row4_col0" class="data row4 col0" >Dependents</td>
#       <td id="T_00cc9_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_00cc9_row4_col2" class="data row4 col2" >Discard</td>
#       <td id="T_00cc9_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_00cc9_row4_col4" class="data row4 col4" >Keep</td>
#       <td id="T_00cc9_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_00cc9_row4_col6" class="data row4 col6" >Keep</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00cc9_row5_col0" class="data row5 col0" >Number of Dependents</td>
#       <td id="T_00cc9_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_00cc9_row5_col2" class="data row5 col2" >Discard</td>
#       <td id="T_00cc9_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_00cc9_row5_col4" class="data row5 col4" >Keep</td>
#       <td id="T_00cc9_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_00cc9_row5_col6" class="data row5 col6" >Discard</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_00cc9_row6_col0" class="data row6 col0" >Referred a Friend</td>
#       <td id="T_00cc9_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_00cc9_row6_col2" class="data row6 col2" >Discard</td>
#       <td id="T_00cc9_row6_col3" class="data row6 col3" >5</td>
#       <td id="T_00cc9_row6_col4" class="data row6 col4" >Keep</td>
#       <td id="T_00cc9_row6_col5" class="data row6 col5" >5</td>
#       <td id="T_00cc9_row6_col6" class="data row6 col6" >Keep</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_00cc9_row7_col0" class="data row7 col0" >Number of Referrals</td>
#       <td id="T_00cc9_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_00cc9_row7_col2" class="data row7 col2" >Discard</td>
#       <td id="T_00cc9_row7_col3" class="data row7 col3" >5</td>
#       <td id="T_00cc9_row7_col4" class="data row7 col4" >Keep</td>
#       <td id="T_00cc9_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_00cc9_row7_col6" class="data row7 col6" >Discard</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_00cc9_row8_col0" class="data row8 col0" >Tenure in Months</td>
#       <td id="T_00cc9_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_00cc9_row8_col2" class="data row8 col2" >Discard</td>
#       <td id="T_00cc9_row8_col3" class="data row8 col3" >5</td>
#       <td id="T_00cc9_row8_col4" class="data row8 col4" >Keep</td>
#       <td id="T_00cc9_row8_col5" class="data row8 col5" >0</td>
#       <td id="T_00cc9_row8_col6" class="data row8 col6" >Discard</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_00cc9_row9_col0" class="data row9 col0" >Tenure Category</td>
#       <td id="T_00cc9_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_00cc9_row9_col2" class="data row9 col2" >Discard</td>
#       <td id="T_00cc9_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_00cc9_row9_col4" class="data row9 col4" >Keep</td>
#       <td id="T_00cc9_row9_col5" class="data row9 col5" >0</td>
#       <td id="T_00cc9_row9_col6" class="data row9 col6" >Discard</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_00cc9_row10_col0" class="data row10 col0" >Phone Service</td>
#       <td id="T_00cc9_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_00cc9_row10_col2" class="data row10 col2" >Discard</td>
#       <td id="T_00cc9_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_00cc9_row10_col4" class="data row10 col4" >Discard</td>
#       <td id="T_00cc9_row10_col5" class="data row10 col5" >0</td>
#       <td id="T_00cc9_row10_col6" class="data row10 col6" >Discard</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_00cc9_row11_col0" class="data row11 col0" >Avg Monthly Long Distance Charges</td>
#       <td id="T_00cc9_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_00cc9_row11_col2" class="data row11 col2" >Discard</td>
#       <td id="T_00cc9_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_00cc9_row11_col4" class="data row11 col4" >Discard</td>
#       <td id="T_00cc9_row11_col5" class="data row11 col5" >0</td>
#       <td id="T_00cc9_row11_col6" class="data row11 col6" >Discard</td>
#     </tr>
#     <tr>
#       <th id="T_00cc9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_00cc9_row12_col0" class="data row12 col0" >Multiple Lines</td>
#       <td id="T_00cc9_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_00cc9_row12_col2" class="data row12 col2" >Discard</td>
#       <td id="T_00cc9_row12_col3" class="da

# %%
#Remove categorical Data
X = X.drop(['City'], axis = 1)

# %% [markdown]
# **Variance**

# %%
def select_features_variance(X, y, n_splits=5, random_state=99):
    skf = StratifiedKFold(n_splits=n_splits, random_state=random_state, shuffle=True)
    results = []

    for count, (train_index, val_index) in enumerate(skf.split(X, y), start=1):

        X_train, X_val = X.iloc[train_index], X.iloc[val_index]


        var = X_train.var()
        results.append(var)

    result_df = pd.concat(results, axis=1)
    result_df.columns = [f'Variance (Split {i})' for i in range(1, n_splits+1)]
    
    return result_df

result_df = select_features_variance(X, y)
result_df
# Out:
#                                    Variance (Split 1)  Variance (Split 2)  \
# Age                                          0.075345            0.074570
# Under 30                                     0.157691            0.159303
# Senior Citizen                               0.136295            0.134371
# Married                                      0.249858            0.249717
# Dependents                                   0.179431            0.175607
# Number of Dependents                         0.011632            0.011019
# Referred a Friend                            0.248477            0.248168
# Number of Referrals                          0.073366            0.073537
# Tenure in Months                             0.119598            0.118874
# Tenure Category                              0.120436            0.120354
# Phone Service                                0.085525            0.087821
# Avg Monthly Long Distance Charges            0.095522            0.095145
# Multiple Lines                               0.244722            0.242935
# Internet Service                             0.169279            0.168267
# Avg Monthly GB Download                      0.058484            0.057410
# Online Security                              0.204140            0.205723
# Online Backup                                0.225865            0.226848
# Device Protection Plan                       0.225865            0.227171
# Premium Tech Support                         0.206837            0.207864
# Streaming TV                                 0.237098            0.235645
# Streaming Movies                             0.238358            0.237259
# Streaming Music                              0.229929            0.228285
# Unlimited Data                               0.220336            0.219473
# Paperless Billing                            0.241817            0.241655
# Monthly Charge                               0.089426            0.089490
# Total Charges                                0.068579            0.068324
# Total Refunds                                0.024184            0.025158
# Total Extra Data Charges                     0.028604            0.028550
# Total Long Distance Charges                  0.057079            0.055843
# Total Revenue                                0.057819            0.057337
# Satisfaction Score                           0.089967            0.088972
# Churn Score                                  0.053676            0.054198
# CLTV                                         0.069518            0.069592
# Population                                   0.040606            0.040545
# Engagement Score                             0.082221            0.083194
# Gender_Male                                  0.249991            0.250023
# Offer_Offer A                                0.069455            0.068549
# Offer_Offer B                                0.102215            0.104797
# Offer_Offer C                                0.055465            0.055935
# Offer_Offer D                                0.078835            0.078247
# Offer_Offer E                                0.101669            0.100161
# Internet Type_Cable                          0.105068            0.106551
# Internet Type_DSL                            0.179902            0.178769
# Internet Type_Fiber Optic                    0.245103            0.245374
# Payment Method_Bank Withdrawal               0.246878            0.246592
# Payment Method_Credit Card                   0.237617            0.236895
# Density_High                                 0.223951            0.224804
# Density_Low                                  0.221487            0.220823
# Contract_Month-to-Month                      0.249959            0.249911
# Contract_One Year                            0.173657            0.172870
# Contract_Two Year                            0.195805            0.195391
#
#                                    Variance (Split 3)  Variance (Split 4)  \
# Age                                          0.075027            0.075905
# Under 30                                     0.160688            0.159281
# Senior Citizen                               0.133524            0.137588
# Married                                      0.249795            0.249646
# Dependents                                   0.180746            0.175972
# Number of Dependents                         0.011798            0.011473
# Referred a Friend                            0.248304            0.248068
# Number of Referrals                          0.075481            0.074642
# Tenure in Months                             0.119968            0.119459
# Tenure Category                              0.121168            0.120713
# Phone Service                                0.087678            0.087950
# Avg Monthly Long Distance Charges            0.095608            0.095673
# Multiple Lines                               0.243720            0.244395
# Internet Service                             0.171782            0.169257
# Avg Monthly GB Download                      0.057603            0.057919
# Online Security                              0.204595            0.205177
# Online Backup                                0.225477            0.226340
# Device Protection Plan                       0.226250            0.225346
# Premium Tech Support                         0.204972            0.206000
# Streaming TV                                 0.236026            0.237163
# Streaming Movies                             0.237138            0.237122
# Streaming Music                              0.228180            0.228162
# Unlimited Data                               0.219411            0.220009
# Paperless Billing                            0.242040            0.241046
# Monthly Charge                               0.090020            0.089191
# Total Charges                                0.068335            0.067982
# Total Refunds                                0.025596            0.025473
# Total Extra Data Charges                     0.026370            0.028844
# Total Long Distance Charges                  0.056511            0.056972
# Total Revenue                                0.057373            0.057105
# Satisfaction Score                           0.089865            0.090868
# Churn Score                                  0.054583            0.054003
# CLTV                                         0.069327            0.068305
# Population                                   0.039632            0.040897
# Engagement Score                             0.083427            0.082396
# Gender_Male                                  0.249991            0.250027
# Offer_Offer A                                0.069455            0.069745
# Offer_Offer B                                0.104662            0.103561
# Offer_Offer C                                0.053267            0.056863
# Offer_Offer D                                0.078688            0.077055
# Offer_Offer E                                0.100847            0.100420
# Internet Type_Cable                          0.104391            0.101516
# Internet Type_DSL                            0.178484            0.180723
# Internet Type_Fiber Optic                    0.244978            0.245532
# Payment Method_Bank Withdrawal               0.247609            0.246789
# Payment Method_Credit Card                   0.238964            0.238228
# Density_High                                 0.224804            0.224898
# Density_Low                                  0.219473            0.221886
# Contract_Month-to-Month                      0.249838            0.249937
# Contract_One Year                            0.168368            0.172156
# Contract_Two Year                            0.197772            0.196525
#
#                                    Variance (Split 5)
# Age                                          0.076170
# Under 30                                     0.159922
# Senior Citizen                               0.137588
# Married                                      0.249745
# Dependents                                   0.176550
# Number of Dependents                         0.011296
# Referred a Friend                            0.248146
# Number of Referrals                          0.075176
# Tenure in Months                             0.119516
# Tenure Category                              0.121002
# Phone Service                                0.088379
# Avg Monthly Long Distance Charges            0.095544
# Multiple Lines                               0.243821
# Internet Service                             0.170163
# Avg Monthly GB Download                      0.057121
# Online Security                              0.202970
# Online Backup                                0.225346
# Device Protection Plan                       0.223644
# Premium Tech Support                         0.204422
# Streaming TV                                 0.237363
# Streaming Movies                             0.237483
# Streaming Music                              0.227951
# Unlimited Data                               0.220070
# Paperless Billing                            0.241113
# Monthly Charge                               0.090092
# Total Charges                                0.068715
# Total Refunds                                0.025548
# Total Extra Data Charges                     0.027686
# Total Long Distance Charges                  0.055653
# Total Revenue                                0.057424
# Satisfaction Score                           0.091578
# Churn Score                                  0.054142
# CLTV                                         0.069312
# Population                                   0.040182
# Engagement Score                             0.082434
# Gender_Male                                  0.250044
# Offer_Offer A                                0.064737
# Offer_Offer B                                0.101379
# Offer_Offer C                                0.055769
# Offer_Offer D                                0.078087
# Offer_Offer E                                0.103153
# Internet Type_Cable                          0.102336
# Internet Type_DSL                            0.179974
# Internet Type_Fiber Optic                    0.245363
# Payment Method_Bank Withdrawal               0.247162
# Payment Method_Credit Card                   0.238305
# Density_High                                 0.222889
# Density_Low                                  0.222419
# Contract_Month-to-Month                      0.249745
# Contract_One Year                            0.171262
# Contract_Two Year                            0.194033

# %% [markdown]
# No Constant Variables

# %% [markdown]
# __Notes:__
#
# > 1 - __Chi-Squared__ discards __Education__ and keeps __Marital_Status__ <p>
# > 2 - __Kendall's correlation__ discards all features (meaning there're no variables with an absolute correlation with the target above 0.5)<p>
# > 3 - __ANOVA test__, discards __Kid_Younger6__, __NumStorePurchases__, __NumAppVisitsMonth__, __Complain__, __CostContact__, __Revenue__ and __Age__ <p>
# > 4 - __Variance__ tells us that the variables __CostContact__ and __Revenue__ are constant features. We should remove those.<p>

# %% [markdown]
# ***
# Now it is time to understand the ones that we should keep and the ones to be removed.
#
# Since we know that regressions are really sensible to correlated features, we should remove the correlated features before applying those techniques, namely Lasso Regression and Recursive Feature Elimination if the estimator used is a regression model. Therefore, we will begin by applying decision trees to identify which features among the correlated ones should be excluded.
#
# ### Decision Trees and Random Forest (Embedded Methods to use before applying regressions)
#
# Use these two methods to first identify the most important variables and exclude redundant or correlated ones. These methods capture non-linear relationships and handle interactions between variables.
#
#
# > * __Decision Trees__ - `For continous, ordinal and binary data` It is important to note that regression models are particularly sensible to correlated features. Therefore, we will begin by applying decision trees to identify which features among the correlated ones should be excluded.
# > * __Random Forest__ - __Can be used to get the feature importances__, Random Forest improve the variance of simple Decision Trees by incorporating randomness. The criteria to get importance will be __Entropy which is a measure of information that indicates the disorder of the features with the target__. Similar to the Gini Index, the optimum split is chosen by the feature with less entropy. <p>
#
# Both methods are not affected by the scale of the features since they make splits based on thresholds and do not rely on the magniture of the values. We tested and results were not different when data was scaled or not.

# %% [markdown]
# **Decision Trees**

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.impute import KNNImputer

def plot_importance(variables, name, subplot_index):
    imp_features = variables.sort_values()
    plt.subplot(1, 5, subplot_index)  # Adjust the subplot settings accordingly
    imp_features.plot(kind="barh", color='green')  # Set color to green
    plt.title("Split " + str(subplot_index))  # Set subplot title to split number
    plt.xticks(fontsize=8)  # Decrease the size of the x-axis labels
    plt.tight_layout()

def select_best_features_dt(X, y):
    count = 1
    fig = plt.figure(figsize=(35, 20))  # Create a figure to contain the subplots
    skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)
    ranking_scores = pd.DataFrame(index=X.columns)  # Create a DataFrame to store the ranking scores

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        dt = DecisionTreeClassifier(random_state=99).fit(X_train, y_train)
        feature_importances = pd.Series(dt.feature_importances_, index=X_train.columns)

        # Store the feature importances in the ranking_scores DataFrame
        ranking_scores[f'Split {count}'] = feature_importances

        plot_importance(feature_importances, 'DT', count)
        count += 1

    plt.suptitle("Feature Importance using DT Model", fontsize=12, fontweight='bold')  # Overall title above the subplots
    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout of the subplots and overall title
    plt.show()

    # Calculate the average ranking score across all splits
    ranking_scores['Average Score'] = ranking_scores.mean(axis=1)
    average_ranking = ranking_scores['Average Score'].sort_values(ascending=False)
    print(average_ranking)

select_best_features_dt(X, y)
# Out:
# Satisfaction Score                   0.728265
# Churn Score                          0.168258
# Online Security                      0.012158
# Tenure in Months                     0.011251
# Monthly Charge                       0.008679
# Contract_Month-to-Month              0.008029
# CLTV                                 0.006975
# Number of Referrals                  0.006213
# Population                           0.005013
# Age                                  0.004557
# Avg Monthly GB Download              0.004025
# Total Long Distance Charges          0.003929
# Avg Monthly Long Distance Charges    0.003617
# Total Revenue                        0.003391
# Total Charges                        0.003097
# Internet Service                     0.002602
# Number of Dependents                 0.002522
# Internet Type_Fiber Optic            0.001542
# Engagement Score                     0.001470
# Referred a Friend                    0.001415
# Senior Citizen                       0.001288
# Offer_Offer C                        0.000947
# Multiple Lines                       0.000864
# Streaming Music                      0.000793
# Total Extra Data Charges             0.000724
# Total Refunds                        0.000620
# Density_High                         0.000520
# Density_Low                          0.000513
# Contract_Two Year                    0.000509
# Offer_Offer D                        0.000498
# Dependents                           0.000492
# Streaming Movies                     0.000485
# Internet Type_Cable                  0.000469
# Premium Tech Support                 0.000460
# Tenure Category                      0.000426
# Gender_Male                          0.000388
# Device Protection Plan               0.000376
# Internet Type_DSL                    0.000375
# Streaming TV                         0.000346
# Online Backup                        0.000338
# Offer_Offer B                        0.000273
# Married                              0.000267
# Payment Method_Credit Card           0.000199
# Unlimited Data                       0.000188
# Offer_Offer A                        0.000137
# Under 30                             0.000137
# Paperless Billing                    0.000121
# Contract_One Year                    0.000097
# Payment Method_Bank Withdrawal       0.000091
# Offer_Offer E                        0.000052
# Phone Service                        0.000000
# Name: Average Score, dtype: float64

# %% [markdown]
# **Random Forest**

# %%
def plot_importance(variables, name, subplot_index):
    imp_features = variables.sort_values()
    plt.subplot(1, 5, subplot_index)  # Adjust the subplot settings accordingly
    imp_features.plot(kind="barh", color='green')  # Set color to green
    plt.title("Split " + str(subplot_index))  # Set subplot title to split number
    plt.xticks(fontsize=8)  # Decrease the size of the x-axis labels
    plt.tight_layout()

# %%
def apply_rf(X_train, y_train, subplot_index):
    rf = RandomForestClassifier(criterion='entropy', random_state=99).fit(X_train, y_train)
    feature_importances = pd.Series(rf.feature_importances_, index=X_train.columns)
    plot_importance(feature_importances, 'RF', subplot_index)
    return feature_importances

def select_best_features_rf(X, y):
    count = 1
    fig = plt.figure(figsize=(35, 20))  # Create a figure to contain the subplots
    skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)
    ranking_scores = pd.DataFrame(index=X.columns)  # Create a DataFrame to store the ranking scores

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        # Select numerical features for random forest
        X_train_num = X_train.select_dtypes(include=[np.number])

        # Scale the numerical features
        scaler = MinMaxScaler().fit(X_train_num)
        X_train_scaled = scaler.transform(X_train_num)
        X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_num.columns)

        # Apply random forest to scaled numerical features
        feature_importances = apply_rf(X_train_scaled, y_train, count)

        # Store the feature importances in the ranking_scores DataFrame
        ranking_scores[f'Split {count}'] = feature_importances

        count += 1

    plt.suptitle("Feature Importance using RF Model", fontsize=12, fontweight='bold')  # Overall title above the subplots
    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout of the subplots and overall title
    plt.show()

    # Calculate the average ranking score across all splits
    ranking_scores['Average Score'] = ranking_scores.mean(axis=1)
    average_ranking = ranking_scores['Average Score'].sort_values(ascending=False)
    print(average_ranking)

select_best_features_rf(X, y)
# Out:
# Satisfaction Score                   0.343422
# Churn Score                          0.267384
# Contract_Month-to-Month              0.047777
# Number of Referrals                  0.028902
# Contract_Two Year                    0.023959
# Monthly Charge                       0.022605
# Tenure in Months                     0.021807
# Total Revenue                        0.018684
# Tenure Category                      0.018094
# Total Charges                        0.016850
# Avg Monthly GB Download              0.015409
# Age                                  0.014813
# Total Long Distance Charges          0.013992
# Internet Type_Fiber Optic            0.012030
# CLTV                                 0.011420
# Population                           0.011391
# Dependents                           0.011092
# Avg Monthly Long Distance Charges    0.009768
# Number of Dependents                 0.009347
# Online Security                      0.008351
# Engagement Score                     0.006879
# Contract_One Year                    0.005779
# Senior Citizen                       0.005216
# Payment Method_Credit Card           0.005139
# Internet Service                     0.004649
# Paperless Billing                    0.003369
# Premium Tech Support                 0.002870
# Payment Method_Bank Withdrawal       0.002829
# Streaming Music                      0.002417
# Referred a Friend                    0.002356
# Total Extra Data Charges             0.002220
# Married                              0.002193
# Offer_Offer E                        0.002098
# Multiple Lines                       0.001987
# Gender_Male                          0.001923
# Internet Type_DSL                    0.001904
# Streaming TV                         0.001866
# Streaming Movies                     0.001788
# Density_High                         0.001742
# Unlimited Data                       0.001678
# Online Backup                        0.001615
# Density_Low                          0.001581
# Total Refunds                        0.001496
# Device Protection Plan               0.001376
# Under 30                             0.001262
# Offer_Offer B                        0.001032
# Offer_Offer D                        0.000926
# Internet Type_Cable                  0.000901
# Offer_Offer C                        0.000808
# Phone Service                        0.000663
# Offer_Offer A                        0.000341
# Name: Average Score, dtype: float64

# %% [markdown]
# __Notes:__
#
# We had identified previously with correlation matrix that several groups are highly correlated so we should decide which variables to keep and which to remove. In terms of feature importance, **random forests often provide more reliable results than individual decision trees**. Random forests consider the collective wisdom of multiple trees and average their predictions, resulting in a more stable and robust estimate of feature importance.
#
# > - __Most important features to keep__: <p>
#     >> Satisfaction Score, Churn Score, Contract Month to Month, COntract Two Years, New Customer

# %% [markdown]
# ***
# At this moment, we already removed correlated features and can apply techniques where regression is used.
#
# First, lets apply Wrapper Methods.
#
# ***
# ## Wrapper Methods
# Use a classifier to assess features or feature subsets<p>
#
# Wrapper methods are used to train a model using a subset of features. According to the conclusions drawn from the previous model, it decides whether to include or exclude certain features from the subgroup, it'll be applied wrapper methods like: <p>
#
# > * __Recursive Feature Elimination (RFE)__* - `for continious, ordinal and binary data`__The algorithm aims to find the best performing subset of features by using greedy optimization__ (making the locally optimal choice at each stage with the hope of finding the global optimum). Each iteration __creates a new model and keeps aside the best or worst performing features__. The next model is constructed using the remaining features __until all the features have been exhausted__. The features are then __ranked according to their elimination order__ <p>
# > * __Forward Selection (SFS)__ - Starts with __no feature in the model and iterate forward__. On each subsequent repetition, __add the feature that improves the model__ the most __until the addition of a new variable does not improve its performance__ <p>
# > * __Backward Selection (SBS)__ - Starts with __all the features during backward elimination and remove the least significant feature at every iteration__, which improves the model's performance. This process is __repeated until no more improvement is observed__  <p>
#
# For the regressions we used scalled data.

# %% [markdown]
# **Recursive Feature Elimination (RFE)**

# %% [markdown]
# <div style="background-color: #ffe6cc; color: #cc000; padding: 10px;">
# * Here we are using RFECV instead of RFE as we want to automatically determine the optimal number of features to keep. It performs the feature selection recursively by considering different subsets of features and evaluates their performance using cross-validation. Eliminates the need to specify the number of features to keep manually,  as it automatically selects the optimal number based on the cross-validated performance.
# </div>

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd

def apply_rfecv(X_train, y_train):
    rfecv = RFECV(estimator=LogisticRegression(random_state=42), min_features_to_select=5)
    rfecv.fit(X_train, y_train)
    selected_features = pd.Series(rfecv.support_, index=X_train.columns)
    return selected_features

# Prepare StratifiedKFold instance
skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)

# Fit the scaler on the entire training set
scaler = MinMaxScaler()

# Apply RFECV on each fold
rfe_results = pd.DataFrame()
rfe_results['Features'] = X.columns
rfe_feat_count = {}  # Dictionary to store counts for RFECV

for train_index, val_index in skf.split(X, y):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Select numerical features
    X_train_num = X_train.select_dtypes(include=[np.number])

    ########## Scale the numerical features using MinMaxScaler ##########
    scaler.fit(X_train_num)
    X_train_scaled = scaler.transform(X_train_num)
    X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_num.columns)

    # Apply RFECV on scaled data
    selected_features = apply_rfecv(X_train_scaled, y_train)

    for feature, selected in selected_features.items():
        if selected:
            if feature in rfe_feat_count:
                rfe_feat_count[feature] += 1
            else:
                rfe_feat_count[feature] = 1

# Add 'RFECV_Significant_Count' column to rfe_results
rfe_results['RFECV_Significant_Count'] = rfe_results['Features'].apply(lambda x: rfe_feat_count.get(x, 0))

# Add 'Wrapper_RFECV' column
rfe_results['Wrapper_RFECV'] = rfe_results['RFECV_Significant_Count'].apply(lambda count: 'Keep' if count >= 3 else 'Remove')
rfe_results.loc[~rfe_results['Features'].apply(lambda x: X[x].dtypes in [np.number, np.float64, np.int64]), 'Wrapper_RFECV'] = ''

# Print the results
print(rfe_results)
# Out:
#                              Features  RFECV_Significant_Count Wrapper_RFECV
# 0                                 Age                        2        Remove
# 1                            Under 30                        1        Remove
# 2                      Senior Citizen                        3          Keep
# 3                             Married                        3          Keep
# 4                          Dependents                        5          Keep
# 5                Number of Dependents                        1        Remove
# 6                   Referred a Friend                        4          Keep
# 7                 Number of Referrals                        5          Keep
# 8                    Tenure in Months                        3          Keep
# 9                     Tenure Category                        5          Keep
# 10                      Phone Service                        3          Keep
# 11  Avg Monthly Long Distance Charges                        1        Remove
# 12                     Multiple Lines                        2        Remove
# 13                   Internet Service                        3          Keep
# 14            Avg Monthly GB Download                        1        Remove
# 15                    Online Security                        5          Keep
# 16                      Online Backup                        2        Remove
# 17             Device Protection Plan                        2        Remove
# 18               Premium Tech Support                        2        Remove
# 19                       Streaming TV                        0        Remove
# 20                   Streaming Movies                        3          Keep
# 21                    Streaming Music                        3          Keep
# 22                     Unlimited Data                        1        Remove
# 23                  Paperless Billing                        2        Remove
# 24                     Monthly Charge                        5          Keep
# 25                      Total Charges                        0        Remove
# 26                      Total Refunds                        2        Remove
# 27           Total Extra Data Charges                        2        Remove
# 28        Total Long Distance Charges                        3          Keep
# 29                      Total Revenue                        1        Remove
# 30                 Satisfaction Score                        5          Keep
# 31                        Churn Score                        5          Keep
# 32                               CLTV                        2        Remove
# 33                         Population                        0        Remove
# 34                   Engagement Score                        2        Remove
# 35                        Gender_Male                        1        Remove
# 36                      Offer_Offer A                        3          Keep
# 37                      Offer_Offer B                        1        Remove
# 38                      Offer_Offer C                        0        Remove
# 39                      Offer_Offer D                        2        Remove
# 40                      Offer_Offer E                        3          Keep
# 41                Internet Type_Cable                        2        Remove
# 42                  Internet Type_DSL                        0        Remove
# 43          Internet Type_Fiber Optic                        2        Remove
# 44     Payment Method_Bank Withdrawal                        2        Remove
# 45         Payment Method_Credit Card                        4          Keep
# 46                       Density_High                        2        Remove
# 47                        Density_Low                        2        Remove
# 48            Contract_Month-to-Month                        4          Keep
# 49                  Contract_One Year                        1        Remove
# 50                  Contract_Two Year                        4          Keep

# %% [markdown]
# __Notes:__
#
# Using FRE and SFS we conclude the following features as being the most important to keep:
#
# > - __RFE:__ <p>
#     >> - True in all 5 splits: Dependents, Number of Referrals, Online Security, Monthly Charge, Satisfaction Score, Churn Score<p>
#     >> - True in 4 out of 5 splits: Contract_Two Year,Contract_Month-to-Month, Referred a Friend <p>

# %% [markdown]
# ***
# ## Embedded Methods
# Learn which features best contribute to the accuracy of the model while the model is being created<p>
#
# Embedded methods combine the best features of filtering and wrapping methods by implementing algorithms with built-in methods for selecting features, standard embedded methods are: <p>
#
# > * __Lasso regularization__ - `For continous and ordinal data` __Adds penalty on different parameter to reduce freedom, thus it is less likely to fit noise of training data__ / overfit hence improves generalisation. Lasso Regression apart from preventing overfitting also __reduces the coefficients of less important features to zero__. <p>
#
# Do not apply to binary variables. Scale the data before as this is a regression.

# %%
#def apply_lasso(X_train, y_train, subplot_index):
#    X_train = X_train.drop(['Response_Cmp2', 'Response_Cmp3','Response_Cmp4','Response_Cmp5','Response_Cmp1','Complain'], axis = 1)
#    lasso = LassoCV().fit(X_train, y_train)
#    coef = pd.Series(lasso.coef_, index = X_train.columns)
#    abs_coef = coef.abs()  # Compute absolute values of coefficients
#    plot_importance(abs_coef,'Lasso', subplot_index)  # pass abs_coef instead of coef
#    return abs_coef  # return abs_coef


def apply_lasso(X_train, y_train, subplot_index, display_plot=True):
    lasso = LassoCV().fit(X_train, y_train)
    coef = pd.Series(lasso.coef_, index = X_train.columns)
    abs_coef = coef.abs()  # Compute absolute values of coefficients
    if display_plot:
        plot_importance(abs_coef,'Lasso', subplot_index)  # pass abs_coef instead of coef
    return abs_coef  # return abs_coef

# %%
def select_best_features_lasso(X, y, display_plot=True):
    count = 1
    fig = plt.figure(figsize=(35, 20))  # Create a figure to contain the subplots
    skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)
    ranking_scores = pd.DataFrame(index=X.columns)  # Create a DataFrame to store the ranking scores

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        # Select numerical features for Lasso
        X_train_num = X_train.select_dtypes(include=[np.number])

        # Scale the numerical features
        scaler = MinMaxScaler().fit(X_train_num)
        X_train_scaled = scaler.transform(X_train_num)
        X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_num.columns)

        # Apply Lasso to scaled numerical features
        feature_importances = apply_lasso(X_train_scaled, y_train, count, display_plot)

        # Store the feature importances in the ranking_scores DataFrame
        ranking_scores[f'Split {count}'] = feature_importances

        count += 1

    if display_plot:
        plt.suptitle("Feature Importance using Lasso Model", fontsize=12, fontweight='bold')  # Overall title above the subplots
        plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout of the subplots and overall title
        plt.show()

    # Create the lasso_results DataFrame
    lasso_results = ranking_scores.copy()

    # Determine 'Keep' or 'Remove' based on the significant count
    lasso_results['Lasso_Significant_Count'] = (lasso_results >= 0.1).sum(axis=1)
    lasso_results['Embedded_Lasso'] = np.where(lasso_results['Lasso_Significant_Count'] >= 3, 'Keep', 'Remove')

    return lasso_results
select_best_features_lasso(X, y, True)
# Out:
#                                     Split 1   Split 2   Split 3   Split 4  \
# Age                                0.028723  0.013209  0.017006  0.000000
# Under 30                           0.000000  0.002429  0.000000  0.000000
# Senior Citizen                     0.007750  0.028350  0.017616  0.035338
# Married                            0.030009  0.039752  0.036206  0.023034
# Dependents                         0.054193  0.059539  0.065016  0.051642
# Number of Dependents               0.000000  0.000000  0.032097  0.000000
# Referred a Friend                  0.030511  0.023503  0.026058  0.039480
# Number of Referrals                0.133162  0.124724  0.138772  0.136181
# Tenure in Months                   0.011252  0.002560  0.058116  0.000000
# Tenure Category                    0.081384  0.065767  0.100682  0.047121
# Phone Service                      0.051881  0.031286  0.040226  0.037675
# Avg Monthly Long Distance Charges  0.000000  0.011167  0.024285  0.004551
# Multiple Lines                     0.000000  0.003296  0.013330  0.000000
# Internet Service                   0.000000  0.001328  0.000000  0.000000
# Avg Monthly GB Download            0.000000  0.000000  0.009708  0.000000
# Online Security                    0.139361  0.139983  0.146483  0.140933
# Online Backup                      0.016373  0.015213  0.014221  0.012958
# Device Protection Plan             0.000011  0.000136  0.002625  0.001840
# Premium Tech Support               0.029123  0.026091  0.031134  0.026212
# Streaming TV                       0.005719  0.012881  0.009439  0.009494
# Streaming Movies                   0.018182  0.023446  0.020608  0.015657
# Streaming Music                    0.024543  0.023139  0.027165  0.021820
# Unlimited Data                     0.015756  0.012905  0.013427  0.008360
# Paperless Billing                  0.012563  0.008726  0.012809  0.016652
# Monthly Charge                     0.173933  0.175504  0.196409  0.162938
# Total Charges                      0.075738  0.102885  0.152129  0.117828
# Total Refunds                      0.020316  0.013798  0.010459  0.025977
# Total Extra Data Charges           0.000000  0.000000  0.000000  0.000000
# Total Long Distance Charges        0.024296  0.015092  0.035727  0.004899
# Total Revenue                      0.000000  0.000000  0.000000  0.000000
# Satisfaction Score                 0.773529  0.774892  0.766476  0.765962
# Churn Score                        0.561142  0.563098  0.543243  0.550695
# CLTV                               0.009588  0.008779  0.000000  0.005615
# Population                         0.022813  0.031215  0.034912  0.036423
# Engagement Score                   0.000000  0.000000  0.000000  0.000000
# Gender_Male                        0.012031  0.010519  0.007010  0.010827
# Offer_Offer A                      0.031733  0.034565  0.032920  0.042176
# Offer_Offer B                      0.003987  0.015825  0.006294  0.007417
# Offer_Offer C                      0.019837  0.024840  0.024915  0.028302
# Offer_Offer D                      0.032809  0.035860  0.034410  0.035795
# Offer_Offer E                      0.031108  0.025742  0.039891  0.035078
# Internet Type_Cable                0.005082  0.010700  0.007046  0.000000
# Internet Type_DSL                  0.004486  0.004381  0.003815  0.005836
# Internet Type_Fiber Optic          0.000000  0.000000  0.000000  0.000000
# Payment Method_Bank Withdrawal     0.018388  0.024412  0.014308  0.015760
# Payment Method_Credit Card         0.034336  0.046515  0.035263  0.043113
# Density_High                       0.009617  0.000000  0.012328  0.000000
# Density_Low                        0.008654  0.006806  0.001851  0.001789
# Contract_Month-to-Month            0.064647  0.059074  0.057512  0.067794
# Contract_One Year                  0.000000  0.000000  0.000000  0.000000
# Contract_Two Year                  0.016639  0.014844  0.017580  0.011533
#
#                                     Split 5  Lasso_Significant_Count  \
# Age                                0.009687                        0
# Under 30                           0.000000                        0
# Senior Citizen                     0.025503                        0
# Married                            0.034759                        0
# Dependents                         0.052100                        0
# Number of Dependents               0.001951                        0
# Referred a Friend                  0.024083                        0
# Number of Referrals                0.138841                        5
# Tenure in Months                   0.069947                        0
# Tenure Category                    0.098298                        1
# Phone Service                      0.050493                        0
# Avg Monthly Long Distance Charges  0.009062                        0
# Multiple Lines                     0.013825                        0
# Internet Service                   0.000000                        0
# Avg Monthly GB Download            0.009185                        0
# Online Security                    0.139195                        5
# Online Backup                      0.023053                        0
# Device Protection Plan             0.003483                        0
# Premium Tech Support               0.029929                        0
# Streaming TV                       0.005381                        0
# Streaming Movies                   0.018046                        0
# Streaming Music                    0.031626                        0
# Unlimited Data                     0.006131                        0
# Paperless Billing                  0.011052                        0
# Monthly Charge                     0.193399                        5
# Total Charges                      0.156405                        4
# Total Refunds                      0.011135                        0
# Total Extra Data Charges           0.000000                        0
# Total Long Distance Charges        0.019994                        0
# Total Revenue                      0.000000                        0
# Satisfaction Score                 0.760356                        5
# Churn Score                        0.566915                        5
# CLTV                               0.004021                        0
# Population                         0.037204                        0
# Engagement Score                   0.000000                        0
# Gender_Male                        0.007493                        0
# Offer_Offer A                      0.031478                        0
# Offer_Offer B                      0.009423                        0
# Offer_Offer C                      0.023847                        0
# Offer_Offer D                      0.035633                        0
# Offer_Offer E                      0.035297                        0
# Internet Type_Cable                0.014282                        0
# Internet Type_DSL                  0.008592                        0
# Internet Type_Fiber Optic          0.000000                        0
# Payment Method_Bank Withdrawal     0.022329                        0
# Payment Method_Credit Card         0.043667                        0
# Density_High                       0.004117                        0
# Density_Low                        0.000000                        0
# Contract_Month-to-Month            0.054292                        0
# Contract_One Year                  0.000000                        0
# Contract_Two Year                  0.018670                        0
#
#                                   Embedded_Lasso
# Age                                       Remove
# Under 30                                  Remove
# Senior Citizen                            Remove
# Married                                   Remove
# Dependents                                Remove
# Number of Dependents                      Remove
# Referred a Friend                         Remove
# Number of Referrals                         Keep
# Tenure in Months                          Remove
# Tenure Category                           Remove
# Phone Service                             Remove
# Avg Monthly Long Distance Charges         Remove
# Multiple Lines                            Remove
# Internet Service                          Remove
# Avg Monthly GB Download                   Remove
# Online Security                             Keep
# Online Backup                             Remove
# Device Protection Plan                    Remove
# Premium Tech Support                      Remove
# Streaming TV                              Remove
# Streaming Movies                          Remove
# Streaming Music                           Remove
# Unlimited Data                            Remove
# Paperless Billing                         Remove
# Monthly Charge                              Keep
# Total Charges                               Keep
# Total Refunds                             Remove
# Total Extra Data Charges                  Remove
# Total Long Distance Charges               Remove
# Total Revenue                             Remove
# Satisfaction Score                          Keep
# Churn Score                                 Keep
# CLTV                                      Remove
# Population                                Remove
# Engagement Score                          Remove
# Gender_Male                               Remove
# Offer_Offer A                             Remove
# Offer_Offer B                             Remove
# Offer_Offer C                             Remove
# Offer_Offer D                             Remove
# Offer_Offer E                             Remove
# Internet Type_Cable                       Remove
# Internet Type_DSL                         Remove
# Internet Type_Fiber Optic                 Remove
# Payment Method_Bank Withdrawal            Remove
# Payment Method_Credit Card                Remove
# Density_High                              Remove
# Density_Low                               Remove
# Contract_Month-to-Month                   Remove
# Contract_One Year                         Remove
# Contract_Two Year                         Remove

# %% [markdown]
# __Notes:__
#
# Using the Lasso Method and again the Random Forest we conclude the following features as being the most important to keep:
#
# > - __Lasso:(threshold higher than 0.1 coefficient)__ <p>
#     >> - True in all 5 splits: Number of Referrals, Online Security, Monthly Charge, Satisfaction Score, Churn Score<p>
# > - __Random Forest: (threshold higher than 0.02)__ <p>
#     >> - True in all 5 splits: Number of Referrals, Tenure in Months, Monthly Charge, Satisfaction Score, Churn Score, Contract_Month-to-Month, Contract_Two Year<p>

# %%
def apply_rf(X_train, y_train, subplot_index):
    rf = RandomForestClassifier(criterion='entropy', random_state=99).fit(X_train, y_train)
    feature_importances = pd.Series(rf.feature_importances_, index=X_train.columns)
    return feature_importances

def select_best_features_rf(X, y):
    count = 1
    skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)
    ranking_scores = pd.DataFrame(index=X.columns)  # Create a DataFrame to store the ranking scores

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        # Select numerical features for random forest
        X_train_num = X_train.select_dtypes(include=[np.number])

        # Scale the numerical features
        scaler = MinMaxScaler().fit(X_train_num)
        X_train_scaled = scaler.transform(X_train_num)
        X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_num.columns)

        # Apply random forest to scaled numerical features
        feature_importances = apply_rf(X_train_scaled, y_train, count)

        # Store the feature importances in the ranking_scores DataFrame
        ranking_scores[f'Split {count}'] = feature_importances

        count += 1

    # Create the RF_results DataFrame
    RF_results = ranking_scores.copy()

    # Determine 'Keep' or 'Remove' based on the significant count
    RF_results['RF_Significant_Count'] = (RF_results >= 0.02).sum(axis=1)   # Threshold of 0.04 to count as significant
    RF_results['Embedded_RF'] = np.where(RF_results['RF_Significant_Count'] >= 3, 'Keep', 'Remove')

    return RF_results

RF_results = select_best_features_rf(X, y)
RF_results
# Out:
#                                     Split 1   Split 2   Split 3   Split 4  \
# Age                                0.013842  0.015127  0.014261  0.014681
# Under 30                           0.001240  0.001278  0.001293  0.001316
# Senior Citizen                     0.005943  0.005642  0.004198  0.004266
# Married                            0.002221  0.002228  0.002175  0.001808
# Dependents                         0.012580  0.011215  0.010329  0.010174
# Number of Dependents               0.010609  0.009255  0.008729  0.008961
# Referred a Friend                  0.002156  0.002666  0.002740  0.002280
# Number of Referrals                0.029326  0.024385  0.030421  0.029950
# Tenure in Months                   0.022667  0.022803  0.020699  0.022530
# Tenure Category                    0.017530  0.017797  0.018909  0.017309
# Phone Service                      0.000833  0.000663  0.000603  0.000447
# Avg Monthly Long Distance Charges  0.009935  0.009781  0.009344  0.009141
# Multiple Lines                     0.001861  0.001938  0.001956  0.001882
# Internet Service                   0.003284  0.006010  0.004717  0.003644
# Avg Monthly GB Download            0.013987  0.015326  0.015442  0.016213
# Online Security                    0.007078  0.009049  0.009814  0.008499
# Online Backup                      0.001611  0.001622  0.001555  0.001484
# Device Protection Plan             0.001642  0.001264  0.001235  0.001361
# Premium Tech Support               0.002370  0.003913  0.002697  0.002035
# Streaming TV                       0.001649  0.001826  0.002025  0.001736
# Streaming Movies                   0.001521  0.001975  0.001785  0.001501
# Streaming Music                    0.002621  0.002116  0.002581  0.002261
# Unlimited Data                     0.001473  0.001741  0.001661  0.001743
# Paperless Billing                  0.003574  0.002758  0.004116  0.003323
# Monthly Charge                     0.023479  0.022253  0.023935  0.020062
# Total Charges                      0.018959  0.017191  0.015875  0.015165
# Total Refunds                      0.001100  0.001536  0.001445  0.001575
# Total Extra Data Charges           0.002479  0.002325  0.001680  0.002280
# Total Long Distance Charges        0.013919  0.014236  0.013721  0.013552
# Total Revenue                      0.018008  0.019830  0.020511  0.017926
# Satisfaction Score                 0.338886  0.355757  0.333932  0.359375
# Churn Score                        0.271307  0.258169  0.273730  0.260354
# CLTV                               0.010732  0.011849  0.010934  0.011646
# Population                         0.011823  0.011227  0.011713  0.010946
# Engagement Score                   0.006253  0.006776  0.007678  0.006403
# Gender_Male                        0.001862  0.001790  0.001929  0.001811
# Offer_Offer A                      0.000338  0.000291  0.000367  0.000423
# Offer_Offer B                      0.001008  0.001046  0.001299  0.000771
# Offer_Offer C                      0.001184  0.000782  0.000606  0.000636
# Offer_Offer D                      0.001181  0.000860  0.001079  0.000704
# Offer_Offer E                      0.001899  0.001644  0.001941  0.002729
# Internet Type_Cable                0.000902  0.001088  0.000921  0.000848
# Internet Type_DSL                  0.001585  0.002105  0.002052  0.001960
# Internet Type_Fiber Optic          0.012770  0.011708  0.012111  0.011241
# Payment Method_Bank Withdrawal     0.002419  0.003034  0.003120  0.003423
# Payment Method_Credit Card         0.004755  0.004822  0.005231  0.006155
# Density_High                       0.001952  0.001588  0.001978  0.001555
# Density_Low                        0.001516  0.001528  0.001641  0.001628
# Contract_Month-to-Month            0.048829  0.045792  0.045602  0.050771
# Contract_One Year                  0.006076  0.005286  0.005864  0.005591
# Contract_Two Year                  0.023226  0.023106  0.025816  0.021926
#
#                                     Split 5  RF_Significant_Count Embedded_RF
# Age                                0.016154                     0      Remove
# Under 30                           0.001183                     0      Remove
# Senior Citizen                     0.006029                     0      Remove
# Married                            0.002533                     0      Remove
# Dependents                         0.011160                     0      Remove
# Number of Dependents               0.009179                     0      Remove
# Referred a Friend                  0.001937                     0      Remove
# Number of Referrals                0.030427                     5        Keep
# Tenure in Months                   0.020338                     5        Keep
# Tenure Category                    0.018926                     0      Remove
# Phone Service                      0.000771                     0      Remove
# Avg Monthly Long Distance Charges  0.010639                     0      Remove
# Multiple Lines                     0.002296                     0      Remove
# Internet Service                   0.005589                     0      Remove
# Avg Monthly GB Download            0.016079                     0      Remove
# Online Security                    0.007315                     0      Remove
# Online Backup                      0.001803                     0      Remove
# Device Protection Plan             0.001378                     0      Remove
# Premium Tech Support               0.003334                     0      Remove
# Streaming TV                       0.002096                     0      Remove
# Streaming Movies                   0.002159                     0      Remove
# Streaming Music                    0.002508                     0      Remove
# Unlimited Data                     0.001773                     0      Remove
# Paperless Billing                  0.003073                     0      Remove
# Monthly Charge                     0.023294                     5        Keep
# Total Charges                      0.017058                     0      Remove
# Total Refunds                      0.001826                     0      Remove
# Total Extra Data Charges           0.002337                     0      Remove
# Total Long Distance Charges        0.014530                     0      Remove
# Total Revenue                      0.017142                     1      Remove
# Satisfaction Score                 0.329159                     5        Keep
# Churn Score                        0.273361                     5        Keep
# CLTV                               0.011941                     0      Remove
# Population                         0.011247                     0      Remove
# Engagement Score                   0.007284                     0      Remove
# Gender_Male                        0.002223                     0      Remove
# Offer_Offer A                      0.000285                     0      Remove
# Offer_Offer B                      0.001039                     0      Remove
# Offer_Offer C                      0.000830                     0      Remove
# Offer_Offer D                      0.000806                     0      Remove
# Offer_Offer E                      0.002276                     0      Remove
# Internet Type_Cable                0.000746                     0      Remove
# Internet Type_DSL                  0.001816                     0      Remove
# Internet Type_Fiber Optic          0.012321                     0      Remove
# Payment Method_Bank Withdrawal     0.002150                     0      Remove
# Payment Method_Credit Card         0.004731                     0      Remove
# Density_High                       0.001639                     0      Remove
# Density_Low                        0.001595                     0      Remove
# Contract_Month-to-Month            0.047889                     5        Keep
# Contract_One Year                  0.006076                     0      Remove
# Contract_Two Year                  0.025723                     5        Keep

# %% [markdown]
# [BACK TO TOC](#toc)
#
# <div class="alert alert-block alert-success">
# <a id='decision'>
# <font color = '#006400'>
#
# # 5. Feature Decision </font>
# </a>
#
# </div>
#
# Merging all data and create 5 different scenarios

# %%
# Merge the results
merged_results = filtered.merge(rfe_results, on='Features', how='outer')

# Store Lasso results in lasso_results variable
lasso_results = select_best_features_lasso(X, y, False).reset_index()

# Merge Lasso results
merged_results = merged_results.merge(lasso_results[['index', 'Embedded_Lasso']], left_on='Features', right_on='index', how='outer').drop(columns=['index'])

# Store RF results in RF_results variable
RF_results = select_best_features_rf(X, y).reset_index()

# Merge RF results
merged_results = merged_results.merge(RF_results[['index', 'Embedded_RF']], left_on='Features', right_on='index', how='outer').drop(columns=['index'])

# Remove the unnecessary columns
merged_results = merged_results.drop(columns=['Kendall_Significant_Count',
                                              'ANOVA_Significant_Count',
                                              'CHI2_Significant_Count',
                                              'RFECV_Significant_Count',])

# Rename the columns for clarity
merged_results = merged_results.rename(columns={
    'Filter_Kendall': 'Filter_Kendall',
    'Filter_ANOVA': 'Filter_ANOVA',
    'Filter_CHI2': 'Filter_CHI2',
    'Wrapper_RFECV': 'Wrapper_RFECV',
    'Embedded_Lasso': 'Embedded_Lasso',
    'Embedded_RF': 'Embedded_RF'
})

# Set '-' for missing values
merged_results = merged_results.fillna('-')

# Modify values for rows where Features are 'Education' and 'Marital_Status'
merged_results.loc[merged_results['Features'].isin(['Education', 'Marital_Status']), 
                   merged_results.columns.difference(['Features', 'Filter_CHI2'])] = '-'

# Only keep the rows where Filter_CHI2 and Embedded_Lasso have valid values (not '-')
filtered_merged_results = merged_results.loc[(merged_results['Filter_CHI2'] != '-') | (merged_results['Embedded_Lasso'] != '-')]

# Count 'keep' values by row
filtered_merged_results['Keep_Count'] = filtered_merged_results.apply(lambda row: row.str.count('Keep').sum(), axis=1)

# Sort the dataframe by 'Keep_Count' column in descending order
filtered_merged_results = filtered_merged_results.sort_values(by='Keep_Count', ascending=False)

# Display the sorted dataframe
filtered_merged_results
# Out:
#                              Features Filter_Kendall Filter_ANOVA Filter_CHI2  \
# 30                 Satisfaction Score           Keep         Keep     Discard
# 31                        Churn Score           Keep         Keep     Discard
# 50                  Contract_Two Year        Discard         Keep        Keep
# 7                 Number of Referrals        Discard         Keep     Discard
# 15                    Online Security        Discard         Keep        Keep
# 48            Contract_Month-to-Month        Discard         Keep        Keep
# 24                     Monthly Charge        Discard         Keep     Discard
# 6                   Referred a Friend        Discard         Keep        Keep
# 36                      Offer_Offer A        Discard         Keep        Keep
# 2                      Senior Citizen        Discard         Keep        Keep
# 3                             Married        Discard         Keep        Keep
# 45         Payment Method_Credit Card        Discard         Keep        Keep
# 21                    Streaming Music        Discard         Keep        Keep
# 13                   Internet Service        Discard         Keep        Keep
# 20                   Streaming Movies        Discard         Keep        Keep
# 4                          Dependents        Discard         Keep        Keep
# 8                    Tenure in Months        Discard         Keep     Discard
# 40                      Offer_Offer E        Discard         Keep        Keep
# 42                  Internet Type_DSL        Discard         Keep        Keep
# 37                      Offer_Offer B        Discard         Keep        Keep
# 43          Internet Type_Fiber Optic        Discard         Keep        Keep
# 28        Total Long Distance Charges        Discard         Keep     Discard
# 46                       Density_High        Discard         Keep        Keep
# 49                  Contract_One Year        Discard         Keep        Keep
# 44     Payment Method_Bank Withdrawal        Discard         Keep        Keep
# 25                      Total Charges        Discard         Keep     Discard
# 17             Device Protection Plan        Discard         Keep        Keep
# 1                            Under 30        Discard         Keep        Keep
# 23                  Paperless Billing        Discard         Keep        Keep
# 22                     Unlimited Data        Discard         Keep        Keep
# 9                     Tenure Category        Discard         Keep     Discard
# 12                     Multiple Lines        Discard         Keep        Keep
# 19                       Streaming TV        Discard         Keep        Keep
# 18               Premium Tech Support        Discard         Keep        Keep
# 16                      Online Backup        Discard         Keep        Keep
# 26                      Total Refunds        Discard         Keep     Discard
# 5                Number of Dependents        Discard         Keep     Discard
# 10                      Phone Service        Discard      Discard     Discard
# 14            Avg Monthly GB Download        Discard         Keep     Discard
# 0                                 Age        Discard         Keep     Discard
# 33                         Population        Discard         Keep     Discard
# 32                               CLTV        Discard         Keep     Discard
# 29                      Total Revenue        Discard         Keep     Discard
# 39                      Offer_Offer D        Discard      Discard     Discard
# 41                Internet Type_Cable        Discard      Discard     Discard
# 27           Total Extra Data Charges        Discard      Discard     Discard
# 35                        Gender_Male        Discard      Discard     Discard
# 34                   Engagement Score        Discard      Discard     Discard
# 11  Avg Monthly Long Distance Charges        Discard      Discard     Discard
# 47                        Density_Low        Discard      Discard     Discard
# 38                      Offer_Offer C        Discard      Discard     Discard
#
#    Wrapper_RFECV Embedded_Lasso Embedded_RF  Keep_Count
# 30          Keep           Keep        Keep           5
# 31          Keep           Keep        Keep           5
# 50          Keep         Remove        Keep           4
# 7           Keep           Keep        Keep           4
# 15          Keep           Keep      Remove           4
# 48          Keep         Remove        Keep           4
# 24          Keep           Keep        Keep           4
# 6           Keep         Remove      Remove           3
# 36          Keep         Remove      Remove           3
# 2           Keep         Remove      Remove           3
# 3           Keep         Remove      Remove           3
# 45          Keep         Remove      Remove           3
# 21          Keep         Remove      Remove           3
# 13          Keep         Remove      Remove           3
# 20          Keep         Remove      Remove           3
# 4           Keep         Remove      Remove           3
# 8           Keep         Remove        Keep           3
# 40          Keep         Remove      Remove           3
# 42        Remove         Remove      Remove           2
# 37        Remove         Remove      Remove           2
# 43        Remove         Remove      Remove           2
# 28          Keep         Remove      Remove           2
# 46        Remove         Remove      Remove           2
# 49        Remove         Remove      Remove           2
# 44        Remove         Remove      Remove           2
# 25        Remove           Keep      Remove           2
# 17        Remove         Remove      Remove           2
# 1         Remove         Remove      Remove           2
# 23        Remove         Remove      Remove           2
# 22        Remove         Remove      Remove           2
# 9           Keep         Remove      Remove           2
# 12        Remove         Remove      Remove           2
# 19        Remove         Remove      Remove           2
# 18        Remove         Remove      Remove           2
# 16        Remove         Remove      Remove           2
# 26        Remove         Remove      Remove           1
# 5         Remove         Remove      Remove           1
# 10          Keep         Remove      Remove           1
# 14        Remove         Remove      Remove           1
# 0         Remove         Remove      Remove           1
# 33        Remove         Remove      Remove           1
# 32        Remove         Remove      Remove           1
# 29        Remove         Remove      Remove           1
# 39        Remove         Remove      Remove           0
# 41        Remove         Remove      Remove           0
# 27        Remove         Remove      Remove           0
# 35        Remove         Remove      Remove           0
# 34        Remove         Remove      Remove           0
# 11        Remove         Remove      Remove           0
# 47        Remove         Remove      Remove           0
# 38        Remove         Remove      Remove           0

# %%
# Select the top 15 rows
top_15_results = filtered_merged_results.head(15)

# Sort the dataframe by 'Keep_Count' column in descending order
top_15_results = top_15_results.sort_values(by='Keep_Count', ascending=True)

# Create a horizontal bar graph with soft green color and no background
fig, ax = plt.subplots(figsize=(8, 4))
bars = ax.barh(top_15_results['Features'], top_15_results['Keep_Count'], color='#B0C726')

# Label the bars with their values
for bar in bars:
    xval = bar.get_width()
    ax.text(xval, bar.get_y() + bar.get_height()/2, round(xval, 2), va='center', ha='left')

# Turn off the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Remove x and y axis lines
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')

plt.xlabel('Features importance by methods')
plt.title('Top Features')
plt.savefig('outputs/output_plot.png', bbox_inches='tight', transparent=True)
plt.show()

# %% [markdown]
# __`Which variables should we keep using this techniques?`__ <p>
# __Notes:__
#
# > 1 - For categorical variables the choice is obvious, __Marital_Status__  will be kept and __Education__ dropped. <p>
# > 2 - For numerical variables:
#     >> - __# 1 Keep always__: Satisfaction Score, Churn Score, Contract_Month-to-Month, Number of Referrals	, Online Security , Monthly Charge<p>
#     >> - __# 2 Keep almost always__ Satisfaction Score, Churn Score, Contract_Month-to-Month, Number of Referrals , Online Security	, Monthly Charge, Offer_Offer E, Offer_Offer A, Contract_Two Year<p>

# %%
scenario1_td = df[['Satisfaction Score', 'Churn Score', 'Contract_Month-to-Month', 'Number of Referrals' , 'Online Security' , 'Monthly Charge']].copy()

scenario2_td = df[['Satisfaction Score', 'Churn Score', 'Contract_Month-to-Month', 'Number of Referrals' , 'Online Security' , 'Monthly Charge', 'Offer_Offer E', 'Offer_Offer A', 'Contract_Two Year']].copy()

# %% [markdown]
# **Export to CSV**

# %%
#scenario1_td.to_csv('data/processed/scenario1_v2.csv')
#scenario2_td.to_csv('data/processed/scenario2_v2.csv')
