# %% [markdown]
# # Feature Selection
#
# [1. Import data (Data Integration)](#1st-bullet)<br>
# [2. Explore data (Data Access, Exploration and Understanding)](#2nd-bullet)<br>
# [3. Modify data (Data Preparation)](#3rd-bullet)<br>
# - [3.1. Feature Selection](#4th-bullet)<br>
#     - [3.1.1. Categorical Variables](#5th-bullet)<br>
#         - [3.1.1.1. Chi-Square](#6th-bullet)<br>
#     - [3.1.2 Numerical Variables](#7th-bullet)<br>
#         - [3.1.2.1. Variance](#8th-bullet)<br>
#         - [3.1.2.2. Spearman Correlation](#9th-bullet)<br>
#         - [3.1.2.3. Feature Importance in Decision Trees](#10th-bullet)<br>
#         - [3.1.2.4. Recursive Feature Elimination with Logistic Regression](#11th-bullet)<br>
#         - [3.1.2.5. Lasso Regression](#12th-bullet)<br>
#
#
# <img src="Images/process_ML.png" style="height:70px">

# %% [markdown]
# __`Step 1`__ Import all the needed libraries.

# %%
# import needed libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

############################################ FEATURE SELECTION ############################################
#!pip install scipy
import scipy.stats as stats
from scipy.stats import chi2_contingency # filter method
from sklearn.feature_selection import RFE # wrapper method
from sklearn.linear_model import LogisticRegression #(This is one possible model to apply inside RFE)
from sklearn.linear_model import LassoCV # embedded method
from sklearn.tree import DecisionTreeClassifier # embedded method
from scipy.stats import spearmanr
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import f_classif
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a class="anchor" id="1st-bullet">
#
# # 1. Import data (Data Integration)
#
# </a>
#
# <img src="Images/step1.png" style="height:70px">

# %% [markdown]
# __`Step 2`__ Import the train dataset and define the index as the `Custid`.

# %%
data = pd.read_csv(r'df_clustered.csv')
data.set_index('Customer ID', inplace = True)
data.head(5)
# Out:
#                   Age  Under 30  Senior Citizen  Married  Dependents
# Customer ID
# 8779-QRDMV   0.967213         0               1        0           0  \
# 7495-OOKFY   0.901639         0               1        1           1
# 1658-BYGOY   0.852459         0               1        0           1
# 4598-XLKNJ   0.967213         0               1        1           1
# 4846-WHAFZ   1.000000         0               1        1           1
#
#              Number of Dependents         City  Referred a Friend
# Customer ID
# 8779-QRDMV               0.000000  Los Angeles                  0  \
# 7495-OOKFY               0.111111  Los Angeles                  1
# 1658-BYGOY               0.333333  Los Angeles                  0
# 4598-XLKNJ               0.111111    Inglewood                  1
# 4846-WHAFZ               0.111111     Whittier                  1
#
#              Number of Referrals  Tenure in Months  Tenure Category
# Customer ID
# 8779-QRDMV              0.000000          0.000000             0.00  \
# 7495-OOKFY              0.090909          0.098592             0.25
# 1658-BYGOY              0.000000          0.239437             0.50
# 4598-XLKNJ              0.090909          0.338028             0.50
# 4846-WHAFZ              0.090909          0.507042             0.75
#
#              Phone Service  Avg Monthly Long Distance Charges  Multiple Lines
# Customer ID
# 8779-QRDMV               0                           0.000000               0  \
# 7495-OOKFY               1                           0.977195               1
# 1658-BYGOY               1                           0.226645               1
# 4598-XLKNJ               1                           0.395279               0
# 4846-WHAFZ               1                           0.126625               1
#
#              Internet Service  Avg Monthly GB Download  Online Security
# Customer ID
# 8779-QRDMV                  1                 0.094118                0  \
# 7495-OOKFY                  1                 0.200000                0
# 1658-BYGOY                  1                 0.611765                0
# 4598-XLKNJ                  1                 0.141176                0
# 4846-WHAFZ                  1                 0.164706                0
#
#              Online Backup  Device Protection Plan  Premium Tech Support
# Customer ID
# 8779-QRDMV               0                       1                     0  \
# 7495-OOKFY               1                       0                     0
# 1658-BYGOY               0                       0                     0
# 4598-XLKNJ               1                       1                     0
# 4846-WHAFZ               0                       0                     0
#
#              Streaming TV  Streaming Movies  Streaming Music  Unlimited Data
# Customer ID
# 8779-QRDMV              0                 1                0               0  \
# 7495-OOKFY              0                 0                0               1
# 1658-BYGOY              1                 1                1               1
# 4598-XLKNJ              1                 1                0               1
# 4846-WHAFZ              0                 0                0               1
#
#              Paperless Billing  Monthly Charge  Total Charges  Total Refunds
# Customer ID
# 8779-QRDMV                   1        0.212935       0.002406       0.000000  \
# 7495-OOKFY                   1        0.620896       0.070909       0.000000
# 1658-BYGOY                   1        0.768159       0.200063       0.916047
# 4598-XLKNJ                   1        0.798507       0.287988       0.269733
# 4846-WHAFZ                   1        0.579602       0.328796       0.000000
#
#              Total Extra Data Charges  Total Long Distance Charges
# Customer ID
# 8779-QRDMV                   0.133333                     0.000000  \
# 7495-OOKFY                   0.000000                     0.109630
# 1658-BYGOY                   0.000000                     0.057211
# 4598-XLKNJ                   0.000000                     0.138580
# 4846-WHAFZ                   0.000000                     0.065702
#
#              Total Revenue  Satisfaction Score  New Customer  Churn Label
# Customer ID
# 8779-QRDMV        0.003202                0.50             0            1  \
# 7495-OOKFY        0.083855                0.50             0            1
# 1658-BYGOY        0.158013                0.25             0            1
# 4598-XLKNJ        0.248680                0.25             0            1
# 4846-WHAFZ        0.257652                0.25             0            1
#
#              Churn Score      CLTV                  Churn Reason  Population
# Customer ID
# 8779-QRDMV      0.945055  0.762731  Competitor offered more data    0.652488  \
# 7495-OOKFY      0.703297  0.733600  Competitor made better offer    0.528687
# 1658-BYGOY      0.835165  0.261508  Competitor made better offer    0.451422
# 4598-XLKNJ      0.912088  0.741383     Limited range of services    0.263759
# 4846-WHAFZ      0.681319  0.175673            Extra data charges    0.249387
#
#              Engagement Score  Gender_Male  Offer_Offer A  Offer_Offer B
# Customer ID
# 8779-QRDMV           0.142857            1              0              0  \
# 7495-OOKFY           0.571429            0              0              0
# 1658-BYGOY           0.428571            1              0              0
# 4598-XLKNJ           0.571429            0              0              0
# 4846-WHAFZ           0.428571            0              0              0
#
#              Offer_Offer C  Offer_Offer D  Offer_Offer E  Internet Type_Cable
# Customer ID
# 8779-QRDMV               0              0              0                    0  \
# 7495-OOKFY               0              0              1                    0
# 1658-BYGOY               0              1              0                    0
# 4598-XLKNJ               1              0              0                    0
# 4846-WHAFZ               1              0              0                    0
#
#              Internet Type_DSL  Internet Type_Fiber Optic
# Customer ID
# 8779-QRDMV                   1                          0  \
# 7495-OOKFY                   0                          1
# 1658-BYGOY                   0                          1
# 4598-XLKNJ                   0                          1
# 4846-WHAFZ                   0                          1
#
#              Payment Method_Bank Withdrawal  Payment Method_Credit Card
# Customer ID
# 8779-QRDMV                                1                           0  \
# 7495-OOKFY                                0                           1
# 1658-BYGOY                                1                           0
# 4598-XLKNJ                                1                           0
# 4846-WHAFZ                                1                           0
#
#              Churn Category_Attitude  Churn Category_Competitor
# Customer ID
# 8779-QRDMV                         0                          1  \
# 7495-OOKFY                         0                          1
# 1658-BYGOY                         0                          1
# 4598-XLKNJ                         0                          0
# 4846-WHAFZ                         0                          0
#
#              Churn Category_Dissatisfaction  Churn Category_Price
# Customer ID
# 8779-QRDMV                                0                     0  \
# 7495-OOKFY                                0                     0
# 1658-BYGOY                                0                     0
# 4598-XLKNJ                                1                     0
# 4846-WHAFZ                                0                     1
#
#              Density_High  Density_Low  Contract_Month-to-Month
# Customer ID
# 8779-QRDMV              1            0                        1  \
# 7495-OOKFY              1            0                        1
# 1658-BYGOY              1            0                        1
# 4598-XLKNJ              0            0                        1
# 4846-WHAFZ              0            0                        1
#
#              Contract_One Year  Contract_Two Year  Cluster_Demo  Cluster_SVC
# Customer ID
# 8779-QRDMV                   0                  0             2            3  \
# 7495-OOKFY                   0                  0             1            0
# 1658-BYGOY                   0                  0             2            0
# 4598-XLKNJ                   0                  0             1            0
# 4846-WHAFZ                   0                  0             1            0
#
#              Cluster_Streaming  Cluster_Tenure  Cluster_Payment
# Customer ID
# 8779-QRDMV                   1               0                2  \
# 7495-OOKFY                   1               0                1
# 1658-BYGOY                   2               0                2
# 4598-XLKNJ                   0               0                2
# 4846-WHAFZ                   1               0                2
#
#              Cluster_Profit  Cluster_Overall  Cluster_Churn
# Customer ID
# 8779-QRDMV                1                0              1
# 7495-OOKFY                2                0              1
# 1658-BYGOY                0                0              1
# 4598-XLKNJ                0                0              3
# 4846-WHAFZ                0                0              3

# %% [markdown]
# <a class="anchor" id="2nd-bullet">
#
# # 2. Explore data (Data access, exploration and understanding)
#
# </a>
# <img src="Images/step2.png" style="height:70px">
#
# Remember, this step is very important as it is at this stage that you will really look into the data that you have. Generally speaking, if you do well at this stage, the following stages will be more smooth.
#
# Moreover, you should also take the time to find meaningful patterns on the data: what interesting relationships can be found between the variables and how can that knowledge be inform your future decisions.
#
# __`Step 3`__ Check if you have missing values in your data with the method `info()`.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 8779-QRDMV to 3186-AJIEK
# Data columns (total 67 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                7043 non-null   float64
#  1   Under 30                           7043 non-null   int64
#  2   Senior Citizen                     7043 non-null   int64
#  3   Married                            7043 non-null   int64
#  4   Dependents                         7043 non-null   int64
#  5   Number of Dependents               7043 non-null   float64
#  6   City                               7043 non-null   object
#  7   Referred a Friend                  7043 non-null   int64
#  8   Number of Referrals                7043 non-null   float64
#  9   Tenure in Months                   7043 non-null   float64
#  10  Tenure Category                    7043 non-null   float64
#  11  Phone Service                      7043 non-null   int64
#  12  Avg Monthly Long Distance Charges  7043 non-null   float64
#  13  Multiple Lines                     7043 non-null   int64
#  14  Internet Service                   7043 non-null   int64
#  15  Avg Monthly GB Download            7043 non-null   float64
#  16  Online Security                    7043 non-null   int64
#  17  Online Backup                      7043 non-null   int64
#  18  Device Protection Plan             7043 non-null   int64
#  19  Premium Tech Support               7043 non-null   int64
#  20  Streaming TV                       7043 non-null   int64
#  21  Streaming Movies                   7043 non-null   int64
#  22  Streaming Music                    7043 non-null   int64
#  23  Unlimited Data                     7043 non-null   int64
#  24  Paperless Billing                  7043 non-null   int64
#  25  Monthly Charge                     7043 non-null   float64
#  26  Total Charges                      7043 non-null   float64
#  27  Total Refunds                      7043 non-null   float64
#  28  Total Extra Data Charges           7043 non-null   float64
#  29  Total Long Distance Charges        7043 non-null   float64
#  30  Total Revenue                      7043 non-null   float64
#  31  Satisfaction Score                 7043 non-null   float64
#  32  New Customer                       7043 non-null   int64
#  33  Churn Label                        7043 non-null   int64
#  34  Churn Score                        7043 non-null   float64
#  35  CLTV                               7043 non-null   float64
#  36  Churn Reason                       1869 non-null   object
#  37  Population                         7043 non-null   float64
#  38  Engagement Score                   7043 non-null   float64
#  39  Gender_Male                        7043 non-null   int64
#  40  Offer_Offer A                      7043 non-null   int64
#  41  Offer_Offer B                      7043 non-null   int64
#  42  Offer_Offer C                      7043 non-null   int64
#  43  Offer_Offer D                      7043 non-null   int64
#  44  Offer_Offer E                      7043 non-null   int64
#  45  Internet Type_Cable                7043 non-null   int64
#  46  Internet Type_DSL                  7043 non-null   int64
#  47  Internet Type_Fiber Optic          7043 non-null   int64
#  48  Payment Method_Bank Withdrawal     7043 non-null   int64
#  49  Payment Method_Credit Card         7043 non-null   int64
#  50  Churn Category_Attitude            7043 non-null   int64
#  51  Churn Category_Competitor          7043 non-null   int64
#  52  Churn Category_Dissatisfaction     7043 non-null   int64
#  53  Churn Category_Price               7043 non-null   int64
#  54  Density_High                       7043 non-null   int64
#  55  Density_Low                        7043 non-null   int64
#  56  Contract_Month-to-Month            7043 non-null   int64
#  57  Contract_One Year                  7043 non-null   int64
#  58  Contract_Two Year                  7043 non-null   int64
#  59  Cluster_Demo                       7043 non-null   int64
#  60  Cluster_SVC                        7043 non-null   int64
#  61  Cluster_Streaming                  7043 non-null   int64
#  62  Cluster_Tenure                     7043 non-null   int64
#  63  Cluster_Payment                    7043 non-null   int64
#  64  Cluster_Profit                     7043 non-null   int64
#  65  Cluster_Overall                    7043 non-null   int64
#  66  Cluster_Churn                      7043 non-null   int64
# dtypes: float64(18), int64(47), object(2)
# memory usage: 3.7+ MB

# %%
## Drop Columns for working DataSet
columns_to_drop = ['Cluster_Demo', 'Cluster_SVC', 'Cluster_Streaming', 'Cluster_Tenure',
                   'Cluster_Payment', 'Cluster_Profit', 'Cluster_Overall', 'Cluster_Churn']
data = data.drop(columns=columns_to_drop)

# %%
pd.set_option('display.max_columns', None)
data.head(3)
# Out:
#                   Age  Under 30  Senior Citizen  Married  Dependents
# Customer ID
# 8779-QRDMV   0.967213         0               1        0           0  \
# 7495-OOKFY   0.901639         0               1        1           1
# 1658-BYGOY   0.852459         0               1        0           1
#
#              Number of Dependents         City  Referred a Friend
# Customer ID
# 8779-QRDMV               0.000000  Los Angeles                  0  \
# 7495-OOKFY               0.111111  Los Angeles                  1
# 1658-BYGOY               0.333333  Los Angeles                  0
#
#              Number of Referrals  Tenure in Months  Tenure Category
# Customer ID
# 8779-QRDMV              0.000000          0.000000             0.00  \
# 7495-OOKFY              0.090909          0.098592             0.25
# 1658-BYGOY              0.000000          0.239437             0.50
#
#              Phone Service  Avg Monthly Long Distance Charges  Multiple Lines
# Customer ID
# 8779-QRDMV               0                           0.000000               0  \
# 7495-OOKFY               1                           0.977195               1
# 1658-BYGOY               1                           0.226645               1
#
#              Internet Service  Avg Monthly GB Download  Online Security
# Customer ID
# 8779-QRDMV                  1                 0.094118                0  \
# 7495-OOKFY                  1                 0.200000                0
# 1658-BYGOY                  1                 0.611765                0
#
#              Online Backup  Device Protection Plan  Premium Tech Support
# Customer ID
# 8779-QRDMV               0                       1                     0  \
# 7495-OOKFY               1                       0                     0
# 1658-BYGOY               0                       0                     0
#
#              Streaming TV  Streaming Movies  Streaming Music  Unlimited Data
# Customer ID
# 8779-QRDMV              0                 1                0               0  \
# 7495-OOKFY              0                 0                0               1
# 1658-BYGOY              1                 1                1               1
#
#              Paperless Billing  Monthly Charge  Total Charges  Total Refunds
# Customer ID
# 8779-QRDMV                   1        0.212935       0.002406       0.000000  \
# 7495-OOKFY                   1        0.620896       0.070909       0.000000
# 1658-BYGOY                   1        0.768159       0.200063       0.916047
#
#              Total Extra Data Charges  Total Long Distance Charges
# Customer ID
# 8779-QRDMV                   0.133333                     0.000000  \
# 7495-OOKFY                   0.000000                     0.109630
# 1658-BYGOY                   0.000000                     0.057211
#
#              Total Revenue  Satisfaction Score  New Customer  Churn Label
# Customer ID
# 8779-QRDMV        0.003202                0.50             0            1  \
# 7495-OOKFY        0.083855                0.50             0            1
# 1658-BYGOY        0.158013                0.25             0            1
#
#              Churn Score      CLTV                  Churn Reason  Population
# Customer ID
# 8779-QRDMV      0.945055  0.762731  Competitor offered more data    0.652488  \
# 7495-OOKFY      0.703297  0.733600  Competitor made better offer    0.528687
# 1658-BYGOY      0.835165  0.261508  Competitor made better offer    0.451422
#
#              Engagement Score  Gender_Male  Offer_Offer A  Offer_Offer B
# Customer ID
# 8779-QRDMV           0.142857            1              0              0  \
# 7495-OOKFY           0.571429            0              0              0
# 1658-BYGOY           0.428571            1              0              0
#
#              Offer_Offer C  Offer_Offer D  Offer_Offer E  Internet Type_Cable
# Customer ID
# 8779-QRDMV               0              0              0                    0  \
# 7495-OOKFY               0              0              1                    0
# 1658-BYGOY               0              1              0                    0
#
#              Internet Type_DSL  Internet Type_Fiber Optic
# Customer ID
# 8779-QRDMV                   1                          0  \
# 7495-OOKFY                   0                          1
# 1658-BYGOY                   0                          1
#
#              Payment Method_Bank Withdrawal  Payment Method_Credit Card
# Customer ID
# 8779-QRDMV                                1                           0  \
# 7495-OOKFY                                0                           1
# 1658-BYGOY                                1                           0
#
#              Churn Category_Attitude  Churn Category_Competitor
# Customer ID
# 8779-QRDMV                         0                          1  \
# 7495-OOKFY                         0                          1
# 1658-BYGOY                         0                          1
#
#              Churn Category_Dissatisfaction  Churn Category_Price
# Customer ID
# 8779-QRDMV                                0                     0  \
# 7495-OOKFY                                0                     0
# 1658-BYGOY                                0                     0
#
#              Density_High  Density_Low  Contract_Month-to-Month
# Customer ID
# 8779-QRDMV              1            0                        1  \
# 7495-OOKFY              1            0                        1
# 1658-BYGOY              1            0                        1
#
#              Contract_One Year  Contract_Two Year
# Customer ID
# 8779-QRDMV                   0                  0
# 7495-OOKFY                   0                  0
# 1658-BYGOY                   0                  0

# %%
data.describe(include='O').T
# Out:
#              count unique                            top freq
# City          7043   1106                    Los Angeles  293
# Churn Reason  1869     20  Competitor had better devices  313

# %%
# Check unique values
data['City'].value_counts()
# Out:
# City
# Los Angeles               293
# San Diego                 285
# San Jose                  112
# Sacramento                108
# San Francisco             104
# Fresno                     61
# Long Beach                 60
# Oakland                    52
# Escondido                  51
# Stockton                   44
# Fallbrook                  43
# Glendale                   40
# Bakersfield                39
# Temecula                   38
# Riverside                  32
# Berkeley                   32
# Pasadena                   30
# Whittier                   30
# Irvine                     28
# San Bernardino             28
# Santa Barbara              28
# Anaheim                    28
# Modesto                    28
# Inglewood                  25
# Santa Monica               25
# Burbank                    25
# Torrance                   25
# Santa Ana                  24
# Santa Rosa                 24
# Chula Vista                22
# Van Nuys                   20
# Corona                     20
# Orange                     20
# Garden Grove               20
# Rancho Cucamonga           20
# Salinas                    20
# North Hollywood            20
# Lakewood                   17
# Santa Cruz                 16
# Vallejo                    16
# Hayward                    16
# Concord                    16
# San Mateo                  16
# Palmdale                   16
# Newport Beach              16
# Redwood City               16
# Huntington Beach           16
# Palo Alto                  16
# Moreno Valley              16
# Fullerton                  16
# Fremont                    16
# West Covina                15
# Gardena                    15
# Downey                     15
# Ontario                    15
# Covina                     15
# Compton                    15
# Pomona                     15
# Beverly Hills              15
# Redding                    12
# Hemet                      12
# Novato                     12
# Fontana                    12
# Lancaster                  12
# Roseville                  12
# Richmond                   12
# Santa Maria                12
# Ventura                    12
# Sunnyvale                  12
# Chico                      12
# Mountain View              12
# Los Gatos                  12
# Sun City                   12
# Walnut Creek               12
# San Leandro                12
# Santa Clara                12
# Oxnard                     12
# El Cajon                   12
# Oceanside                  11
# Visalia                    11
# Glendora                   10
# Redondo Beach              10
# Upland                     10
# Northridge                 10
# Sherman Oaks               10
# Thousand Oaks              10
# Arcadia                    10
# Valencia                   10
# Carson                     10
# Malibu                     10
# Woodland Hills             10
# La Mesa                    10
# Culver City                10
# Canoga Park                10
# San Pedro                  10
# Spring Valley              10
# Encino                     10
# Monterey Park              10
# Buena Park                 10
# El Monte                   10
# Indio                       9
# Rancho Santa Fe             9
# Alhambra                    9
# La Puente                   9
# Palm Springs                9
# Vista                       9
# San Gabriel                 9
# Desert Hot Springs          9
# Perris                      8
# Victorville                 8
# Citrus Heights              8
# Yuba City                   8
# Tustin                      8
# Camarillo                   8
# Palm Desert                 8
# Woodland                    8
# Lodi                        8
# Manteca                     8
# Simi Valley                 8
# Frazier Park                8
# Brea                        8
# Carlsbad                    8
# San Clemente                8
# Grass Valley                8
# Vacaville                   8
# West Sacramento             8
# Davis                       8
# Madera                      8
# Rancho Cordova              8
# Auburn                      8
# Turlock                     8
# Yorba Linda                 8
# Eureka                      8
# Lake Elsinore               8
# Oroville                    8
# Rialto                      8
# Daly City                   8
# Danville                    8
# Castro Valley               8
# Los Altos                   8
# Napa                        8
# San Rafael                  8
# Costa Mesa                  8
# Murrieta                    8
# Rocklin                     8
# Elk Grove                   8
# San Dimas                   8
# Alameda                     8
# San Marcos                  8
# Merced                      8
# Mission Viejo               8
# Pleasanton                  8
# Clovis                      8
# San Jacinto                 8
# Petaluma                    8
# Redlands                    7
# San Luis Obispo             7
# Lompoc                      6
# Mecca                       5
# White Water                 5
# Salton City                 5
# Montclair                   5
# Poway                       5
# Winnetka                    5
# North Hills                 5
# San Fernando                5
# Huntington Park             5
# Pacific Palisades           5
# Montrose                    5
# San Marino                  5
# Hawaiian Gardens            5
# West Hollywood              5
# Canyon Country              5
# Azusa                       5
# Rosemead                    5
# Tecate                      5
# Potrero                     5
# Mission Hills               5
# Valley Village              5
# Adelanto                    5
# Rowland Heights             5
# Palo Verde                  5
# El Centro                   5
# Hawthorne                   5
# Los Alamitos                5
# Pico Rivera                 5
# Artesia                     5
# Sunset Beach                5
# Baldwin Park                5
# Chino Hills                 5
# Hacienda Heights            5
# La Verne                    5
# Descanso                    5
# Pine Valley                 5
# Calipatria                  5
# Beaumont                    5
# Warner Springs              5
# San Ysidro                  5
# Cabazon                     5
# Calexico                    5
# Sierra Madre                5
# Alpine                      5
# Temple City                 5
# Pacoima                     5
# Diamond Bar                 5
# Mt Baldy                    5
# Oak Park                    5
# Newbury Park                5
# Calabasas                   5
# La Crescenta                5
# Surfside                    5
# Westlake Village            5
# Norwalk                     5
# Cypress                     5
# Playa Del Rey               5
# Rancho Palos Verdes         5
# Palos Verdes Peninsula      5
# Maywood                     5
# Manhattan Beach             5
# Bell                        5
# Bellflower                  5
# Paramount                   5
# La Canada Flintridge        5
# South El Monte              5
# Cathedral City              5
# Santa Clarita               5
# Pioneertown                 5
# Yucca Valley                5
# Montebello                  5
# Granada Hills               5
# Stevenson Ranch             5
# Castaic                     5
# Walnut                      5
# Studio City                 5
# Morongo Valley              5
# Santa Ysabel                5
# Heber                       5
# Coronado                    5
# Banning                     5
# West Hills                  5
# Lemon Grove                 5
# Earp                        5
# Newhall                     5
# Thousand Palms              5
# Agoura Hills                5
# Twentynine Palms            5
# Porter Ranch                5
# Seal Beach                  5
# Lomita                      5
# Sun Valley                  5
# Cerritos                    5
# La Mirada                   5
# Desert Center               5
# Claremont                   5
# El Segundo                  5
# Chino                       5
# Sylmar                      5
# Topanga                     5
# Reseda                      5
# Venice                      5
# Duarte                      5
# South Pasadena              5
# Hermosa Beach               5
# Brawley                     5
# La Palma                    5
# Stanton                     5
# South Gate                  5
# National City               5
# La Quinta                   5
# Wilmington                  5
# Santa Fe Springs            5
# Harbor City                 5
# Rancho Mirage               5
# Chatsworth                  5
# Mira Loma                   5
# Lawndale                    5
# Avalon                      5
# La Habra                    5
# Tarzana                     5
# Altadena                    5
# Marina Del Rey              5
# Amboy                       5
# Lynwood                     5
# Sunland                     5
# Tujunga                     5
# Monrovia                    5
# Bolinas                     4
# Seaside                     4
# Milpitas                    4
# Calistoga                   4
# Lafayette                   4
# Lathrop                     4
# Lockeford                   4
# Cupertino                   4
# Westwood                    4
# Capitola                    4
# Sierraville                 4
# Arnold                      4
# Sanger                      4
# Blairsden Graeagle          4
# Whitmore                    4
# Pacific Grove               4
# Guadalupe                   4
# Valyermo                    4
# Silverado                   4
# Hoopa                       4
# Oak Run                     4
# Old Station                 4
# Sonoma                      4
# Casmalia                    4
# Wasco                       4
# Sequoia National Park       4
# Lemoore                     4
# Carpinteria                 4
# Hinkley                     4
# Lake Hughes                 4
# Calimesa                    4
# Vernalis                    4
# Clements                    4
# Stevinson                   4
# Pinecrest                   4
# Guatay                      4
# Bieber                      4
# Bonita                      4
# Campo Seco                  4
# Eagleville                  4
# Carmel Valley               4
# Rough And Ready             4
# Winters                     4
# Ukiah                       4
# Mckinleyville               4
# Korbel                      4
# Smith River                 4
# Trinidad                    4
# Amador City                 4
# Diamond Springs             4
# Orangevale                  4
# Penryn                      4
# Plymouth                    4
# Colfax                      4
# Gualala                     4
# Meadow Vista                4
# Antelope                    4
# Arbuckle                    4
# Bangor                      4
# Magalia                     4
# Strawberry Valley           4
# Callahan                    4
# Cottonwood                  4
# Douglas City                4
# Fall River Mills            4
# Rio Nido                    4
# Comptche                    4
# Downieville                 4
# Sausalito                   4
# Belmont                     4
# Pescadero                   4
# San Bruno                   4
# Antioch                     4
# San Lorenzo                 4
# Union City                  4
# Albany                      4
# Bodega Bay                  4
# Marshall                    4
# San Anselmo                 4
# Tomales                     4
# Cloverdale                  4
# Valley Ford                 4
# Alviso                      4
# Acampo                      4
# Linden                      4
# Valley Springs              4
# West Point                  4
# Atwater                     4
# Mariposa                    4
# Oakdale                     4
# Caspar                      4
# Nubieber                    4
# Angelus Oaks                4
# Apple Valley                4
# Covelo                      4
# Rodeo                       4
# Deer Park                   4
# Sunol                       4
# Inverness                   4
# Mill Valley                 4
# San Juan Bautista           4
# Avery                       4
# Mountain Ranch              4
# Planada                     4
# Clearlake Oaks              4
# Guerneville                 4
# Baker                       4
# Jenner                      4
# Brooks                      4
# El Dorado                   4
# Garden Valley               4
# Nicolaus                    4
# Rio Oso                     4
# Thornton                    4
# Dutch Flat                  4
# Echo Lake                   4
# Weimar                      4
# Dublin                      4
# Pope Valley                 4
# Pleasant Hill               4
# Brisbane                    4
# Cedar Glen                  4
# Colton                      4
# Fawnskin                    4
# Sugarloaf                   4
# Anza                        4
# Newport Coast               4
# Trabuco Canyon              4
# Piru                        4
# Santa Paula                 4
# Taft                        4
# Los Osos                    4
# Buellton                    4
# Morro Bay                   4
# Templeton                   4
# Independence                4
# Rosamond                    4
# Hume                        4
# North Fork                  4
# Oakhurst                    4
# Traver                      4
# Samoa                       4
# Myers Flat                  4
# Solana Beach                4
# Zenia                       4
# Kneeland                    4
# San Andreas                 4
# Wilseyville                 4
# Ceres                       4
# Escalon                     4
# Hornitos                    4
# Keyes                       4
# Sonora                      4
# Tracy                       4
# Boonville                   4
# Duncans Mills               4
# Forestville                 4
# Fort Bragg                  4
# Geyserville                 4
# Kenwood                     4
# Little River                4
# Lower Lake                  4
# Monte Rio                   4
# Potter Valley               4
# Sebastopol                  4
# Upper Lake                  4
# Willits                     4
# Windsor                     4
# Blocksburg                  4
# Arcata                      4
# Carlotta                    4
# Mokelumne Hill              4
# Burson                      4
# Mount Hamilton              4
# San Carlos                  4
# Fish Camp                   4
# Los Banos                   4
# Orange Cove                 4
# Raymond                     4
# Reedley                     4
# Wishon                      4
# Gonzales                    4
# Soledad                     4
# Spreckels                   4
# La Honda                    4
# Moss Beach                  4
# Stanford                    4
# Soquel                      4
# Benicia                     4
# Brentwood                   4
# Hercules                    4
# Suisun City                 4
# Belvedere Tiburon           4
# Bodega                      4
# Fairfax                     4
# Lagunitas                   4
# San Geronimo                4
# Mount Hermon                4
# Paicines                    4
# Fortuna                     4
# Mad River                   4
# Dos Palos                   4
# Orick                       4
# Washington                  4
# Big Bar                     4
# Chester                     4
# French Gulch                4
# Gazelle                     4
# Gerber                      4
# Grenada                     4
# Mccloud                     4
# Manton                      4
# Millville                   4
# Scott Bar                   4
# Tehama                      4
# Weed                        4
# Yreka                       4
# Cedarville                  4
# Chilcoot                    4
# Clio                        4
# Coleville                   4
# Herlong                     4
# Janesville                  4
# Litchfield                  4
# Loyalton                    4
# Markleeville                4
# Calpine                     4
# Tulelake                    4
# Stonyford                   4
# Stirling City               4
# Smartville                  4
# North Highlands             4
# Orleans                     4
# Phillipsville               4
# Scotia                      4
# Weott                       4
# Willow Creek                4
# Leggett                     4
# Esparto                     4
# Fiddletown                  4
# Foresthill                  4
# Georgetown                  4
# Ione                        4
# Placerville                 4
# Richvale                    4
# River Pines                 4
# Volcano                     4
# Alta                        4
# Gold Run                    4
# El Dorado Hills             4
# Marysville                  4
# Alleghany                   4
# Biggs                       4
# Goodyears Bar               4
# Meridian                    4
# Oregon House                4
# Firebaugh                   4
# Coarsegold                  4
# Clarksburg                  4
# Dunsmuir                    4
# Clayton                     4
# Rohnert Park                4
# Olema                       4
# Woodacre                    4
# Aptos                       4
# Watsonville                 4
# Groveland                   4
# Jamestown                   4
# Livingston                  4
# Tuolumne                    4
# Annapolis                   4
# Graton                      4
# Hopland                     4
# Navarro                     4
# Burnt Ranch                 4
# Petrolia                    4
# Cool                        4
# Kirkwood                    4
# Rescue                      4
# Sutter Creek                4
# Wilton                      4
# Kyburz                      4
# Gridley                     4
# Orland                      4
# Taylorsville                4
# Angwin                      4
# Greenfield                  4
# Carmel By The Sea           4
# Paynes Creek                4
# Galt                        4
# Hood                        4
# Walnut Grove                4
# Emigrant Gap                4
# Browns Valley               4
# Crescent Mills              4
# Maxwell                     4
# Olivehurst                  4
# Bella Vista                 4
# Castella                    4
# Happy Camp                  4
# Susanville                  4
# Riverdale                   4
# Termo                       4
# Carnelian Bay               4
# Kings Beach                 4
# Capistrano Beach            4
# Corcoran                    4
# Farmersville                4
# Lebec                       4
# Richgrove                   4
# Tulare                      4
# Solvang                     4
# Badger                      4
# Cassel                      4
# Etna                        4
# Auberry                     4
# Mcarthur                    4
# San Juan Capistrano         4
# Westminster                 4
# Villa Park                  4
# Fillmore                    4
# Goleta                      4
# Arvin                       4
# Glennville                  4
# Hanford                     4
# Lake Isabella               4
# Laton                       4
# Mc Farland                  4
# Three Rivers                4
# Tupman                      4
# Arroyo Grande               4
# Cayucos                     4
# Grover Beach                4
# Paso Robles                 4
# San Ardo                    4
# San Simeon                  4
# Santa Margarita             4
# Darwin                      4
# June Lake                   4
# Littlerock                  4
# Llano                       4
# Mammoth Lakes               4
# Aliso Viejo                 4
# Laguna Hills                4
# Mountain Center             4
# Coachella                   4
# Mill Creek                  4
# Platina                     4
# Wendel                      4
# Imperial Beach              4
# Encinitas                   4
# King City                   4
# Imperial                    4
# Ocotillo                    4
# Dulzura                     4
# Cardiff By The Sea          4
# Blythe                      4
# Joshua Tree                 4
# Needles                     4
# Winterhaven                 4
# Landers                     4
# Fort Irwin                  4
# Grand Terrace               4
# Big Bear Lake               4
# Death Valley                4
# Essex                       4
# Forest Falls                4
# Hesperia                    4
# Lake Arrowhead              4
# Loma Linda                  4
# Pebble Beach                4
# Igo                         4
# Tollhouse                   4
# Weaverville                 4
# Dana Point                  4
# Lake Forest                 4
# Laguna Beach                4
# Moorpark                    4
# Avenal                      4
# Exeter                      4
# New Cuyama                  4
# Big Pine                    4
# Dinuba                      4
# Shaver Lake                 4
# Chualar                     4
# Portola Valley              4
# Martinez                    4
# Moraga                      4
# Oakley                      4
# Emeryville                  4
# Larkspur                    4
# Ben Lomond                  4
# Campbell                    4
# Davenport                   4
# Vallecito                   4
# Woodbridge                  4
# Delhi                       4
# Yucaipa                     4
# Shingletown                 4
# Clearlake                   4
# Hat Creek                   4
# San Pablo                   4
# Corte Madera                4
# Point Reyes Station         4
# Boulder Creek               4
# Morgan Hill                 4
# Murphys                     4
# Crows Landing               4
# Winton                      4
# Cobb                        4
# Mendocino                   4
# Blue Lake                   4
# Fair Oaks                   4
# Grizzly Flats               4
# Guinda                      4
# Loomis                      4
# Pioneer                     4
# Soda Springs                4
# Elk Creek                   4
# Grimes                      4
# Princeton                   4
# Williams                    4
# Anderson                    4
# Big Bend                    4
# Riverbank                   4
# Lakeport                    4
# Pinole                      4
# Buttonwillow                4
# Strathmore                  4
# Woodlake                    4
# Creston                     4
# Los Olivos                  4
# Santa Ynez                  4
# Shandon                     4
# Benton                      4
# Bishop                      4
# O Neals                     4
# Millbrae                    4
# Montara                     4
# Pacifica                    4
# Bethel Island               4
# El Cerrito                  4
# Travis Afb                  4
# Yountville                  4
# San Joaquin                 4
# Brookdale                   4
# Castroville                 4
# Farmington                  4
# Hathaway Pines              4
# Wallace                     4
# El Nido                     4
# Pixley                      4
# Fountain Valley             4
# Lucerne                     4
# Foothill Ranch              4
# The Sea Ranch               4
# Bridgeville                 4
# Garberville                 4
# Lotus                       4
# Mather                      4
# Sloughhouse                 4
# Brownsville                 4
# Forbestown                  4
# Shasta Lake                 4
# Hornbrook                   4
# Mineral                     4
# Trinity Center              4
# Mount Laguna                4
# Julian                      4
# La Jolla                    4
# Westmorland                 4
# Mentone                     4
# Nipton                      4
# Pinon Hills                 4
# Shoshone                    4
# Yermo                       4
# Menifee                     4
# Winchester                  4
# Port Costa                  4
# Fairfield                   4
# Waterford                   4
# Rio Dell                    4
# Madison                     4
# Pleasant Grove              4
# Sheridan                    4
# Wheatland                   4
# Canyon Dam                  4
# Dobbins                     4
# Forest Ranch                4
# Nevada City                 4
# Lewiston                    4
# Palo Cedro                  4
# Round Mountain              4
# Wrightwood                  4
# Nuevo                       4
# Corona Del Mar              4
# Midway City                 4
# Oak View                    4
# Terra Bella                 4
# Bradley                     4
# Nipomo                      4
# Lee Vining                  4
# Cutler                      4
# Dunlap                      4
# Fowler                      4
# Folsom                      4
# Loleta                      4
# Tranquillity                4
# Bayside                     4
# Thermal                     4
# Summerland                  4
# Alpaugh                     4
# Camp Nelson                 4
# Delano                      4
# Fellows                     4
# Biola                       4
# Selma                       4
# Squaw Valley                4
# Jolon                       4
# Birds Landing               4
# Byron                       4
# Livermore                   4
# San Ramon                   4
# Greenbrae                   4
# Forest Knolls               4
# Freedom                     4
# Gilroy                      4
# Glencoe                     4
# Columbia                    4
# Fulton                      4
# Nice                        4
# Alderpoint                  4
# South Dos Palos             4
# Lockwood                    4
# Crockett                    4
# Adin                        4
# Red Bluff                   4
# Doyle                       4
# Sierra City                 4
# Tahoe Vista                 4
# Campo                       4
# Bonsall                     4
# Pala                        4
# North Palm Springs          4
# Crestline                   4
# Lucerne Valley              4
# Running Springs             4
# Somis                       4
# Coalinga                    4
# Ducor                       4
# Huron                       4
# Mc Kittrick                 4
# Woody                       4
# Boron                       4
# Helm                        4
# Parlier                     4
# Half Moon Bay               4
# Loma Mar                    4
# Atherton                    4
# Paskenta                    4
# Twain                       4
# Marina                      4
# Sutter                      4
# San Lucas                   4
# El Sobrante                 4
# Stinson Beach               4
# Moss Landing                4
# Angels Camp                 4
# Sheep Ranch                 4
# Ballico                     4
# Catheys Valley              4
# Hickman                     4
# Soulsbyville                4
# Branscomb                   4
# Philo                       4
# Point Arena                 4
# Westport                    4
# Gasquet                     4
# Piercy                      4
# Carmichael                  4
# Herald                      4
# Newcastle                   4
# Applegate                   4
# Butte City                  4
# Clipper Mills               4
# Quincy                      4
# Hughson                     4
# Penngrove                   4
# Albion                      4
# Hydesville                  4
# Redway                      4
# Salyer                      4
# Greenwood                   4
# Isleton                     4
# Knights Landing             4
# Pilot Hill                  4
# Pine Grove                  4
# Rio Linda                   4
# Twin Bridges                4
# Granite Bay                 4
# Challenge                   4
# Dunnigan                    4
# North San Juan              4
# Palermo                     4
# Willows                     4
# Burney                      4
# Corning                     4
# Dorris                      4
# Montgomery Creek            4
# Mount Shasta                4
# Standish                    4
# Ranchita                    4
# Helendale                   4
# Klamath                     4
# Honeydew                    4
# Oro Grande                  4
# Yorkville                   4
# Kettleman City              4
# Posey                       4
# Springville                 4
# Cambria                     4
# Caliente                    4
# Olancha                     4
# Randsburg                   4
# Dos Rios                    4
# Raisin City                 4
# Carmel                      4
# Burlingame                  4
# San Gregorio                4
# Newark                      4
# Saint Helena                4
# San Martin                  4
# Scotts Valley               4
# Denair                      4
# Hilmar                      4
# Long Barn                   4
# Patterson                   4
# Snelling                    4
# Healdsburg                  4
# Occidental                  4
# Lytle Creek                 4
# Laguna Niguel               4
# Armona                      4
# Ripon                       4
# Middletown                  4
# Witter Springs              4
# Fields Landing              4
# Redcrest                    4
# Somerset                    4
# Durham                      4
# Paradise                    4
# Hyampom                     4
# Klamath River               4
# Lakehead                    4
# Seeley                      4
# Phelan                      4
# March Air Reserve Base      4
# Homeland                    4
# Idyllwild                   4
# Bodfish                     4
# Kernville                   4
# Lemon Cove                  4
# Shafter                     4
# Keene                       4
# Pearblossom                 4
# Miramonte                   4
# Orosi                       4
# Salida                      4
# Newman                      4
# Lamont                      4
# Le Grand                    4
# Lindsay                     4
# Atascadero                  4
# Edwards                     4
# Keeler                      4
# Tehachapi                   4
# Bass Lake                   4
# Cantua Creek                4
# Caruthers                   4
# Chowchilla                  4
# Del Rey                     4
# Five Points                 4
# Kerman                      4
# Monterey                    4
# Alamo                       4
# Orinda                      4
# Cotati                      4
# Aromas                      4
# Saratoga                    4
# Copperopolis                4
# Big Oak Flat                4
# Coulterville                4
# El Portal                   4
# Gustine                     4
# Earlimart                   4
# Prather                     4
# Norco                       4
# Avila Beach                 4
# Rancho Santa Margarita      4
# Ladera Ranch                4
# Placentia                   4
# Ojai                        4
# Port Hueneme                4
# California Hot Springs      4
# Ivanhoe                     4
# Lost Hills                  4
# Porterville                 4
# Stratford                   4
# Weldon                      4
# San Miguel                  4
# Rio Vista                   4
# California City             4
# Acton                       4
# Bridgeport                  4
# Ahwahnee                    4
# Big Creek                   4
# Friant                      4
# Kingsburg                   4
# Aguanga                     4
# Sultana                     4
# Menlo Park                  4
# South San Francisco         4
# Wildomar                    4
# Parker Dam                  4
# Olympic Valley              4
# Milford                     4
# Glen Ellen                  4
# Glenhaven                   4
# Kelseyville                 4
# Laytonville                 4
# Manchester                  4
# Redwood Valley              4
# Elverta                     4
# Shingle Springs             4
# Camino                      4
# Pollock Pines               4
# Beale Afb                   4
# Camptonville                4
# Colusa                      4
# Glenn                       4
# Greenville                  4
# Live Oak                    4
# Canby                       4
# Forks Of Salmon             4
# Greenview                   4
# Junction City               4
# Lookout                     4
# Macdoel                     4
# Madeline                    4
# Pittsburg                   4
# Lakeshore                   4
# Capay                       4
# Mi Wuk Village              4
# Flournoy                    4
# Courtland                   4
# Lakeside                    4
# Dixon                       4
# Ramona                      4
# Somes Bar                   4
# Elmira                      4
# Meadow Valley               4
# Miranda                     4
# Ferndale                    4
# Elk                         4
# Cazadero                    4
# Daggett                     4
# Twain Harte                 4
# Midpines                    4
# La Grange                   4
# Cressey                     4
# French Camp                 4
# Felton                      4
# San Quentin                 4
# Nicasio                     4
# Jackson                     4
# Dillon Beach                4
# Lincoln                     4
# Berry Creek                 4
# Penn Valley                 4
# Hamilton City               4
# Los Molinos                 4
# Ludlow                      3
# Tahoma                      3
# Valley Center               3
# Fort Bidwell                3
# Seiad Valley                3
# Mojave                      3
# Shasta                      3
# Palomar Mountain            3
# Santee                      3
# Boulevard                   3
# Niland                      3
# Wofford Heights             3
# Alturas                     3
# Topaz                       3
# Davis Creek                 3
# Ravendale                   3
# Pismo Beach                 3
# Oceano                      3
# Vina                        3
# Jamul                       3
# Barstow                     3
# Del Mar                     3
# Bloomington                 3
# Highland                    3
# Big Bear City               3
# Los Alamos                  3
# Portola                     3
# Pauma Valley                3
# Indian Wells                3
# Borrego Springs             3
# Homewood                    3
# Green Valley Lake           3
# Tahoe City                  3
# Likely                      3
# Jacumba                     2
# South Lake Tahoe            2
# Johannesburg                2
# Eldridge                    2
# Holtville                   2
# Name: count, dtype: int64

# %%
# Check unique values
data['Churn Reason'].value_counts()
# Out:
# Churn Reason
# Competitor had better devices                313
# Competitor made better offer                 311
# Attitude of support person                   220
# Don't know                                   130
# Competitor offered more data                 117
# Competitor offered higher download speeds    100
# Attitude of service provider                  94
# Price too high                                78
# Product dissatisfaction                       77
# Network reliability                           72
# Long distance charges                         64
# Service dissatisfaction                       63
# Moved                                         46
# Extra data charges                            39
# Limited range of services                     37
# Poor expertise of online support              31
# Lack of affordable download/upload speed      30
# Lack of self-service on Website               29
# Poor expertise of phone support               12
# Deceased                                       6
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate

# Your data loading code here...
# Assuming your data is stored in a variable named 'data'

plt.figure(figsize=(9, 7))

custcmap = sns.diverging_palette(100, 150, as_cmap=True) 
corr = data[['Age', 'Under 30', 'Senior Citizen', 'Married', 'Dependents', 
              'Number of Dependents', 'Referred a Friend', 'Number of Referrals', 
              'Tenure in Months', 'Tenure Category', 'Phone Service', 
              'Avg Monthly Long Distance Charges', 'Multiple Lines', 'Internet Service', 
              'Avg Monthly GB Download', 'Online Security', 'Online Backup', 
              'Device Protection Plan', 'Premium Tech Support', 'Streaming TV', 
              'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Paperless Billing', 
              'Monthly Charge', 'Total Charges', 'Total Refunds', 'Total Extra Data Charges', 
              'Total Long Distance Charges', 'Total Revenue', 'Satisfaction Score', 
              'New Customer', 'Churn Label', 'Churn Score', 'CLTV', 
              'Population', 'Engagement Score', 'Gender_Male', 'Offer_Offer A', 
              'Offer_Offer B', 'Offer_Offer C', 'Offer_Offer D', 'Offer_Offer E', 
              'Internet Type_Cable', 'Internet Type_DSL', 'Internet Type_Fiber Optic', 
              'Payment Method_Bank Withdrawal', 'Payment Method_Credit Card', 
              'Churn Category_Attitude', 'Churn Category_Competitor', 
              'Churn Category_Dissatisfaction', 'Churn Category_Price', 'Density_High', 
              'Density_Low', 'Contract_Month-to-Month', 'Contract_One Year', 
              'Contract_Two Year']].corr(method='spearman')

# Filter correlations greater than 0.75
high_corr_mask = (np.abs(corr) > 0.75) & (corr < 1.0)

# Extract indices of high correlations
high_corr_indices = np.column_stack(np.where(high_corr_mask))

# Create a DataFrame with feature pairs and their correlation values
high_corr_feature_pairs = pd.DataFrame(
    [(corr.index[i], corr.columns[j], corr.iloc[i, j]) for i, j in high_corr_indices],
    columns=['Feature 1', 'Feature 2', 'Correlation']
)

# Display the table using tabulate
table = tabulate(high_corr_feature_pairs, headers='keys', tablefmt='grid', showindex=False)
print("Feature Pairs with Correlation > 0.95:")
print(table)
# Out:
# Feature Pairs with Correlation > 0.95:
# +--------------------------------+--------------------------------+---------------+
# | Feature 1                      | Feature 2                      |   Correlation |
# +================================+================================+===============+
# | Married                        | Referred a Friend              |      0.949987 |
# +--------------------------------+--------------------------------+---------------+
# | Married                        | Number of Referrals            |      0.896375 |
# +--------------------------------+--------------------------------+---------------+
# | Dependents                     | Number of Dependents           |      0.989819 |
# +--------------------------------+--------------------------------+---------------+
# | Number of Dependents           | Dependents                     |      0.989819 |
# +--------------------------------+--------------------------------+---------------+
# | Referred a Friend              | Married                        |      0.949987 |
# +--------------------------------+--------------------------------+---------------+
# | Referred a Friend              | Number of Referrals            |      0.943566 |
# +--------------------------------+--------------------------------+---------------+
# | Number of Referrals            | Married                        |      0.896375 |
# +--------------------------------+--------------------------------+---------------+
# | Number of Referrals            | Referred a Friend              |      0.943566 |
# +--------------------------------+--------------------------------+---------------+
# | Tenure in Months               | Tenure Category                |      0.975713 |
# +--------------------------------+--------------------------------+---------------+
# | Tenure in Months               | Total Charges                  |      0.889476 |
# +--------------------------------+--------------------------------+---------------+
# | Tenure in Months               | Total Revenue                  |      0.912647 |
# +--------------------------------+--------------------------------+---------------+
# | Tenure Category                | Tenure in Months               |      0.975713 |
# +--------------------------------+--------------------------------+---------------+
# | Tenure Category                | Total Charges                  |      0.871436 |
# +--------------------------------+--------------------------------+---------------+
# | Tenure Category                | Total Revenue                  |      0.895825 |
# +--------------------------------+--------------------------------+---------------+
# | Internet Service               | Unlimited Data                 |      0.755734 |
# +--------------------------------+--------------------------------+---------------+
# | Streaming Movies               | Streaming Music                |      0.848528 |
# +--------------------------------+--------------------------------+---------------+
# | Streaming Music                | Streaming Movies               |      0.848528 |
# +--------------------------------+--------------------------------+---------------+
# | Unlimited Data                 | Internet Service               |      0.755734 |
# +--------------------------------+--------------------------------+---------------+
# | Monthly Charge                 | Engagement Score               |      0.777587 |
# +--------------------------------+--------------------------------+---------------+
# | Monthly Charge                 | Internet Type_Fiber Optic      |      0.786059 |
# +--------------------------------+--------------------------------+---------------+
# | Total Charges                  | Tenure in Months               |      0.889476 |
# +--------------------------------+--------------------------------+---------------+
# | Total Charges                  | Tenure Category                |      0.871436 |
# +--------------------------------+--------------------------------+---------------+
# | Total Charges                  | Total Revenue                  |      0.978366 |
# +--------------------------------+--------------------------------+---------------+
# | Total Long Distance Charges    | Total Revenue                  |      0.777501 |
# +--------------------------------+--------------------------------+---------------+
# | Total Revenue                  | Tenure in Months               |      0.912647 |
# +--------------------------------+--------------------------------+---------------+
# | Total Revenue                  | Tenure Category                |      0.895825 |
# +--------------------------------+--------------------------------+---------------+
# | Total Revenue                  | Total Charges                  |      0.978366 |
# +--------------------------------+--------------------------------+---------------+
# | Total Revenue                  | Total Long Distance Charges    |      0.777501 |
# +--------------------------------+--------------------------------+---------------+
# | Population                     | Density_High                   |      0.820187 |
# +--------------------------------+--------------------------------+---------------+
# | Population                     | Density_Low                    |     -0.814594 |
# +--------------------------------+--------------------------------+---------------+
# | Engagement Score               | Monthly Charge                 |      0.777587 |
# +--------------------------------+--------------------------------+---------------+
# | Internet Type_Fiber Optic      | Monthly Charge                 |      0.786059 |
# +--------------------------------+--------------------------------+---------------+
# | Payment Method_Bank Withdrawal | Payment Method_Credit Card     |     -0.893593 |
# +--------------------------------+--------------------------------+---------------+
# | Payment Method_Credit Card     | Payment Method_Bank Withdrawal |     -0.893593 |
# +--------------------------------+--------------------------------+---------------+
# | Density_High                   | Population                     |      0.820187 |
# +--------------------------------+--------------------------------+---------------+
# | Density_Low                    | Population                     |     -0.814594 |
# +--------------------------------+--------------------------------+---------------+

# %% [markdown]
# ## Outliers

# %%
import pandas as pd
import numpy as np

# Identify numeric columns excluding binary variables
numeric_cols = data.select_dtypes(include=[np.number]).columns
non_binary_cols = [col for col in numeric_cols if len(data[col].unique()) > 2]

# Calculate the interquartile range for each non-binary numeric variable
q1 = data[non_binary_cols].quantile(0.25)
q3 = data[non_binary_cols].quantile(0.75)
iqr = q3 - q1

# Calculate the lower and upper bounds for each non-binary variable
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Identify outliers for each non-binary variable
outliers = ((data[non_binary_cols] < lower_bound) | (data[non_binary_cols] > upper_bound))

# Count outliers for each non-binary variable
outliers_count = outliers.sum()

# Exclude columns with only 1 or 0 outliers and are binary
outliers_count_filtered = outliers_count[(outliers_count > 1) & (outliers_count < len(data) - 1)]

# Display only non-binary columns with more than 1 and less than (len(data) - 1) outliers
print(outliers_count_filtered)
# Out:
# Number of Dependents           1627
# Number of Referrals             676
# Avg Monthly GB Download         362
# Total Refunds                   525
# Total Extra Data Charges        728
# Total Long Distance Charges     196
# Total Revenue                    21
# Satisfaction Score              922
# Population                       57
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already calculated outliers_count_filtered as mentioned in your code

# Determine the number of subplots needed
num_plots = len(outliers_count_filtered.index)
num_cols = 4
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

# Create subplots with boxplots in a 4x4 grid
fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 8))

# Flatten the axes array to make it easier to iterate
axes = axes.flatten()

# Iterate through each variable with outliers
for i, col in enumerate(outliers_count_filtered.index):
    if col in data.columns:
        sns.boxplot(x=data[col], ax=axes[i])
        axes[i].set_title(f'{col}')
    else:
        print(f"Column '{col}' not found in the DataFrame.")

# Remove any empty subplots
for j in range(num_plots, num_cols * num_rows):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# <a class="anchor" id="3rd-bullet">
#
# # 3. Modify data (Data preparation)
#
# </a>
# <img src="Images/step3.png" style="height:70px">
#
# Remember that your decisions at this step should be exclusively informed by your **training data**. While you will need to split your data between training and validation, how that split will be made and how to apply the approppriate transformations will depend on the type of model assessment solution you select for your project (each has its own set of advantages and disadvantages that you need to consider). **Please find a list of possible methods for model assessment below**:
#
# 1. **Holdout method**
# 2. **Repeated Holdout method**
# 3. **K-Fold Cross-Validation**
# 4. **One Leave Out**
#
# In this dataset, we are going to use K-Fold Cross-Validation, since it is the one more appropriate for the size of the dataset that we are using.
#
# <img src="Images/KFold.png" style="height:300px">

# %% [markdown]
# __`Step 5`__ Import `StratifiedKFold` from `sklearn.model_selection`.

# %%
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# __`Step 6`__ Create a new instance of StratifiedKFold named as `skf`, with the following hyperparameters:
# - n_splits = 5
# - random_state = 99
# - shuffle = True

# %%
skf = StratifiedKFold(n_splits = 5, random_state = 99, shuffle = True)

# %% [markdown]
# __`Step 7`__ To apply any of the model assessment techniques previously mentioned, we need to define at first what are our independent variables (`X`) and the target (`y`).

# %%
X = data.drop('Churn Label', axis = 1)
y = data['Churn Label'].copy()

# %% [markdown]
# For the remaining steps, we are going to deal with our data as if we had two different data sets: the train and validation data.

# %% [markdown]
# <a class="anchor" id="4th-bullet">
#
# ## 3.1. Feature Selection
#
# </a>
#
# In this step we are going to apply Feature Selection, namely:
# - __Variance (Filter Method)__
# - __Spearman Correlation (Filter Method)__
# - __Recursive Feature Elimination (RFE) (Wrapper Method)__
# - __Lasso Regression (Wrapper Method)__
# - __Decision Trees (Embedded Method)__
#
# Since we know that regressions are really sensible to correlated features, we should remove the correlated features before applying those techniques, namely Lasso Regression and Recursive Feature Elimination if the estimator used is a regression model.
#
# In that way, we are going to apply the feature selection techniques in the following order: <br>
# __(1) Variance__ - To  understand if there are any constant variables;<br>
# __(2) Spearman Correlation__ - To verify if there are any correlated features;<br>
# __(3) Decision Trees__ - To just keep one variable from a group of correlated features;<br>
# __(4) RFE__ - To iteratively select features by considering subsets of features;<br>
# __(5) Lasso__ - To identify and select important features in a dataset;<br>
#
# Furthermore, to apply Feature selection, we need at first to identify the data type of each variable, since different techniques are specific to different data types.

# %%
data.head(3)
# Out:
#                   Age  Under 30  Senior Citizen  Married  Dependents
# Customer ID
# 8779-QRDMV   0.967213         0               1        0           0  \
# 7495-OOKFY   0.901639         0               1        1           1
# 1658-BYGOY   0.852459         0               1        0           1
#
#              Number of Dependents         City  Referred a Friend
# Customer ID
# 8779-QRDMV               0.000000  Los Angeles                  0  \
# 7495-OOKFY               0.111111  Los Angeles                  1
# 1658-BYGOY               0.333333  Los Angeles                  0
#
#              Number of Referrals  Tenure in Months  Tenure Category
# Customer ID
# 8779-QRDMV              0.000000          0.000000             0.00  \
# 7495-OOKFY              0.090909          0.098592             0.25
# 1658-BYGOY              0.000000          0.239437             0.50
#
#              Phone Service  Avg Monthly Long Distance Charges  Multiple Lines
# Customer ID
# 8779-QRDMV               0                           0.000000               0  \
# 7495-OOKFY               1                           0.977195               1
# 1658-BYGOY               1                           0.226645               1
#
#              Internet Service  Avg Monthly GB Download  Online Security
# Customer ID
# 8779-QRDMV                  1                 0.094118                0  \
# 7495-OOKFY                  1                 0.200000                0
# 1658-BYGOY                  1                 0.611765                0
#
#              Online Backup  Device Protection Plan  Premium Tech Support
# Customer ID
# 8779-QRDMV               0                       1                     0  \
# 7495-OOKFY               1                       0                     0
# 1658-BYGOY               0                       0                     0
#
#              Streaming TV  Streaming Movies  Streaming Music  Unlimited Data
# Customer ID
# 8779-QRDMV              0                 1                0               0  \
# 7495-OOKFY              0                 0                0               1
# 1658-BYGOY              1                 1                1               1
#
#              Paperless Billing  Monthly Charge  Total Charges  Total Refunds
# Customer ID
# 8779-QRDMV                   1        0.212935       0.002406       0.000000  \
# 7495-OOKFY                   1        0.620896       0.070909       0.000000
# 1658-BYGOY                   1        0.768159       0.200063       0.916047
#
#              Total Extra Data Charges  Total Long Distance Charges
# Customer ID
# 8779-QRDMV                   0.133333                     0.000000  \
# 7495-OOKFY                   0.000000                     0.109630
# 1658-BYGOY                   0.000000                     0.057211
#
#              Total Revenue  Satisfaction Score  New Customer  Churn Label
# Customer ID
# 8779-QRDMV        0.003202                0.50             0            1  \
# 7495-OOKFY        0.083855                0.50             0            1
# 1658-BYGOY        0.158013                0.25             0            1
#
#              Churn Score      CLTV                  Churn Reason  Population
# Customer ID
# 8779-QRDMV      0.945055  0.762731  Competitor offered more data    0.652488  \
# 7495-OOKFY      0.703297  0.733600  Competitor made better offer    0.528687
# 1658-BYGOY      0.835165  0.261508  Competitor made better offer    0.451422
#
#              Engagement Score  Gender_Male  Offer_Offer A  Offer_Offer B
# Customer ID
# 8779-QRDMV           0.142857            1              0              0  \
# 7495-OOKFY           0.571429            0              0              0
# 1658-BYGOY           0.428571            1              0              0
#
#              Offer_Offer C  Offer_Offer D  Offer_Offer E  Internet Type_Cable
# Customer ID
# 8779-QRDMV               0              0              0                    0  \
# 7495-OOKFY               0              0              1                    0
# 1658-BYGOY               0              1              0                    0
#
#              Internet Type_DSL  Internet Type_Fiber Optic
# Customer ID
# 8779-QRDMV                   1                          0  \
# 7495-OOKFY                   0                          1
# 1658-BYGOY                   0                          1
#
#              Payment Method_Bank Withdrawal  Payment Method_Credit Card
# Customer ID
# 8779-QRDMV                                1                           0  \
# 7495-OOKFY                                0                           1
# 1658-BYGOY                                1                           0
#
#              Churn Category_Attitude  Churn Category_Competitor
# Customer ID
# 8779-QRDMV                         0                          1  \
# 7495-OOKFY                         0                          1
# 1658-BYGOY                         0                          1
#
#              Churn Category_Dissatisfaction  Churn Category_Price
# Customer ID
# 8779-QRDMV                                0                     0  \
# 7495-OOKFY                                0                     0
# 1658-BYGOY                                0                     0
#
#              Density_High  Density_Low  Contract_Month-to-Month
# Customer ID
# 8779-QRDMV              1            0                        1  \
# 7495-OOKFY              1            0                        1
# 1658-BYGOY              1            0                        1
#
#              Contract_One Year  Contract_Two Year
# Customer ID
# 8779-QRDMV                   0                  0
# 7495-OOKFY                   0                  0
# 1658-BYGOY                   0                  0

# %%
import pandas as pd
import numpy as np

# Assuming 'data' is your DataFrame
# You can load your dataset using pd.read_csv, pd.read_excel, or other appropriate functions

# Create an empty DataFrame to store variable information
variable_info = pd.DataFrame(columns=['Variable', 'Data Type'])

# Iterate through each column in the dataset
for column in data.columns:
    # Determine the data type of the column
    data_type = None

    # Check if the column is categorical
    if data[column].dtype == 'object':
        unique_values = data[column].nunique()
        if unique_values == 2:
            data_type = 'Binary'
        else:
            data_type = 'Categorical'
    # Check if the column is numerical
    elif np.issubdtype(data[column].dtype, np.number):
        if data[column].nunique() == 2:
            data_type = 'Binary'
        else:
            data_type = 'Continuous'

    # Concatenate the information to the variable_info DataFrame
    variable_info = pd.concat([variable_info, pd.DataFrame({'Variable': [column], 'Data Type': [data_type]})], ignore_index=True)

# Replace 'None' with 'Unknown' in the 'Data Type' column
variable_info['Data Type'].replace({None: 'Unknown'}, inplace=True)

# Display the resulting table with variable names
pd.set_option('display.max_rows', None)
print(variable_info)
# Out:
#                              Variable    Data Type
# 0                                 Age   Continuous
# 1                            Under 30       Binary
# 2                      Senior Citizen       Binary
# 3                             Married       Binary
# 4                          Dependents       Binary
# 5                Number of Dependents   Continuous
# 6                                City  Categorical
# 7                   Referred a Friend       Binary
# 8                 Number of Referrals   Continuous
# 9                    Tenure in Months   Continuous
# 10                    Tenure Category   Continuous
# 11                      Phone Service       Binary
# 12  Avg Monthly Long Distance Charges   Continuous
# 13                     Multiple Lines       Binary
# 14                   Internet Service       Binary
# 15            Avg Monthly GB Download   Continuous
# 16                    Online Security       Binary
# 17                      Online Backup       Binary
# 18             Device Protection Plan       Binary
# 19               Premium Tech Support       Binary
# 20                       Streaming TV       Binary
# 21                   Streaming Movies       Binary
# 22                    Streaming Music       Binary
# 23                     Unlimited Data       Binary
# 24                  Paperless Billing       Binary
# 25                     Monthly Charge   Continuous
# 26                      Total Charges   Continuous
# 27                      Total Refunds   Continuous
# 28           Total Extra Data Charges   Continuous
# 29        Total Long Distance Charges   Continuous
# 30                      Total Revenue   Continuous
# 31                 Satisfaction Score   Continuous
# 32                       New Customer       Binary
# 33                        Churn Label       Binary
# 34                        Churn Score   Continuous
# 35                               CLTV   Continuous
# 36                       Churn Reason  Categorical
# 37                         Population   Continuous
# 38                   Engagement Score   Continuous
# 39                        Gender_Male       Binary
# 40                      Offer_Offer A       Binary
# 41                      Offer_Offer B       Binary
# 42                      Offer_Offer C       Binary
# 43                      Offer_Offer D       Binary
# 44                      Offer_Offer E       Binary
# 45                Internet Type_Cable       Binary
# 46                  Internet Type_DSL       Binary
# 47          Internet Type_Fiber Optic       Binary
# 48     Payment Method_Bank Withdrawal       Binary
# 49         Payment Method_Credit Card       Binary
# 50            Churn Category_Attitude       Binary
# 51          Churn Category_Competitor       Binary
# 52     Churn Category_Dissatisfaction       Binary
# 53               Churn Category_Price       Binary
# 54                       Density_High       Binary
# 55                        Density_Low       Binary
# 56            Contract_Month-to-Month       Binary
# 57                  Contract_One Year       Binary
# 58                  Contract_Two Year       Binary

# %%
data.isna().sum()
# Out:
# Age                                     0
# Under 30                                0
# Senior Citizen                          0
# Married                                 0
# Dependents                              0
# Number of Dependents                    0
# City                                    0
# Referred a Friend                       0
# Number of Referrals                     0
# Tenure in Months                        0
# Tenure Category                         0
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                          0
# Internet Service                        0
# Avg Monthly GB Download                 0
# Online Security                         0
# Online Backup                           0
# Device Protection Plan                  0
# Premium Tech Support                    0
# Streaming TV                            0
# Streaming Movies                        0
# Streaming Music                         0
# Unlimited Data                          0
# Paperless Billing                       0
# Monthly Charge                          0
# Total Charges                           0
# Total Refunds                           0
# Total Extra Data Charges                0
# Total Long Distance Charges             0
# Total Revenue                           0
# Satisfaction Score                      0
# New Customer                            0
# Churn Label                             0
# Churn Score                             0
# CLTV                                    0
# Churn Reason                         5174
# Population                              0
# Engagement Score                        0
# Gender_Male                             0
# Offer_Offer A                           0
# Offer_Offer B                           0
# Offer_Offer C                           0
# Offer_Offer D                           0
# Offer_Offer E                           0
# Internet Type_Cable                     0
# Internet Type_DSL                       0
# Internet Type_Fiber Optic               0
# Payment Method_Bank Withdrawal          0
# Payment Method_Credit Card              0
# Churn Category_Attitude                 0
# Churn Category_Competitor               0
# Churn Category_Dissatisfaction          0
# Churn Category_Price                    0
# Density_High                            0
# Density_Low                             0
# Contract_Month-to-Month                 0
# Contract_One Year                       0
# Contract_Two Year                       0
# dtype: int64

# %% [markdown]
# <a class="anchor" id="5th-bullet">
#
# ### 3.1.1. Categorical features
#
# </a>
#
# We are going to use chi-square to understand which categorical variables should we keep. <br>
#
#
# <a class="anchor" id="6th-bullet">
#
# #### __`3.1.1.1. Chi-Square (Filter Method) - For categorical data`__
#
# </a>

# %% [markdown]
# __`Step 8`__ - Create a function named as `apply_chisquare` to select features from the categorical variables using `chi2_contigency`from `scipy.stats`.

# %%
def apply_chisquare(X,y,var,alpha=0.05):        
    dfObserved = pd.crosstab(y,X) 
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)
    dfExpected = pd.DataFrame(expected, columns=dfObserved.columns, index = dfObserved.index)
    if p<alpha:
        result="{0} is IMPORTANT for Prediction".format(var)
    else:
        result="{0} is NOT an important predictor. (Discard {0} from model)".format(var)
    print(result)

# %% [markdown]
# Now it is time to select the categorical features to keep. <br>
# Remember that we want to select features that are important, independently of the subset of data that is being used for train. <br>
# For that, we need to apply our function previously defined inside the StratifiedKFold.
#
# __`Step 9`__ - Create a function named as `select_best_cat_features` that receives the independent variables (X) and the target (y). <br>
# Inside of this function, follow these steps:<br>
# - Apply the previously defined StratifiedKFold as "skf" for cross-validation.
# - Fill missing data, focusing on the categorical features.
# - Correct misclassifications in the categorical data that were identified during exploration.
# - Call the "apply_chisquare" function on your categorical variables.

# %%
def select_best_cat_features(X,y):
    count = 1
    
    ############################################## APPLY SKF ######################################################
    for train_index, val_index in skf.split(X,y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        
        #################################### SELECT FEATURES WITH CHI-SQUARE #######################################        
        print('_________________________________________________________________________________________________\n')
        print('                                     SPLIT ' + str(count) + '                                    ')
        print('_________________________________________________________________________________________________')

        # check which features to use using chi-square
        X_train_cat = X_train[['City','Churn Reason']].copy()
        for var in X_train_cat:
            apply_chisquare(X_train_cat[var],y_train, var)
            
        count+=1

# %% [markdown]
# __`Step 9B`__ - Call your function `select_best_cat_features` passing as arguments your independent variables and your target.

# %%
select_best_cat_features(X,y)
# Out:
# _________________________________________________________________________________________________
#
#                                      SPLIT 1
# _________________________________________________________________________________________________
# City is IMPORTANT for Prediction
# Churn Reason is NOT an important predictor. (Discard Churn Reason from model)
# _________________________________________________________________________________________________
#
#                                      SPLIT 2
# _________________________________________________________________________________________________
# City is IMPORTANT for Prediction
# Churn Reason is NOT an important predictor. (Discard Churn Reason from model)
# _________________________________________________________________________________________________
#
#                                      SPLIT 3
# _________________________________________________________________________________________________
# City is IMPORTANT for Prediction
# Churn Reason is NOT an important predictor. (Discard Churn Reason from model)
# _________________________________________________________________________________________________
#
#                                      SPLIT 4
# _________________________________________________________________________________________________
# City is IMPORTANT for Prediction
# Churn Reason is NOT an important predictor. (Discard Churn Reason from model)
# _________________________________________________________________________________________________
#
#                                      SPLIT 5
# _________________________________________________________________________________________________
# City is IMPORTANT for Prediction
# Churn Reason is NOT an important predictor. (Discard Churn Reason from model)

# %% [markdown]
# #### What can we conclude?
#
# | Predictor | Chi-Square | What to do? (One possible way to "solve")|
# | --- | --- | --- |
# | City | 5 Yes 0 No | Keep |
# | Churn Reason | 0 YES & 5 NO | Remove|
#
#
# Keep "City" and Remove "Churn Reason"

# %%
X = X.drop(['Churn Reason'], axis = 1)

# %% [markdown]
# ## Variance

# %%
def select_features_variance(x, y, n_splits=5, random_state=99):
    skf = StratifiedKFold(n_splits=n_splits, random_state=random_state, shuffle=True)
    results = []

    for count, (train_index, val_index) in enumerate(skf.split(x, y), start=1):
        X_train, X_val = x.iloc[train_index], x.iloc[val_index]

        # Exclude non-numeric columns
        numeric_columns = X_train.select_dtypes(include=np.number).columns
        X_train_numeric = X_train[numeric_columns]

        # Calculate variance
        var = X_train_numeric.var()
        results.append(var)

    result_df = pd.concat(results, axis=1)
    result_df.columns = [f'Variance (Split {i})' for i in range(1, n_splits+1)]
    
    return result_df

result_df = select_features_variance(X, y)
result_df
# Out:
#                                    Variance (Split 1)  Variance (Split 2)
# Age                                          0.075345            0.074570  \
# Under 30                                     0.157691            0.159303
# Senior Citizen                               0.136295            0.134371
# Married                                      0.249858            0.249717
# Dependents                                   0.179431            0.175607
# Number of Dependents                         0.011632            0.011019
# Referred a Friend                            0.248477            0.248168
# Number of Referrals                          0.073366            0.073537
# Tenure in Months                             0.119598            0.118874
# Tenure Category                              0.120436            0.120354
# Phone Service                                0.085525            0.087821
# Avg Monthly Long Distance Charges            0.095522            0.095145
# Multiple Lines                               0.244722            0.242935
# Internet Service                             0.169279            0.168267
# Avg Monthly GB Download                      0.058484            0.057410
# Online Security                              0.204140            0.205723
# Online Backup                                0.225865            0.226848
# Device Protection Plan                       0.225865            0.227171
# Premium Tech Support                         0.206837            0.207864
# Streaming TV                                 0.237098            0.235645
# Streaming Movies                             0.238358            0.237259
# Streaming Music                              0.229929            0.228285
# Unlimited Data                               0.220336            0.219473
# Paperless Billing                            0.241817            0.241655
# Monthly Charge                               0.089426            0.089490
# Total Charges                                0.068579            0.068324
# Total Refunds                                0.024184            0.025158
# Total Extra Data Charges                     0.028604            0.028550
# Total Long Distance Charges                  0.057079            0.055843
# Total Revenue                                0.057819            0.057337
# Satisfaction Score                           0.089967            0.088972
# New Customer                                 0.058740            0.059825
# Churn Score                                  0.053676            0.054198
# CLTV                                         0.069518            0.069592
# Population                                   0.040606            0.040545
# Engagement Score                             0.082221            0.083194
# Gender_Male                                  0.249991            0.250023
# Offer_Offer A                                0.069455            0.068549
# Offer_Offer B                                0.102215            0.104797
# Offer_Offer C                                0.055465            0.055935
# Offer_Offer D                                0.078835            0.078247
# Offer_Offer E                                0.101669            0.100161
# Internet Type_Cable                          0.105068            0.106551
# Internet Type_DSL                            0.179902            0.178769
# Internet Type_Fiber Optic                    0.245103            0.245374
# Payment Method_Bank Withdrawal               0.246878            0.246592
# Payment Method_Credit Card                   0.237617            0.236895
# Churn Category_Attitude                      0.042574            0.041116
# Churn Category_Competitor                    0.108294            0.106820
# Churn Category_Dissatisfaction               0.039978            0.040629
# Churn Category_Price                         0.028601            0.029102
# Density_High                                 0.223951            0.224804
# Density_Low                                  0.221487            0.220823
# Contract_Month-to-Month                      0.249959            0.249911
# Contract_One Year                            0.173657            0.172870
# Contract_Two Year                            0.195805            0.195391
#
#                                    Variance (Split 3)  Variance (Split 4)
# Age                                          0.075027            0.075905  \
# Under 30                                     0.160688            0.159281
# Senior Citizen                               0.133524            0.137588
# Married                                      0.249795            0.249646
# Dependents                                   0.180746            0.175972
# Number of Dependents                         0.011798            0.011473
# Referred a Friend                            0.248304            0.248068
# Number of Referrals                          0.075481            0.074642
# Tenure in Months                             0.119968            0.119459
# Tenure Category                              0.121168            0.120713
# Phone Service                                0.087678            0.087950
# Avg Monthly Long Distance Charges            0.095608            0.095673
# Multiple Lines                               0.243720            0.244395
# Internet Service                             0.171782            0.169257
# Avg Monthly GB Download                      0.057603            0.057919
# Online Security                              0.204595            0.205177
# Online Backup                                0.225477            0.226340
# Device Protection Plan                       0.226250            0.225346
# Premium Tech Support                         0.204972            0.206000
# Streaming TV                                 0.236026            0.237163
# Streaming Movies                             0.237138            0.237122
# Streaming Music                              0.228180            0.228162
# Unlimited Data                               0.219411            0.220009
# Paperless Billing                            0.242040            0.241046
# Monthly Charge                               0.090020            0.089191
# Total Charges                                0.068335            0.067982
# Total Refunds                                0.025596            0.025473
# Total Extra Data Charges                     0.026370            0.028844
# Total Long Distance Charges                  0.056511            0.056972
# Total Revenue                                0.057373            0.057105
# Satisfaction Score                           0.089865            0.090868
# New Customer                                 0.061679            0.057486
# Churn Score                                  0.054583            0.054003
# CLTV                                         0.069327            0.068305
# Population                                   0.039632            0.040897
# Engagement Score                             0.083427            0.082396
# Gender_Male                                  0.249991            0.250027
# Offer_Offer A                                0.069455            0.069745
# Offer_Offer B                                0.104662            0.103561
# Offer_Offer C                                0.053267            0.056863
# Offer_Offer D                                0.078688            0.077055
# Offer_Offer E                                0.100847            0.100420
# Internet Type_Cable                          0.104391            0.101516
# Internet Type_DSL                            0.178484            0.180723
# Internet Type_Fiber Optic                    0.244978            0.245532
# Payment Method_Bank Withdrawal               0.247609            0.246789
# Payment Method_Credit Card                   0.238964            0.238228
# Churn Category_Attitude                      0.042574            0.044663
# Churn Category_Competitor                    0.103305            0.101242
# Churn Category_Dissatisfaction               0.042412            0.041433
# Churn Category_Price                         0.029602            0.029430
# Density_High                                 0.224804            0.224898
# Density_Low                                  0.219473            0.221886
# Contract_Month-to-Month                      0.249838            0.249937
# Contract_One Year                            0.168368            0.172156
# Contract_Two Year                            0.197772            0.196525
#
#                                    Variance (Split 5)
# Age                                          0.076170
# Under 30                                     0.159922
# Senior Citizen                               0.137588
# Married                                      0.249745
# Dependents                                   0.176550
# Number of Dependents                         0.011296
# Referred a Friend                            0.248146
# Number of Referrals                          0.075176
# Tenure in Months                             0.119516
# Tenure Category                              0.121002
# Phone Service                                0.088379
# Avg Monthly Long Distance Charges            0.095544
# Multiple Lines                               0.243821
# Internet Service                             0.170163
# Avg Monthly GB Download                      0.057121
# Online Security                              0.202970
# Online Backup                                0.225346
# Device Protection Plan                       0.223644
# Premium Tech Support                         0.204422
# Streaming TV                                 0.237363
# Streaming Movies                             0.237483
# Streaming Music                              0.227951
# Unlimited Data                               0.220070
# Paperless Billing                            0.241113
# Monthly Charge                               0.090092
# Total Charges                                0.068715
# Total Refunds                                0.025548
# Total Extra Data Charges                     0.027686
# Total Long Distance Charges                  0.055653
# Total Revenue                                0.057424
# Satisfaction Score                           0.091578
# New Customer                                 0.063819
# Churn Score                                  0.054142
# CLTV                                         0.069312
# Population                                   0.040182
# Engagement Score                             0.082434
# Gender_Male                                  0.250044
# Offer_Offer A                                0.064737
# Offer_Offer B                                0.101379
# Offer_Offer C                                0.055769
# Offer_Offer D                                0.078087
# Offer_Offer E                                0.103153
# Internet Type_Cable                          0.102336
# Internet Type_DSL                            0.179974
# Internet Type_Fiber Optic                    0.245363
# Payment Method_Bank Withdrawal               0.247162
# Payment Method_Credit Card                   0.238305
# Churn Category_Attitude                      0.042081
# Churn Category_Competitor                    0.106131
# Churn Category_Dissatisfaction               0.041433
# Churn Category_Price                         0.028596
# Density_High                                 0.222889
# Density_Low                                  0.222419
# Contract_Month-to-Month                      0.249745
# Contract_One Year                            0.171262
# Contract_Two Year                            0.194033

# %% [markdown]
# **Spearmann Correlation**
#
# - Since our target is binary, we should not consider the correlation of the independent variables with the target variable to understand if they are "important".
# - In addition, the other binary variables should be excluded:

# %%
def compute_correlation(X, y, skf):
    result = pd.DataFrame(columns=['Combination'] + [f'Split {i+1}' for i in range(skf.n_splits)])

    for i, (train_index, val_index) in enumerate(skf.split(X, y), start=1):
        X_train = X.iloc[train_index].copy()

        # Select numerical features excluding binary variables
        X_train_num = X_train.select_dtypes(include=[np.number])
        binary_vars = ['Under 30', 'Senior Citizen', 'Married', 'Dependents',
                       'Phone Service', 'Referred a Friend', 'Multiple Lines',
                       'Online Security', 'Online Backup', 'Device Protection Plan',
                       'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
                       'Unlimited Data', 'Paperless Billing', 'New Customer',
                       'Gender_Male', 'Offer_Offer A', 'Offer_Offer B',
                       'Offer_Offer C', 'Offer_Offer D', 'Offer_Offer E',
                       'Internet Type_Cable', 'Internet Type_DSL', 'Internet Type_Fiber Optic',
                       'Payment Method_Bank Withdrawal', 'Payment Method_Credit Card',
                       'Gender_Male',
                       'Churn Category_Attitude', 'Churn Category_Competitor',
                       'Churn Category_Dissatisfaction', 'Churn Category_Price',
                       'Density_High', 'Density_Low',
                       'Contract_Month-to-Month', 'Contract_One Year', 'Contract_Two Year']
        X_train_num = X_train_num.drop(binary_vars, axis=1)

        # Compute Spearman correlation for numerical features
        combinations = set()
        correlations = {}
        for col1 in X_train_num.columns:
            for col2 in X_train_num.columns:
                if col1 != col2 and (col2, col1) not in combinations:
                    correlation, _ = spearmanr(X_train_num[col1], X_train_num[col2])
                    if abs(correlation) > 0.7:
                        combinations.add((col1, col2))
                        combinations.add((col2, col1))
                        combination_name = f"{col1} Vs {col2}"
                        correlations[combination_name] = [round(correlation, 1)]

        result.loc[:, f'Split {i}'] = pd.Series(correlations)

    result['Combination'] = result.index
    result = result.reset_index(drop=True)

    return result

# Prepare StratifiedKFold instance
skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)

# Compute correlation and generate table
correlation_table = compute_correlation(X, y, skf)
correlation_table
# Out:
#                                      Combination Split 1 Split 2 Split 3
# 0            Tenure in Months Vs Tenure Category   [1.0]   [1.0]   [1.0]  \
# 1              Tenure in Months Vs Total Charges   [0.9]   [0.9]   [0.9]
# 2              Tenure in Months Vs Total Revenue   [0.9]   [0.9]   [0.9]
# 3               Tenure Category Vs Total Charges   [0.9]   [0.9]   [0.9]
# 4               Tenure Category Vs Total Revenue   [0.9]   [0.9]   [0.9]
# 5    Internet Service Vs Avg Monthly GB Download   [0.7]   [0.7]   [0.7]
# 6             Internet Service Vs Monthly Charge   [0.7]   [0.7]   [0.7]
# 7           Internet Service Vs Engagement Score   [0.7]   [0.7]   [0.7]
# 8             Monthly Charge Vs Engagement Score   [0.8]   [0.8]   [0.8]
# 9                 Total Charges Vs Total Revenue   [1.0]   [1.0]   [1.0]
# 10             Total Charges Vs Engagement Score   [0.7]   [0.7]   [0.7]
# 11  Total Long Distance Charges Vs Total Revenue   [0.8]   [0.8]   [0.8]
#
#    Split 4 Split 5
# 0    [1.0]   [1.0]
# 1    [0.9]   [0.9]
# 2    [0.9]   [0.9]
# 3    [0.9]   [0.9]
# 4    [0.9]   [0.9]
# 5    [0.7]   [0.7]
# 6    [0.7]   [0.7]
# 7    [0.7]   [0.7]
# 8    [0.8]   [0.8]
# 9    [1.0]   [1.0]
# 10   [0.7]   [0.7]
# 11   [0.8]   [0.8]

# %% [markdown]
# ***
# Now it is time to understand the ones that we should keep and the ones to be removed.
#
# Since we know that regressions are really sensible to correlated features, we should remove the correlated features before applying those techniques, namely Lasso Regression and Recursive Feature Elimination if the estimator used is a regression model. Therefore, we will begin by applying decision trees to identify which features among the correlated ones should be excluded.
#
# ### Decision Trees and Random Forest (Embedded Methods to use before applying regressions)
#
# Use these two methods to first identify the most important variables and exclude redundant or correlated ones. These methods capture non-linear relationships and handle interactions between variables.
#
#
# > * __Decision Trees__ - `For continous, ordinal and binary data` It is important to note that regression models are particularly sensible to correlated features. Therefore, we will begin by applying decision trees to identify which features among the correlated ones should be excluded.
# > * __Random Forest__ - __Can be used to get the feature importances__, Random Forest improve the variance of simple Decision Trees by incorporating randomness. The criteria to get importance will be __Entropy which is a measure of information that indicates the disorder of the features with the target__. Similar to the Gini Index, the optimum split is chosen by the feature with less entropy. <p>
#
# Both methods are not affected by the scale of the features since they make splits based on thresholds and do not rely on the magniture of the values. We tested and results were not different when data was scaled or not.

# %% [markdown]
# **Decision Trees**

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold

def plot_importance(variables, name, subplot_index, top_n=15):
    imp_features = variables.nlargest(top_n).sort_values()
    ax = plt.subplot(2, 3, subplot_index)  # Adjust the subplot settings accordingly
    imp_features.plot(kind="barh", color='green', ax=ax)  # Set color to green
    ax.set_title("Split " + str(subplot_index))  # Set subplot title to split number
    ax.tick_params(axis='x', labelsize=8)  # Decrease the size of the x-axis labels

def select_best_features_dt(X, y):
    count = 1
    fig = plt.figure(figsize=(15, 10))  # Create a figure to contain the subplots
    skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)
    ranking_scores = pd.DataFrame(index=X.columns)  # Create a DataFrame to store the ranking scores

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        # Select features
        X_train = X_train.drop(['City'], axis=1)
        dt = DecisionTreeClassifier(random_state=99).fit(X_train, y_train)
        feature_importances = pd.Series(dt.feature_importances_, index=X_train.columns)

        # Store the feature importances in the ranking_scores DataFrame
        ranking_scores[f'Split {count}'] = feature_importances

        plot_importance(feature_importances, 'DT', count)
        count += 1

        
    # Create the DT_results DataFrame
    DT_results = ranking_scores.copy()


    plt.suptitle("Feature Importance using DT Model", fontsize=12, fontweight='bold')  # Overall title above the subplots
    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout of the subplots and overall title
    plt.show()

    # Determine 'Keep' or 'Remove' based on the significant count
    DT_results['DT_Significant_Count'] = (DT_results >= 0.025).sum(axis=1)   # Threshold of 0.04 to count as significant
    DT_results['Embedded_DT'] = np.where(DT_results['DT_Significant_Count'] >= 3, 'Keep', 'Remove')
    return DT_results


select_best_features_dt(X, y)
# Out:
#                                     Split 1   Split 2   Split 3   Split 4
# Age                                0.002266  0.000271  0.000926  0.000961  \
# Under 30                           0.000000  0.000000  0.000000  0.000000
# Senior Citizen                     0.000000  0.002375  0.002695  0.000835
# Married                            0.000000  0.000000  0.000000  0.000000
# Dependents                         0.000000  0.000000  0.000000  0.000000
# Number of Dependents               0.000000  0.000000  0.000000  0.000455
# City                                    NaN       NaN       NaN       NaN
# Referred a Friend                  0.000000  0.000000  0.000000  0.000000
# Number of Referrals                0.000000  0.000000  0.000683  0.000000
# Tenure in Months                   0.006678  0.006792  0.007171  0.011744
# Tenure Category                    0.000000  0.000000  0.000000  0.000000
# Phone Service                      0.000000  0.000000  0.000000  0.000000
# Avg Monthly Long Distance Charges  0.000000  0.000000  0.000000  0.000283
# Multiple Lines                     0.001301  0.000000  0.000000  0.000000
# Internet Service                   0.000000  0.000000  0.000000  0.000000
# Avg Monthly GB Download            0.001968  0.000000  0.001366  0.001629
# Online Security                    0.000000  0.000000  0.000809  0.000000
# Online Backup                      0.000000  0.000000  0.000000  0.000000
# Device Protection Plan             0.000000  0.000000  0.000000  0.000000
# Premium Tech Support               0.000000  0.000000  0.000000  0.000455
# Streaming TV                       0.000455  0.000000  0.000000  0.001311
# Streaming Movies                   0.000455  0.000000  0.000860  0.000000
# Streaming Music                    0.000414  0.001207  0.000000  0.000000
# Unlimited Data                     0.000000  0.000000  0.000000  0.000000
# Paperless Billing                  0.000000  0.000455  0.000000  0.000000
# Monthly Charge                     0.000927  0.000365  0.000000  0.001561
# Total Charges                      0.002074  0.001878  0.001118  0.000000
# Total Refunds                      0.000000  0.000000  0.000000  0.000000
# Total Extra Data Charges           0.000000  0.000000  0.000290  0.000451
# Total Long Distance Charges        0.000000  0.002105  0.000607  0.000000
# Total Revenue                      0.000000  0.000835  0.000335  0.000390
# Satisfaction Score                 0.708655  0.716468  0.708645  0.707733
# New Customer                       0.004341  0.003991  0.005886  0.002531
# Churn Score                        0.152311  0.152675  0.148392  0.156754
# CLTV                               0.000000  0.002439  0.001948  0.000000
# Population                         0.000159  0.000386  0.001756  0.000906
# Engagement Score                   0.000550  0.001116  0.000000  0.000000
# Gender_Male                        0.000000  0.000000  0.000000  0.000000
# Offer_Offer A                      0.000000  0.000000  0.000000  0.000000
# Offer_Offer B                      0.000000  0.000000  0.000000  0.000000
# Offer_Offer C                      0.000455  0.000000  0.000000  0.000111
# Offer_Offer D                      0.000733  0.000720  0.000000  0.000000
# Offer_Offer E                      0.000000  0.000000  0.000000  0.000000
# Internet Type_Cable                0.000000  0.000000  0.000000  0.000000
# Internet Type_DSL                  0.000000  0.000000  0.000000  0.000000
# Internet Type_Fiber Optic          0.000230  0.000343  0.000000  0.001238
# Payment Method_Bank Withdrawal     0.000000  0.000000  0.000000  0.000000
# Payment Method_Credit Card         0.000000  0.000000  0.000000  0.000000
# Churn Category_Attitude            0.034838  0.030533  0.032111  0.033063
# Churn Category_Competitor          0.040106  0.036830  0.038310  0.035863
# Churn Category_Dissatisfaction     0.024783  0.019454  0.029118  0.022079
# Churn Category_Price               0.015209  0.018761  0.016974  0.019648
# Density_High                       0.000000  0.000000  0.000000  0.000000
# Density_Low                        0.000000  0.000000  0.000000  0.000000
# Contract_Month-to-Month            0.001093  0.000000  0.000000  0.000000
# Contract_One Year                  0.000000  0.000000  0.000000  0.000000
# Contract_Two Year                  0.000000  0.000000  0.000000  0.000000
#
#                                     Split 5  DT_Significant_Count Embedded_DT
# Age                                0.000000                     0      Remove
# Under 30                           0.000000                     0      Remove
# Senior Citizen                     0.000000                     0      Remove
# Married                            0.000000                     0      Remove
# Dependents                         0.000000                     0      Remove
# Number of Dependents               0.000000                     0      Remove
# City                                    NaN                     0      Remove
# Referred a Friend                  0.000000                     0      Remove
# Number of Referrals                0.000000                     0      Remove
# Tenure in Months                   0.006573                     0      Remove
# Tenure Category                    0.000000                     0      Remove
# Phone Service                      0.000000                     0      Remove
# Avg Monthly Long Distance Charges  0.001092                     0      Remove
# Multiple Lines                     0.000758                     0      Remove
# Internet Service                   0.000000                     0      Remove
# Avg Monthly GB Download            0.000364                     0      Remove
# Online Security                    0.000000                     0      Remove
# Online Backup                      0.000000                     0      Remove
# Device Protection Plan             0.000000                     0      Remove
# Premium Tech Support               0.000000                     0      Remove
# Streaming TV                       0.000000                     0      Remove
# Streaming Movies                   0.002117                     0      Remove
# Streaming Music                    0.000000                     0      Remove
# Unlimited Data                     0.000000                     0      Remove
# Paperless Billing                  0.000000                     0      Remove
# Monthly Charge                     0.000000                     0      Remove
# Total Charges                      0.000607                     0      Remove
# Total Refunds                      0.000000                     0      Remove
# Total Extra Data Charges           0.000516                     0      Remove
# Total Long Distance Charges        0.001513                     0      Remove
# Total Revenue                      0.000000                     0      Remove
# Satisfaction Score                 0.716695                     5        Keep
# New Customer                       0.003231                     0      Remove
# Churn Score                        0.156552                     5        Keep
# CLTV                               0.001075                     0      Remove
# Population                         0.000607                     0      Remove
# Engagement Score                   0.000444                     0      Remove
# Gender_Male                        0.000000                     0      Remove
# Offer_Offer A                      0.000000                     0      Remove
# Offer_Offer B                      0.000000                     0      Remove
# Offer_Offer C                      0.000000                     0      Remove
# Offer_Offer D                      0.000000                     0      Remove
# Offer_Offer E                      0.000000                     0      Remove
# Internet Type_Cable                0.000000                     0      Remove
# Internet Type_DSL                  0.000000                     0      Remove
# Internet Type_Fiber Optic          0.000139                     0      Remove
# Payment Method_Bank Withdrawal     0.000000                     0      Remove
# Payment Method_Credit Card         0.000000                     0      Remove
# Churn Category_Attitude            0.026177                     5        Keep
# Churn Category_Competitor          0.036881                     5        Keep
# Churn Category_Dissatisfaction     0.024771                     1      Remove
# Churn Category_Price               0.018797                     0      Remove
# Density_High                       0.000000                     0      Remove
# Density_Low                        0.001092                     0      Remove
# Contract_Month-to-Month            0.000000                     0      Remove
# Contract_One Year                  0.000000                     0      Remove
# Contract_Two Year                  0.000000                     0      Remove

# %% [markdown]
# **Random Forest**

# %%
def apply_rf(X_train, y_train, subplot_index):
    rf = RandomForestClassifier(criterion='entropy', random_state=99).fit(X_train, y_train)
    feature_importances = pd.Series(rf.feature_importances_, index=X_train.columns)
    return feature_importances

def plot_importance(variables, name, subplot_index, top_n=15):
    imp_features = variables.nlargest(top_n).sort_values()
    ax = plt.subplot(2, 3, subplot_index)  # Adjust the subplot settings accordingly
    imp_features.plot(kind="barh", color='green', ax=ax)  # Set color to green
    ax.set_title("Split " + str(subplot_index))  # Set subplot title to split number
    ax.tick_params(axis='x', labelsize=8)  # Decrease the size of the x-axis labels


def select_best_features_rf(X, y):
    count = 1
    fig = plt.figure(figsize=(15, 10))  # Create a figure to contain the subplots
    skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)
    ranking_scores = pd.DataFrame(index=X.columns)  # Create a DataFrame to store the ranking scores

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]


        # Select numerical features for random forest
        X_train_num = X_train.select_dtypes(include=[np.number])

        # Scale the numerical features
        scaler = MinMaxScaler().fit(X_train_num)
        X_train_scaled = scaler.transform(X_train_num)
        X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_num.columns)

        # Apply random forest to scaled numerical features
        feature_importances = apply_rf(X_train_scaled, y_train, count)

        # Store the feature importances in the ranking_scores DataFrame
        ranking_scores[f'Split {count}'] = feature_importances
        plot_importance(feature_importances, 'RF', count)
        count += 1

    # Create the RF_results DataFrame
    RF_results = ranking_scores.copy()

    plt.suptitle("Feature Importance using DT Model", fontsize=12, fontweight='bold')  # Overall title above the subplots
    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout of the subplots and overall title
    plt.show()

    # Determine 'Keep' or 'Remove' based on the significant count
    RF_results['RF_Significant_Count'] = (RF_results >= 0.04).sum(axis=1)   # Threshold of 0.04 to count as significant
    RF_results['Embedded_RF'] = np.where(RF_results['RF_Significant_Count'] >= 3, 'Keep', 'Remove')

    return RF_results

RF_results = select_best_features_rf(X, y)
RF_results
# Out:
#                                     Split 1   Split 2   Split 3   Split 4
# Age                                0.007902  0.007684  0.007862  0.007760  \
# Under 30                           0.000541  0.000406  0.000695  0.000626
# Senior Citizen                     0.001600  0.002272  0.002986  0.002400
# Married                            0.000954  0.001179  0.000912  0.001048
# Dependents                         0.006795  0.006209  0.006453  0.006190
# Number of Dependents               0.006289  0.005945  0.005525  0.005400
# City                                    NaN       NaN       NaN       NaN
# Referred a Friend                  0.001469  0.001528  0.001319  0.001273
# Number of Referrals                0.022594  0.024130  0.023566  0.023614
# Tenure in Months                   0.024756  0.026053  0.020182  0.022872
# Tenure Category                    0.011817  0.010261  0.013105  0.011155
# Phone Service                      0.000247  0.000238  0.000343  0.000220
# Avg Monthly Long Distance Charges  0.005390  0.005753  0.005413  0.005218
# Multiple Lines                     0.000932  0.000864  0.001198  0.000984
# Internet Service                   0.003419  0.003923  0.004572  0.003897
# Avg Monthly GB Download            0.009246  0.009257  0.009086  0.008957
# Online Security                    0.004568  0.004974  0.005919  0.004914
# Online Backup                      0.000954  0.000695  0.000646  0.001041
# Device Protection Plan             0.000659  0.000703  0.000782  0.000588
# Premium Tech Support               0.001801  0.001252  0.001336  0.001022
# Streaming TV                       0.001276  0.001562  0.001273  0.001287
# Streaming Movies                   0.000884  0.001125  0.001392  0.001072
# Streaming Music                    0.001474  0.000946  0.001093  0.001143
# Unlimited Data                     0.000688  0.001099  0.000869  0.000884
# Paperless Billing                  0.001482  0.001644  0.002301  0.001420
# Monthly Charge                     0.010777  0.012906  0.013970  0.012448
# Total Charges                      0.012463  0.011344  0.011292  0.012255
# Total Refunds                      0.000577  0.000913  0.000686  0.000886
# Total Extra Data Charges           0.001055  0.001317  0.000889  0.001284
# Total Long Distance Charges        0.008105  0.008546  0.007929  0.008574
# Total Revenue                      0.011895  0.011086  0.010945  0.011746
# Satisfaction Score                 0.287399  0.310907  0.294590  0.297479
# New Customer                       0.018064  0.018514  0.016056  0.015576
# Churn Score                        0.212996  0.195109  0.215249  0.208656
# CLTV                               0.005234  0.005849  0.006059  0.005703
# Population                         0.005080  0.004541  0.005656  0.004932
# Engagement Score                   0.003124  0.004145  0.003606  0.004033
# Gender_Male                        0.000777  0.000906  0.000934  0.000731
# Offer_Offer A                      0.000150  0.000131  0.000132  0.000167
# Offer_Offer B                      0.000531  0.000307  0.000635  0.000708
# Offer_Offer C                      0.000448  0.000444  0.000361  0.000460
# Offer_Offer D                      0.000482  0.000543  0.000433  0.000523
# Offer_Offer E                      0.001354  0.001485  0.001532  0.001320
# Internet Type_Cable                0.000350  0.000381  0.000357  0.000386
# Internet Type_DSL                  0.000881  0.001142  0.001021  0.000957
# Internet Type_Fiber Optic          0.008007  0.007751  0.006224  0.008527
# Payment Method_Bank Withdrawal     0.001461  0.001274  0.001695  0.001719
# Payment Method_Credit Card         0.002554  0.002529  0.003553  0.002459
# Churn Category_Attitude            0.045574  0.040636  0.042813  0.048168
# Churn Category_Competitor          0.125851  0.117974  0.111095  0.112483
# Churn Category_Dissatisfaction     0.040711  0.039014  0.037712  0.037010
# Churn Category_Price               0.019494  0.022485  0.024555  0.023516
# Density_High                       0.000869  0.000839  0.000938  0.000729
# Density_Low                        0.000570  0.000818  0.000496  0.000774
# Contract_Month-to-Month            0.037510  0.037172  0.040188  0.038327
# Contract_One Year                  0.003495  0.002737  0.003224  0.004099
# Contract_Two Year                  0.014424  0.016553  0.016349  0.018380
#
#                                     Split 5  RF_Significant_Count Embedded_RF
# Age                                0.008392                     0      Remove
# Under 30                           0.000667                     0      Remove
# Senior Citizen                     0.002984                     0      Remove
# Married                            0.001097                     0      Remove
# Dependents                         0.006151                     0      Remove
# Number of Dependents               0.006143                     0      Remove
# City                                    NaN                     0      Remove
# Referred a Friend                  0.001015                     0      Remove
# Number of Referrals                0.026933                     0      Remove
# Tenure in Months                   0.019975                     0      Remove
# Tenure Category                    0.014526                     0      Remove
# Phone Service                      0.000222                     0      Remove
# Avg Monthly Long Distance Charges  0.005645                     0      Remove
# Multiple Lines                     0.000905                     0      Remove
# Internet Service                   0.004425                     0      Remove
# Avg Monthly GB Download            0.009698                     0      Remove
# Online Security                    0.004065                     0      Remove
# Online Backup                      0.000930                     0      Remove
# Device Protection Plan             0.000729                     0      Remove
# Premium Tech Support               0.001491                     0      Remove
# Streaming TV                       0.001217                     0      Remove
# Streaming Movies                   0.001130                     0      Remove
# Streaming Music                    0.001327                     0      Remove
# Unlimited Data                     0.001022                     0      Remove
# Paperless Billing                  0.001888                     0      Remove
# Monthly Charge                     0.013989                     0      Remove
# Total Charges                      0.011220                     0      Remove
# Total Refunds                      0.000814                     0      Remove
# Total Extra Data Charges           0.001079                     0      Remove
# Total Long Distance Charges        0.007378                     0      Remove
# Total Revenue                      0.010417                     0      Remove
# Satisfaction Score                 0.287662                     5        Keep
# New Customer                       0.018079                     0      Remove
# Churn Score                        0.212250                     5        Keep
# CLTV                               0.005728                     0      Remove
# Population                         0.005659                     0      Remove
# Engagement Score                   0.003495                     0      Remove
# Gender_Male                        0.000817                     0      Remove
# Offer_Offer A                      0.000213                     0      Remove
# Offer_Offer B                      0.000410                     0      Remove
# Offer_Offer C                      0.000488                     0      Remove
# Offer_Offer D                      0.000439                     0      Remove
# Offer_Offer E                      0.002060                     0      Remove
# Internet Type_Cable                0.000411                     0      Remove
# Internet Type_DSL                  0.000720                     0      Remove
# Internet Type_Fiber Optic          0.009349                     0      Remove
# Payment Method_Bank Withdrawal     0.001087                     0      Remove
# Payment Method_Credit Card         0.001623                     0      Remove
# Churn Category_Attitude            0.041953                     5        Keep
# Churn Category_Competitor          0.120117                     5        Keep
# Churn Category_Dissatisfaction     0.037150                     1      Remove
# Churn Category_Price               0.023102                     0      Remove
# Density_High                       0.000960                     0      Remove
# Density_Low                        0.000779                     0      Remove
# Contract_Month-to-Month            0.038821                     1      Remove
# Contract_One Year                  0.003782                     0      Remove
# Contract_Two Year                  0.015374                     0      Remove

# %% [markdown]
# ***
# At this moment, we already removed correlated features and can apply techniques where regression is used.
#
# First, lets apply Wrapper Methods.
#
# ***
# ## Wrapper Methods
# Use a classifier to assess features or feature subsets<p>
#
# Wrapper methods are used to train a model using a subset of features. According to the conclusions drawn from the previous model, it decides whether to include or exclude certain features from the subgroup, it'll be applied wrapper methods like: <p>
#
# > * __Recursive Feature Elimination (RFE)__* - `for continious, ordinal and binary data`__The algorithm aims to find the best performing subset of features by using greedy optimization__ (making the locally optimal choice at each stage with the hope of finding the global optimum). Each iteration __creates a new model and keeps aside the best or worst performing features__. The next model is constructed using the remaining features __until all the features have been exhausted__. The features are then __ranked according to their elimination order__ <p>
# > * __Forward Selection (SFS)__ - Starts with __no feature in the model and iterate forward__. On each subsequent repetition, __add the feature that improves the model__ the most __until the addition of a new variable does not improve its performance__ <p>
# > * __Backward Selection (SBS)__ - Starts with __all the features during backward elimination and remove the least significant feature at every iteration__, which improves the model's performance. This process is __repeated until no more improvement is observed__  <p>
#
# For the regressions we used scalled data.

# %% [markdown]
# **Recursive Feature Elimination (RFE)**

# %% [markdown]
# <div style="background-color: grey; color: #cc000; padding: 10px;">
# * Here we are using RFECV instead of RFE as we want to automatically determine the optimal number of features to keep. It performs the feature selection recursively by considering different subsets of features and evaluates their performance using cross-validation. Eliminates the need to specify the number of features to keep manually,  as it automatically selects the optimal number based on the cross-validated performance.
# </div>

# %%
from sklearn.feature_selection import RFECV

def apply_rfecv(X_train, y_train):
    rfecv = RFECV(estimator=LogisticRegression(), min_features_to_select=5)
    rfecv.fit(X_train, y_train)
    selected_features = pd.Series(rfecv.support_, index=X_train.columns)
    return selected_features

# Prepare StratifiedKFold instance
skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)

# Apply RFECV on each fold
rfe_results = pd.DataFrame()
rfe_results['Features'] = X.columns
rfe_feat_count = {}  # Dictionary to store counts for RFECV

for train_index, val_index in skf.split(X, y):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Select numerical features
    X_train_num = X_train.select_dtypes(include=[np.number])


    # Apply RFECV on scaled data
    selected_features = apply_rfecv(X_train_num, y_train)

    for feature, selected in selected_features.items():
        if selected:
            if feature in rfe_feat_count:
                rfe_feat_count[feature] += 1
            else:
                rfe_feat_count[feature] = 1

# Add 'RFECV_Significant_Count' column to rfe_results
rfe_results['RFECV_Significant_Count'] = rfe_results['Features'].apply(lambda x: rfe_feat_count[x] if x in rfe_feat_count else 0)

# Add 'Wrapper_RFECV' column
rfe_results['Wrapper_RFECV'] = rfe_results.apply(lambda row: 'Keep' if row['RFECV_Significant_Count'] >= 3 else 'Remove', axis=1)
rfe_results.loc[rfe_results['Features'].apply(lambda x: X[x].dtypes not in [np.number, np.float64, np.int64]), 'Wrapper_RFECV'] = ''

# Print the results
rfe_results
# Out:
#                              Features  RFECV_Significant_Count Wrapper_RFECV
# 0                                 Age                        0        Remove
# 1                            Under 30                        1        Remove
# 2                      Senior Citizen                        4          Keep
# 3                             Married                        3          Keep
# 4                          Dependents                        5          Keep
# 5                Number of Dependents                        1        Remove
# 6                                City                        0
# 7                   Referred a Friend                        5          Keep
# 8                 Number of Referrals                        5          Keep
# 9                    Tenure in Months                        4          Keep
# 10                    Tenure Category                        5          Keep
# 11                      Phone Service                        1        Remove
# 12  Avg Monthly Long Distance Charges                        4          Keep
# 13                     Multiple Lines                        1        Remove
# 14                   Internet Service                        5          Keep
# 15            Avg Monthly GB Download                        3          Keep
# 16                    Online Security                        5          Keep
# 17                      Online Backup                        1        Remove
# 18             Device Protection Plan                        4          Keep
# 19               Premium Tech Support                        3          Keep
# 20                       Streaming TV                        4          Keep
# 21                   Streaming Movies                        3          Keep
# 22                    Streaming Music                        3          Keep
# 23                     Unlimited Data                        0        Remove
# 24                  Paperless Billing                        0        Remove
# 25                     Monthly Charge                        5          Keep
# 26                      Total Charges                        0        Remove
# 27                      Total Refunds                        4          Keep
# 28           Total Extra Data Charges                        2        Remove
# 29        Total Long Distance Charges                        4          Keep
# 30                      Total Revenue                        2        Remove
# 31                 Satisfaction Score                        5          Keep
# 32                       New Customer                        5          Keep
# 33                        Churn Score                        5          Keep
# 34                               CLTV                        3          Keep
# 35                         Population                        1        Remove
# 36                   Engagement Score                        1        Remove
# 37                        Gender_Male                        0        Remove
# 38                      Offer_Offer A                        4          Keep
# 39                      Offer_Offer B                        1        Remove
# 40                      Offer_Offer C                        3          Keep
# 41                      Offer_Offer D                        5          Keep
# 42                      Offer_Offer E                        4          Keep
# 43                Internet Type_Cable                        1        Remove
# 44                  Internet Type_DSL                        3          Keep
# 45          Internet Type_Fiber Optic                        3          Keep
# 46     Payment Method_Bank Withdrawal                        1        Remove
# 47         Payment Method_Credit Card                        5          Keep
# 48            Churn Category_Attitude                        5          Keep
# 49          Churn Category_Competitor                        5          Keep
# 50     Churn Category_Dissatisfaction                        5          Keep
# 51               Churn Category_Price                        5          Keep
# 52                       Density_High                        3          Keep
# 53                        Density_Low                        0        Remove
# 54            Contract_Month-to-Month                        5          Keep
# 55                  Contract_One Year                        0        Remove
# 56                  Contract_Two Year                        5          Keep

# %% [markdown]
# **Forward Selection (SFS)**

# %%
# 36 Min to run!
'''
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.ensemble import RandomForestClassifier

def apply_sfs(X, y, skf, n_features_to_select):
    
    Returns a dataframe with the count of selected features by SFS across the K-Fold splits
    
    Args:
        X (pandas.dataframe) - Variables
        y (pandas.dataframe) - Target
        skf (object) - StratifiedKFold instance
        n_features_to_select (int) - Number of features to select

    Returns: 
        pandas.dataframe
    
    df = pd.DataFrame()
    df['Features'] = X.columns
    sfs_feat_count = {}  # Dictionary to store counts for SFS

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]



        # Select numerical features
        X_train_num = X_train.select_dtypes(include=[np.number])


        # Apply SFS on scaled data
        sfs = SFS(RandomForestClassifier(), k_features=n_features_to_select)
        sfs.fit(X_train_num, y_train)
        selected_features_sfs = pd.Series(sfs.k_feature_names_, index=sfs.k_feature_idx_)

        # Accumulate the counts of selected features for SFS
        for feature in selected_features_sfs:
            if feature in sfs_feat_count:
                sfs_feat_count[feature] += 1
            else:
                sfs_feat_count[feature] = 1

    df['SFS_Significant_Count'] = df['Features'].apply(lambda x: sfs_feat_count.get(x, 0))

    # Add 'Wrapper_SFS' column
    df['Wrapper_SFS'] = df.apply(lambda row: 'Keep' if row['SFS_Significant_Count'] >= 2 else 'Remove', axis=1)
    df.loc[df['Features'].apply(lambda x: X[x].dtypes not in [np.number, np.float64, np.int64]), 'Wrapper_SFS'] = ''

    return df

# Prepare StratifiedKFold instance
skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)

sfs_results = apply_sfs(X, y, skf, n_features_to_select=10)
sfs_results'''
# Out:
# "\nfrom mlxtend.feature_selection import SequentialFeatureSelector as SFS\nfrom sklearn.ensemble import RandomForestClassifier\n\ndef apply_sfs(X, y, skf, n_features_to_select):\n    \n    Returns a dataframe with the count of selected features by SFS across the K-Fold splits\n    \n    Args:\n        X (pandas.dataframe) - Variables\n        y (pandas.dataframe) - Target\n        skf (object) - StratifiedKFold instance\n        n_features_to_select (int) - Number of features to select\n\n    Returns: \n        pandas.dataframe\n    \n    df = pd.DataFrame()\n    df['Features'] = X.columns\n    sfs_feat_count = {}  # Dictionary to store counts for SFS\n\n    for train_index, val_index in skf.split(X, y):\n        X_train, X_val = X.iloc[train_index], X.iloc[val_index]\n        y_train, y_val = y.iloc[train_index], y.iloc[val_index]\n\n\n\n        # Select numerical features\n        X_train_num = X_train.select_dtypes(include=[np.number])\n\n\n        # Apply SFS on scaled data\n        sfs = SFS(RandomForestClassifier(), k_features=n_features_to_select)\n        sfs.fit(X_train_num, y_train)\n        selected_features_sfs = pd.Series(sfs.k_feature_names_, index=sfs.k_feature_idx_)\n\n        # Accumulate the counts of selected features for SFS\n        for feature in selected_features_sfs:\n            if feature in sfs_feat_count:\n                sfs_feat_count[feature] += 1\n            else:\n                sfs_feat_count[feature] = 1\n\n    df['SFS_Significant_Count'] = df['Features'].apply(lambda x: sfs_feat_count.get(x, 0))\n\n    # Add 'Wrapper_SFS' column\n    df['Wrapper_SFS'] = df.apply(lambda row: 'Keep' if row['SFS_Significant_Count'] >= 2 else 'Remove', axis=1)\n    df.loc[df['Features'].apply(lambda x: X[x].dtypes not in [np.number, np.float64, np.int64]), 'Wrapper_SFS'] = ''\n\n    return df\n\n# Prepare StratifiedKFold instance\nskf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)\n\nsfs_results = apply_sfs(X, y, skf, n_features_to_select=10)\nsfs_results"

# %% [markdown]
# ***
# ## Embedded Methods
# Learn which features best contribute to the accuracy of the model while the model is being created<p>
#
# Embedded methods combine the best features of filtering and wrapping methods by implementing algorithms with built-in methods for selecting features, standard embedded methods are: <p>
#
# > * __Lasso regularization__ - `For continous and ordinal data` __Adds penalty on different parameter to reduce freedom, thus it is less likely to fit noise of training data__ / overfit hence improves generalisation. Lasso Regression apart from preventing overfitting also __reduces the coefficients of less important features to zero__. <p>
#
# Do not apply to binary variables. Scale the data before as this is a regression.

# %%
def apply_lasso(X_train, y_train, subplot_index, display_plot=True):
    lasso = LassoCV().fit(X_train, y_train)
    coef = pd.Series(lasso.coef_, index = X_train.columns)
    abs_coef = coef.abs()  # Compute absolute values of coefficients
    if display_plot:
        plot_importance(abs_coef,'Lasso', subplot_index)  # pass abs_coef instead of coef
    return abs_coef  # return abs_coef

# %%
def select_best_features_lasso(X, y, display_plot=True):
    count = 1
    fig = plt.figure(figsize=(15, 10))  # Create a figure to contain the subplots
    skf = StratifiedKFold(n_splits=5, random_state=99, shuffle=True)
    ranking_scores = pd.DataFrame(index=X.columns)  # Create a DataFrame to store the ranking scores

    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        # Select numerical features for Lasso
        X_train_num = X_train.select_dtypes(include=[np.number])


        # Apply Lasso to scaled numerical features
        feature_importances = apply_lasso(X_train_num, y_train, count, display_plot)

        # Store the feature importances in the ranking_scores DataFrame
        ranking_scores[f'Split {count}'] = feature_importances

        count += 1

    if display_plot:
        plt.suptitle("Feature Importance using Lasso Model", fontsize=12, fontweight='bold')  # Overall title above the subplots
        plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout of the subplots and overall title
        plt.show()

    # Create the lasso_results DataFrame
    lasso_results = ranking_scores.copy()

    # Determine 'Keep' or 'Remove' based on the significant count
    lasso_results['Lasso_Significant_Count'] = (lasso_results >= 0.1).sum(axis=1)
    lasso_results['Embedded_Lasso'] = np.where(lasso_results['Lasso_Significant_Count'] >= 3, 'Keep', 'Remove')

    return lasso_results
select_best_features_lasso(X, y, True)
# Out:
#                                     Split 1   Split 2   Split 3   Split 4
# Age                                0.001932  0.000616  0.000000  0.006376  \
# Under 30                           0.002556  0.000000  0.003706  0.001414
# Senior Citizen                     0.001455  0.005518  0.000000  0.005804
# Married                            0.000000  0.003094  0.000000  0.000000
# Dependents                         0.024798  0.025909  0.027321  0.022401
# Number of Dependents               0.000000  0.000000  0.000000  0.000000
# City                                    NaN       NaN       NaN       NaN
# Referred a Friend                  0.027065  0.031604  0.027974  0.029417
# Number of Referrals                0.056711  0.064856  0.062715  0.065575
# Tenure in Months                   0.054259  0.033364  0.037332  0.045151
# Tenure Category                    0.109915  0.088761  0.087415  0.098466
# Phone Service                      0.025395  0.000000  0.002102  0.016290
# Avg Monthly Long Distance Charges  0.012618  0.013873  0.024813  0.017031
# Multiple Lines                     0.002281  0.001343  0.007147  0.001097
# Internet Service                   0.000000  0.026304  0.017952  0.002990
# Avg Monthly GB Download            0.009926  0.013264  0.000000  0.014801
# Online Security                    0.057402  0.057094  0.064802  0.064890
# Online Backup                      0.011622  0.008994  0.009823  0.011148
# Device Protection Plan             0.013223  0.012096  0.008834  0.010862
# Premium Tech Support               0.012577  0.004958  0.005346  0.008535
# Streaming TV                       0.006959  0.015703  0.016163  0.008551
# Streaming Movies                   0.008707  0.002468  0.000000  0.008910
# Streaming Music                    0.000165  0.000000  0.001674  0.002681
# Unlimited Data                     0.000822  0.000069  0.000000  0.000000
# Paperless Billing                  0.000055  0.000176  0.001522  0.003049
# Monthly Charge                     0.110197  0.037710  0.046526  0.103960
# Total Charges                      0.019922  0.030825  0.041854  0.040007
# Total Refunds                      0.020926  0.023164  0.025320  0.024790
# Total Extra Data Charges           0.004490  0.000000  0.000000  0.000000
# Total Long Distance Charges        0.019784  0.013982  0.026634  0.015634
# Total Revenue                      0.000000  0.000000  0.000000  0.000000
# Satisfaction Score                 0.257990  0.282812  0.288493  0.292889
# New Customer                       0.081489  0.084001  0.090096  0.094934
# Churn Score                        0.206859  0.218549  0.215741  0.225386
# CLTV                               0.000165  0.000000  0.008895  0.000000
# Population                         0.010900  0.002666  0.000376  0.004360
# Engagement Score                   0.000000  0.000000  0.000000  0.000000
# Gender_Male                        0.000943  0.003365  0.001904  0.000295
# Offer_Offer A                      0.008540  0.008399  0.011215  0.015122
# Offer_Offer B                      0.005386  0.012718  0.011079  0.008137
# Offer_Offer C                      0.014804  0.020739  0.021417  0.017226
# Offer_Offer D                      0.026696  0.038177  0.032601  0.036192
# Offer_Offer E                      0.007238  0.000000  0.015419  0.016611
# Internet Type_Cable                0.000000  0.002760  0.000000  0.003618
# Internet Type_DSL                  0.001853  0.000127  0.000511  0.000150
# Internet Type_Fiber Optic          0.011250  0.002479  0.000000  0.007255
# Payment Method_Bank Withdrawal     0.001604  0.005330  0.000000  0.003406
# Payment Method_Credit Card         0.007132  0.009405  0.006617  0.013339
# Churn Category_Attitude            0.717371  0.697548  0.688387  0.676093
# Churn Category_Competitor          0.678088  0.655333  0.642943  0.630422
# Churn Category_Dissatisfaction     0.698061  0.668543  0.665109  0.651047
# Churn Category_Price               0.702448  0.685954  0.673862  0.672832
# Density_High                       0.004665  0.002715  0.008785  0.005213
# Density_Low                        0.001039  0.002387  0.002381  0.000977
# Contract_Month-to-Month            0.021599  0.023541  0.027662  0.031514
# Contract_One Year                  0.000000  0.000000  0.000000  0.000000
# Contract_Two Year                  0.010713  0.010727  0.009742  0.007674
#
#                                     Split 5  Lasso_Significant_Count
# Age                                0.000000                        0  \
# Under 30                           0.000000                        0
# Senior Citizen                     0.000715                        0
# Married                            0.000000                        0
# Dependents                         0.022046                        0
# Number of Dependents               0.000000                        0
# City                                    NaN                        0
# Referred a Friend                  0.024631                        0
# Number of Referrals                0.061019                        0
# Tenure in Months                   0.070456                        0
# Tenure Category                    0.115434                        2
# Phone Service                      0.007261                        0
# Avg Monthly Long Distance Charges  0.014120                        0
# Multiple Lines                     0.002365                        0
# Internet Service                   0.011404                        0
# Avg Monthly GB Download            0.011203                        0
# Online Security                    0.056257                        0
# Online Backup                      0.014441                        0
# Device Protection Plan             0.009089                        0
# Premium Tech Support               0.011933                        0
# Streaming TV                       0.009958                        0
# Streaming Movies                   0.000924                        0
# Streaming Music                    0.006083                        0
# Unlimited Data                     0.000144                        0
# Paperless Billing                  0.001890                        0
# Monthly Charge                     0.068412                        2
# Total Charges                      0.038789                        0
# Total Refunds                      0.020211                        0
# Total Extra Data Charges           0.000000                        0
# Total Long Distance Charges        0.014650                        0
# Total Revenue                      0.000000                        0
# Satisfaction Score                 0.275819                        5
# New Customer                       0.087844                        0
# Churn Score                        0.220867                        5
# CLTV                               0.011695                        0
# Population                         0.009224                        0
# Engagement Score                   0.000000                        0
# Gender_Male                        0.000277                        0
# Offer_Offer A                      0.009493                        0
# Offer_Offer B                      0.008296                        0
# Offer_Offer C                      0.012852                        0
# Offer_Offer D                      0.033911                        0
# Offer_Offer E                      0.017959                        0
# Internet Type_Cable                0.006678                        0
# Internet Type_DSL                  0.000779                        0
# Internet Type_Fiber Optic          0.000241                        0
# Payment Method_Bank Withdrawal     0.000000                        0
# Payment Method_Credit Card         0.007735                        0
# Churn Category_Attitude            0.690611                        5
# Churn Category_Competitor          0.651285                        5
# Churn Category_Dissatisfaction     0.674943                        5
# Churn Category_Price               0.684858                        5
# Density_High                       0.004141                        0
# Density_Low                        0.003288                        0
# Contract_Month-to-Month            0.022326                        0
# Contract_One Year                  0.000000                        0
# Contract_Two Year                  0.010630                        0
#
#                                   Embedded_Lasso
# Age                                       Remove
# Under 30                                  Remove
# Senior Citizen                            Remove
# Married                                   Remove
# Dependents                                Remove
# Number of Dependents                      Remove
# City                                      Remove
# Referred a Friend                         Remove
# Number of Referrals                       Remove
# Tenure in Months                          Remove
# Tenure Category                           Remove
# Phone Service                             Remove
# Avg Monthly Long Distance Charges         Remove
# Multiple Lines                            Remove
# Internet Service                          Remove
# Avg Monthly GB Download                   Remove
# Online Security                           Remove
# Online Backup                             Remove
# Device Protection Plan                    Remove
# Premium Tech Support                      Remove
# Streaming TV                              Remove
# Streaming Movies                          Remove
# Streaming Music                           Remove
# Unlimited Data                            Remove
# Paperless Billing                         Remove
# Monthly Charge                            Remove
# Total Charges                             Remove
# Total Refunds                             Remove
# Total Extra Data Charges                  Remove
# Total Long Distance Charges               Remove
# Total Revenue                             Remove
# Satisfaction Score                          Keep
# New Customer                              Remove
# Churn Score                                 Keep
# CLTV                                      Remove
# Population                                Remove
# Engagement Score                          Remove
# Gender_Male                               Remove
# Offer_Offer A                             Remove
# Offer_Offer B                             Remove
# Offer_Offer C                             Remove
# Offer_Offer D                             Remove
# Offer_Offer E                             Remove
# Internet Type_Cable                       Remove
# Internet Type_DSL                         Remove
# Internet Type_Fiber Optic                 Remove
# Payment Method_Bank Withdrawal            Remove
# Payment Method_Credit Card                Remove
# Churn Category_Attitude                     Keep
# Churn Category_Competitor                   Keep
# Churn Category_Dissatisfaction              Keep
# Churn Category_Price                        Keep
# Density_High                              Remove
# Density_Low                               Remove
# Contract_Month-to-Month                   Remove
# Contract_One Year                         Remove
# Contract_Two Year                         Remove

# %% [markdown]
# [BACK TO TOC](#toc)
#
# <div class="alert alert-block alert-success">
# <a id='decision'>
# <font color = '#006400'>
#
# # 5. Feature Decision </font>
# </a>
#
# </div>
#
# Merging all data and create 5 different scenarios

# %%
X_train.columns
# Out:
# Index(['Age', 'Under 30', 'Senior Citizen', 'Married', 'Dependents',
#        'Number of Dependents', 'City', 'Referred a Friend',
#        'Number of Referrals', 'Tenure in Months', 'Tenure Category',
#        'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Avg Monthly GB Download', 'Online Security',
#        'Online Backup', 'Device Protection Plan', 'Premium Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data',
#        'Paperless Billing', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Satisfaction Score', 'New Customer', 'Churn Score',
#        'CLTV', 'Population', 'Engagement Score', 'Gender_Male',
#        'Offer_Offer A', 'Offer_Offer B', 'Offer_Offer C', 'Offer_Offer D',
#        'Offer_Offer E', 'Internet Type_Cable', 'Internet Type_DSL',
#        'Internet Type_Fiber Optic', 'Payment Method_Bank Withdrawal',
#        'Payment Method_Credit Card', 'Churn Category_Attitude',
#        'Churn Category_Competitor', 'Churn Category_Dissatisfaction',
#        'Churn Category_Price', 'Density_High', 'Density_Low',
#        'Contract_Month-to-Month', 'Contract_One Year', 'Contract_Two Year'],
#       dtype='object')

# %%
def filter_fs_df(X, y, skf):
    '''
    Returns a dataframe with the Kendall's Correlation, ANOVA and Chi-Square applied to the input data
    
    Args:
        X (pandas.dataframe) - Variables
        y (pandas.dataframe) - Target
        skf (object) - StratifiedKFold instance

    Returns: 
        pandas.dataframe
    '''
    df = pd.DataFrame()
    df['Features'] = X.columns

    kendall_feat_count = {}  # Dictionary to store counts for Kendall's Correlation
    anova_feat_count = {}  # Dictionary to store counts for ANOVA
    chi_feat_count = {}  # Dictionary to store counts for Chi-Square
    
    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]


        # Select numerical and categorical features
        X_train_num = X_train.select_dtypes(include=[np.number])
        X_train_cat = X_train[['City']]

        # Apply Kendall's correlation for numerical features
        for col in X_train_num:
            if abs(stats.kendalltau(X_train_num[col], y_train)[0]) > .5:
                if col in kendall_feat_count:
                    kendall_feat_count[col] += 1
                else:
                    kendall_feat_count[col] = 1
        
        # Apply ANOVA for numerical features
        for col in X_train_num:
            fvalue, pvalue = f_classif(X_train_num[[col]], y_train)
            if pvalue[0] < 0.05:
                if col in anova_feat_count:
                    anova_feat_count[col] += 1
                else:
                    anova_feat_count[col] = 1

        # Apply Chi-Square for categorical features
        for col in X_train_cat:
            chi_check = pd.crosstab(y_train, X_train_cat[col]) 
            chi2, p, dof, expected = chi2_contingency(chi_check.values)
            if p < .05:
                if col in chi_feat_count:
                    chi_feat_count[col] += 1
                else:
                    chi_feat_count[col] = 1

    df['Kendall_Significant_Count'] = df['Features'].apply(lambda x: kendall_feat_count[x] if x in kendall_feat_count else 0)
    df['Filter_Kendall'] = df['Kendall_Significant_Count'].apply(lambda x: 'Keep' if x > 3 else 'Remove')
    df.loc[df['Features'].apply(lambda x: X[x].dtypes not in [np.number, np.float64, np.int64]), 'Filter_Kendall'] = '-'
    
    df['ANOVA_Significant_Count'] = df['Features'].apply(lambda x: anova_feat_count[x] if x in anova_feat_count else 0)
    df['Filter_ANOVA'] = df['ANOVA_Significant_Count'].apply(lambda x: 'Keep' if x > 3 else 'Remove')
    df.loc[df['Features'].apply(lambda x: X[x].dtypes not in [np.number, np.float64, np.int64]), 'Filter_ANOVA'] = '-'
    
    df['CHI2_Significant_Count'] = df['Features'].apply(lambda x: chi_feat_count[x] if x in chi_feat_count else 0)
    df['Filter_CHI2'] = df['CHI2_Significant_Count'].apply(lambda x: 'Keep' if x > 3 else 'Remove')
    df.loc[df['Features'].apply(lambda x: X[x].dtypes in [np.number, np.float64, np.int64]), 'Filter_CHI2'] = '-'
    
    return df

# Prepare StratifiedKFold instance
skf = StratifiedKFold(n_splits = 5, random_state = 99, shuffle = True)

filtered = filter_fs_df(X, y, skf)
filtered.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_aff57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aff57_level0_col0" class="col_heading level0 col0" >Features</th>
#       <th id="T_aff57_level0_col1" class="col_heading level0 col1" >Kendall_Significant_Count</th>
#       <th id="T_aff57_level0_col2" class="col_heading level0 col2" >Filter_Kendall</th>
#       <th id="T_aff57_level0_col3" class="col_heading level0 col3" >ANOVA_Significant_Count</th>
#       <th id="T_aff57_level0_col4" class="col_heading level0 col4" >Filter_ANOVA</th>
#       <th id="T_aff57_level0_col5" class="col_heading level0 col5" >CHI2_Significant_Count</th>
#       <th id="T_aff57_level0_col6" class="col_heading level0 col6" >Filter_CHI2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aff57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aff57_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_aff57_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_aff57_row0_col2" class="data row0 col2" >Remove</td>
#       <td id="T_aff57_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_aff57_row0_col4" class="data row0 col4" >Keep</td>
#       <td id="T_aff57_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_aff57_row0_col6" class="data row0 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aff57_row1_col0" class="data row1 col0" >Under 30</td>
#       <td id="T_aff57_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_aff57_row1_col2" class="data row1 col2" >Remove</td>
#       <td id="T_aff57_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_aff57_row1_col4" class="data row1 col4" >Keep</td>
#       <td id="T_aff57_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_aff57_row1_col6" class="data row1 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aff57_row2_col0" class="data row2 col0" >Senior Citizen</td>
#       <td id="T_aff57_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_aff57_row2_col2" class="data row2 col2" >Remove</td>
#       <td id="T_aff57_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_aff57_row2_col4" class="data row2 col4" >Keep</td>
#       <td id="T_aff57_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_aff57_row2_col6" class="data row2 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aff57_row3_col0" class="data row3 col0" >Married</td>
#       <td id="T_aff57_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_aff57_row3_col2" class="data row3 col2" >Remove</td>
#       <td id="T_aff57_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_aff57_row3_col4" class="data row3 col4" >Keep</td>
#       <td id="T_aff57_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_aff57_row3_col6" class="data row3 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aff57_row4_col0" class="data row4 col0" >Dependents</td>
#       <td id="T_aff57_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_aff57_row4_col2" class="data row4 col2" >Remove</td>
#       <td id="T_aff57_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_aff57_row4_col4" class="data row4 col4" >Keep</td>
#       <td id="T_aff57_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_aff57_row4_col6" class="data row4 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aff57_row5_col0" class="data row5 col0" >Number of Dependents</td>
#       <td id="T_aff57_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_aff57_row5_col2" class="data row5 col2" >Remove</td>
#       <td id="T_aff57_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_aff57_row5_col4" class="data row5 col4" >Keep</td>
#       <td id="T_aff57_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_aff57_row5_col6" class="data row5 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aff57_row6_col0" class="data row6 col0" >City</td>
#       <td id="T_aff57_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_aff57_row6_col2" class="data row6 col2" >-</td>
#       <td id="T_aff57_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_aff57_row6_col4" class="data row6 col4" >-</td>
#       <td id="T_aff57_row6_col5" class="data row6 col5" >5</td>
#       <td id="T_aff57_row6_col6" class="data row6 col6" >Keep</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aff57_row7_col0" class="data row7 col0" >Referred a Friend</td>
#       <td id="T_aff57_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_aff57_row7_col2" class="data row7 col2" >Remove</td>
#       <td id="T_aff57_row7_col3" class="data row7 col3" >5</td>
#       <td id="T_aff57_row7_col4" class="data row7 col4" >Keep</td>
#       <td id="T_aff57_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_aff57_row7_col6" class="data row7 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aff57_row8_col0" class="data row8 col0" >Number of Referrals</td>
#       <td id="T_aff57_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_aff57_row8_col2" class="data row8 col2" >Remove</td>
#       <td id="T_aff57_row8_col3" class="data row8 col3" >5</td>
#       <td id="T_aff57_row8_col4" class="data row8 col4" >Keep</td>
#       <td id="T_aff57_row8_col5" class="data row8 col5" >0</td>
#       <td id="T_aff57_row8_col6" class="data row8 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aff57_row9_col0" class="data row9 col0" >Tenure in Months</td>
#       <td id="T_aff57_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_aff57_row9_col2" class="data row9 col2" >Remove</td>
#       <td id="T_aff57_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_aff57_row9_col4" class="data row9 col4" >Keep</td>
#       <td id="T_aff57_row9_col5" class="data row9 col5" >0</td>
#       <td id="T_aff57_row9_col6" class="data row9 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_aff57_row10_col0" class="data row10 col0" >Tenure Category</td>
#       <td id="T_aff57_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_aff57_row10_col2" class="data row10 col2" >Remove</td>
#       <td id="T_aff57_row10_col3" class="data row10 col3" >5</td>
#       <td id="T_aff57_row10_col4" class="data row10 col4" >Keep</td>
#       <td id="T_aff57_row10_col5" class="data row10 col5" >0</td>
#       <td id="T_aff57_row10_col6" class="data row10 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_aff57_row11_col0" class="data row11 col0" >Phone Service</td>
#       <td id="T_aff57_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_aff57_row11_col2" class="data row11 col2" >Remove</td>
#       <td id="T_aff57_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_aff57_row11_col4" class="data row11 col4" >Remove</td>
#       <td id="T_aff57_row11_col5" class="data row11 col5" >0</td>
#       <td id="T_aff57_row11_col6" class="data row11 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_aff57_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aff57_row12_col0" class="data row12 col0" >Avg Monthly Long Distance Charges</td>
#       <td id="T_aff57_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_aff57_row12_col2" class="data row12 col2" >Remove</td>
#       <td id="T_aff57_row12_col3" class="data row12 col3" >0</td>
#       <td id="T_aff57_row12_col4" class="data row12 col4" >Remove<

# %%
# Merge the results
merged_results = filtered.merge(rfe_results, on='Features', how='outer')
#merged_results = merged_results.merge(sfs_results, on='Features', how='outer')

# Store Lasso results in lasso_results variable
lasso_results = select_best_features_lasso(X, y, False).reset_index()

# Merge Lasso results
merged_results = merged_results.merge(lasso_results[['index', 'Embedded_Lasso']], left_on='Features', right_on='index', how='outer').drop(columns=['index'])

# Store RF results in RF_results variable
RF_results = select_best_features_rf(X, y).reset_index()
# Store RF results in RF_results variable
DT_results = select_best_features_dt(X, y).reset_index()

# Merge RF results
merged_results = merged_results.merge(RF_results[['index', 'Embedded_RF']], left_on='Features', right_on='index', how='outer').drop(columns=['index'])

# Merge DT results
merged_results = merged_results.merge(DT_results[['index', 'Embedded_DT']], left_on='Features', right_on='index', how='outer').drop(columns=['index'])

# Remove the unnecessary columns
merged_results = merged_results.drop(columns=['Kendall_Significant_Count',
                                              'ANOVA_Significant_Count',
                                              'CHI2_Significant_Count',
                                              'RFECV_Significant_Count'])

# Rename the columns for clarity
merged_results = merged_results.rename(columns={
    'Filter_Kendall': 'Filter_Kendall',
    'Filter_ANOVA': 'Filter_ANOVA',
    'Filter_CHI2': 'Filter_CHI2',
    'Wrapper_SFS_x': 'Wrapper_SFS',
    'Wrapper_RFECV': 'Wrapper_RFECV',
    'Embedded_Lasso': 'Embedded_Lasso',
    'Embedded_RF': 'Embedded_RF'
})

# Set '-' for missing values
merged_results = merged_results.fillna('-')

# Modify values for rows where Features are 'Education' and 'Marital_Status'
merged_results.loc[merged_results['Features'].isin(['City']), 
                   merged_results.columns.difference(['Features', 'Filter_CHI2'])] = '-'

# Only keep the rows where Filter_CHI2 and Embedded_Lasso have valid values (not '-')
filtered_merged_results = merged_results.loc[(merged_results['Filter_CHI2'] != '-') | (merged_results['Embedded_Lasso'] != '-')]

# Display the filtered merged results dataframe
filtered_merged_results
# Out:
#                              Features Filter_Kendall Filter_ANOVA Filter_CHI2
# 0                                 Age         Remove         Keep           -  \
# 1                            Under 30         Remove         Keep           -
# 2                      Senior Citizen         Remove         Keep           -
# 3                             Married         Remove         Keep           -
# 4                          Dependents         Remove         Keep           -
# 5                Number of Dependents         Remove         Keep           -
# 6                                City              -            -        Keep
# 7                   Referred a Friend         Remove         Keep           -
# 8                 Number of Referrals         Remove         Keep           -
# 9                    Tenure in Months         Remove         Keep           -
# 10                    Tenure Category         Remove         Keep           -
# 11                      Phone Service         Remove       Remove           -
# 12  Avg Monthly Long Distance Charges         Remove       Remove           -
# 13                     Multiple Lines         Remove         Keep           -
# 14                   Internet Service         Remove         Keep           -
# 15            Avg Monthly GB Download         Remove         Keep           -
# 16                    Online Security         Remove         Keep           -
# 17                      Online Backup         Remove         Keep           -
# 18             Device Protection Plan         Remove         Keep           -
# 19               Premium Tech Support         Remove         Keep           -
# 20                       Streaming TV         Remove         Keep           -
# 21                   Streaming Movies         Remove         Keep           -
# 22                    Streaming Music         Remove         Keep           -
# 23                     Unlimited Data         Remove         Keep           -
# 24                  Paperless Billing         Remove         Keep           -
# 25                     Monthly Charge         Remove         Keep           -
# 26                      Total Charges         Remove         Keep           -
# 27                      Total Refunds         Remove         Keep           -
# 28           Total Extra Data Charges         Remove       Remove           -
# 29        Total Long Distance Charges         Remove         Keep           -
# 30                      Total Revenue         Remove         Keep           -
# 31                 Satisfaction Score           Keep         Keep           -
# 32                       New Customer         Remove         Keep           -
# 33                        Churn Score           Keep         Keep           -
# 34                               CLTV         Remove         Keep           -
# 35                         Population         Remove         Keep           -
# 36                   Engagement Score         Remove       Remove           -
# 37                        Gender_Male         Remove       Remove           -
# 38                      Offer_Offer A         Remove         Keep           -
# 39                      Offer_Offer B         Remove         Keep           -
# 40                      Offer_Offer C         Remove       Remove           -
# 41                      Offer_Offer D         Remove       Remove           -
# 42                      Offer_Offer E         Remove         Keep           -
# 43                Internet Type_Cable         Remove       Remove           -
# 44                  Internet Type_DSL         Remove         Keep           -
# 45          Internet Type_Fiber Optic         Remove         Keep           -
# 46     Payment Method_Bank Withdrawal         Remove         Keep           -
# 47         Payment Method_Credit Card         Remove         Keep           -
# 48            Churn Category_Attitude         Remove         Keep           -
# 49          Churn Category_Competitor           Keep         Keep           -
# 50     Churn Category_Dissatisfaction         Remove         Keep           -
# 51               Churn Category_Price         Remove         Keep           -
# 52                       Density_High         Remove         Keep           -
# 53                        Density_Low         Remove       Remove           -
# 54            Contract_Month-to-Month         Remove         Keep           -
# 55                  Contract_One Year         Remove         Keep           -
# 56                  Contract_Two Year         Remove         Keep           -
#
#    Wrapper_RFECV Embedded_Lasso Embedded_RF Embedded_DT
# 0         Remove         Remove      Remove      Remove
# 1         Remove         Remove      Remove      Remove
# 2           Keep         Remove      Remove      Remove
# 3           Keep         Remove      Remove      Remove
# 4           Keep         Remove      Remove      Remove
# 5         Remove         Remove      Remove      Remove
# 6              -              -           -           -
# 7           Keep         Remove      Remove      Remove
# 8           Keep         Remove      Remove      Remove
# 9           Keep         Remove      Remove      Remove
# 10          Keep         Remove      Remove      Remove
# 11        Remove         Remove      Remove      Remove
# 12          Keep         Remove      Remove      Remove
# 13        Remove         Remove      Remove      Remove
# 14          Keep         Remove      Remove      Remove
# 15          Keep         Remove      Remove      Remove
# 16          Keep         Remove      Remove      Remove
# 17        Remove         Remove      Remove      Remove
# 18          Keep         Remove      Remove      Remove
# 19          Keep         Remove      Remove      Remove
# 20          Keep         Remove      Remove      Remove
# 21          Keep         Remove      Remove      Remove
# 22          Keep         Remove      Remove      Remove
# 23        Remove         Remove      Remove      Remove
# 24        Remove         Remove      Remove      Remove
# 25          Keep         Remove      Remove      Remove
# 26        Remove         Remove      Remove      Remove
# 27          Keep         Remove      Remove      Remove
# 28        Remove         Remove      Remove      Remove
# 29          Keep         Remove      Remove      Remove
# 30        Remove         Remove      Remove      Remove
# 31          Keep           Keep        Keep        Keep
# 32          Keep         Remove      Remove      Remove
# 33          Keep           Keep        Keep        Keep
# 34          Keep         Remove      Remove      Remove
# 35        Remove         Remove      Remove      Remove
# 36        Remove         Remove      Remove      Remove
# 37        Remove         Remove      Remove      Remove
# 38          Keep         Remove      Remove      Remove
# 39        Remove         Remove      Remove      Remove
# 40          Keep         Remove      Remove      Remove
# 41          Keep         Remove      Remove      Remove
# 42          Keep         Remove      Remove      Remove
# 43        Remove         Remove      Remove      Remove
# 44          Keep         Remove      Remove      Remove
# 45          Keep         Remove      Remove      Remove
# 46        Remove         Remove      Remove      Remove
# 47          Keep         Remove      Remove      Remove
# 48          Keep           Keep        Keep        Keep
# 49          Keep           Keep        Keep        Keep
# 50          Keep           Keep      Remove      Remove
# 51          Keep           Keep      Remove      Remove
# 52          Keep         Remove      Remove      Remove
# 53        Remove         Remove      Remove      Remove
# 54          Keep         Remove      Remove      Remove
# 55        Remove         Remove      Remove      Remove
# 56          Keep         Remove      Remove      Remove

# %% [markdown]
# <a class="anchor" id="10th-bullet">
#
# __`3.1.2.3. Decision Trees (Embedded Method) - For continuous, ordinal and binary data`__
#
# </a>

# %% [markdown]
# Similarly to what we have done in the previous techniques, we will now examine the feature importance of the independent variables in the training data  using a decision tree, regardless of the specific train subset being used.

# %% [markdown]
# __`Step 17`__ - Create a function named as `plot_importance` that receives the feature importances and the name of the model being applied and: <br>
# - Sort the feature importances using sort_values()
# - create a figure with figsize=(4,5)  <br>
# - plot an horizontal bar with the results <br>
# - Add the title ("Feature importance using " and the name of the model)

# %%
def plot_importance(variables,name):
    imp_features = variables.sort_values()
    plt.figure(figsize=(4,5))
    imp_features.plot(kind = "barh")
    plt.title("Feature importance using " + name + " Model")
    plt.show()

# %% [markdown]
# __`Step 18`__ - Create a function named `apply_dt` that takes your training data as input (independent variables and target). In this function:
# - Create a DecisionTreeClassifier with random_state = 99 and fit to your training data, Name it as `dt`
# - Call the attribute from the model decision trees `feature_importances_` and store those results in a Pandas DataFrame.
# - Call the previously defined function `plot_importance` to generate the horizontal bar with the feature importances provided by the decision tree.

# %%
def apply_dt(X_train, y_train):
    dt = DecisionTreeClassifier(random_state = 99).fit(X_train, y_train)
    feature_importances = pd.Series(dt.feature_importances_, index = X_train.columns)
    plot_importance(feature_importances, 'DT')

# %% [markdown]
# __`Step 19`__ - Create a function named as `select_best_features_dt` that receives the independent variables (X) and the target (y). <br>
# Inside of this function, follow these steps:<br>
# - Apply the previously defined StratifiedKFold as "skf" for cross-validation.
# - Fill missing data, focusing this time on the numerical variables.
# - Drop the `Marital_Status`variable, since we are using the feature importance of decision trees to evaluate the numerical data.
# - Call the `apply_dt` function on your data.

# %%
def select_best_features_dt(X, y):
    count = 1
    for train_index, val_index in skf.split(X,y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        ####################################### FILL MISSING DATA #################################################
        # Fill missing values in training data
        X_train['Income'].fillna(X_train['Income'].median(), inplace = True)
        
        ######################################### SELECT FEATURES #################################################        
        print('_________________________________________________________________________________________________\n')
        print('                                     SPLIT ' + str(count) + '                                    ')
        print('_________________________________________________________________________________________________')

        # check which features to use using decision Tree
        X_train = X_train.drop(['Marital_Status'], axis = 1)
        apply_dt(X_train, y_train)
        
        count+=1

# %% [markdown]
# __`Step 19B`__ - Call your function `select_best_features_dt` passing as arguments your independent variables and your target.

# %%
select_best_features_dt(X, y)

# %% [markdown]
# We had identified previously with correlation matrix that two groups of variables that seem to be highly correlated among them, namely:
# - Year_Birth, Income, Frq, Mnt
# - NetPurchase, CatPurchase, Year_Birth
#
# From the first group, we are going to include only Mnt, the variable that according to decision trees feature importance appears three times as the most important one. We remove `Year_Birth`, `Income` and `Frq`.
#
# From the second group (and not considering Year_birth since this variable have a high correlation with Mnt), we are going to keep NetPurchase, that appears always more important than CatPurchase except in the last split. We remove `CatPurchase`.

# %% [markdown]
# __`Step 20`__ - Remove the variables that were excluded by the combination of the results of the decision tree and the correlation matrix, namely `Income`, `Frq`, `CatPurchase` and `Year_Birth`.

# %%
X = X.drop(['Income','Frq','CatPurchase','Year_Birth'], axis = 1)

# %% [markdown]
# At this moment, you already removed correlated features and can apply techniques where regression is used.
#  <br><br>
#  To apply Lasso Regression and RFE (using Logistic Regression as an estimator), we should scale our data previously. <br>
#  In the case of the Decision Trees, it is not needed - the results should be similar if data is scaled or not. <br><br>
#
# <a class="anchor" id="11th-bullet">
#
# __`3.1.2.4. Recursive Feature Elimination (RFE) (Wrapper Method) - For continuous, ordinal and binary data`__
#
# </a>
#
# __`Step 21`__ - Create a function named `apply_rfe` that takes your training data as input (independent variables and target). In this function:
# - Create an instance of RFE named as `rfe`, where `estimator = LogisticRegression()` and `n_features_to_select = 5`
# - Apply the method `fit_transform()` from `rfe` to your training data.
# - Call the attribute from the RFE named `support_` and store those results in a Pandas Series named `selected_features`.
# - Print `selected_features`

# %%
def apply_rfe(X_train, y_train):
    rfe = RFE(estimator = LogisticRegression(), n_features_to_select = 5)
    rfe.fit_transform(X = X_train, y = y_train)
    selected_features = pd.Series(rfe.support_, index = X_train.columns)
    print(selected_features)

# %% [markdown]
# <a class="anchor" id="12th-bullet">
#
# __`3.1.2.5. Lasso - For continuous and ordinal data`__
#
# </a>

# %% [markdown]
# __`Step 22`__ - Create a function named `apply_lasso` that takes your training data as input (independent variables and target). In this function:
# - Remove the variable `Dependents` from the training data, since Lasso regression is not appropriate for binary data.
# - Create an instance of LassoCV, and apply the method `fit()`to your training data.
# - Call the attribute from the Lasso named `coef_` and store those results in a Pandas Series named `coef`. This will return the coefficients associated with each variable.
# - Call the previously defined function `plot_importance` to generate the horizontal bar with the coefficients provided by the Lasso.

# %%
def apply_lasso(X_train, y_train):
    X_train = X_train.drop(['Dependents'], axis = 1)
    lasso = LassoCV().fit(X_train, y_train)
    coef = pd.Series(lasso.coef_, index = X_train.columns)
    plot_importance(coef,'Lasso')

# %% [markdown]
# Now it is time to apply the different techniques to our data to each partition, and get insights from it. We can also apply again Decision Trees to obtain our final results.

# %% [markdown]
# __`Step 23`__ - Create a function named as `select_best_features` that receives the independent variables (X) and the target (y). <br>
# Inside of this function, follow these steps:<br>
# - Apply the previously defined StratifiedKFold as "skf" for cross-validation.
# - Drop the `Marital_Status`variable, since we are evaluating the numerical data.
# - Apply MinMaxScaler to your training data.
# - Call the `apply_rfe` function on your data.
# - Call the `apply_lasso` function on your data.
# - Call the `apply_dt` function on your data.

# %%
def select_best_features(X,y):
    count = 1
    for train_index, val_index in skf.split(X,y):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        ####################################### FILL MISSING DATA #################################################
        # Income was already been removed from our variables
        
        ########################################### SCALE DATA #################################################### 
        numerical_data = X_train.drop(['Marital_Status'], axis = 1).copy()
        scaler = MinMaxScaler().fit(numerical_data)
        X_train_scaled = scaler.transform(numerical_data)
        X_train_scaled = pd.DataFrame(X_train_scaled, columns = numerical_data.columns)
    
        ######################################### SELECT FEATURES #################################################        
        print('_________________________________________________________________________________________________\n')
        print('                                     SPLIT ' + str(count) + '                                    ')
        print('_________________________________________________________________________________________________')
        
        # Check which features to use using RFE
        print('')
        print('----------------- RFE ----------------------')
        apply_rfe(X_train_scaled, y_train)
        
        # check which features to use using lasso
        print('')
        print('----------------- LASSO ----------------------')
        apply_lasso(X_train_scaled, y_train)
            
        # check which features to use using lasso
        print('')
        print('----------------- DT ----------------------')
        apply_dt(X_train_scaled, y_train)
            
        count+=1

# %% [markdown]
# __`Step 23B`__ - Call your function `select_best_features` passing as arguments your independent variables and your target.

# %%
select_best_features(X, y)

# %% [markdown]
# At the end, you can combine the results you obtained previously to understand which features are the most important ones. <br>
# In Decision Trees and in Lasso, we are going to select the the Top 5.
#
# <hr>
#
#
#
# ### Numerical Data
#
# `Which variables should we keep using this techniques?`
#
# | Predictor | RFE | Lasso | DT | What to do? (One possible way to "solve") |
# | --- | --- | --- | --- | --- |
# Dependents | 2 YES | X | 0 YES |REMOVE |
# Rcn | 0 YES | 5 YES | 5 YES | Try with and without |
# Mnt | 5 YES | 5 YES | 5 YES | KEEP |
# Clothes | 5 YES | 4 YES | 4 YES | KEEP |
# Kitchen | 0 YES | 1 YES | 1 YES | REMOVE |
# SmallAppliances | 0 YES | 2 YES | 4 YES | Try with and Without |
# HouseKeeping | 0 YES | 0 YES | 2 YES | REMOVE |
# Toys | 4 YES | 0 YES | 1 YES | Try with and without |
# NetPurchase | 4 YES | 5 YES | 3 YES | KEEP |
# Recomendation | 5 YES | 2 YES | 0 YES | Try with and Without |
# CostPerContact | | | | REMOVE - Constant Feature|
# RevenuePerPositiveAnswer | | | | REMOVE - Constant Feature|
# Income | | | | REMOVE (Highly correlated with Mnt) |
# Frq | |  | | REMOVE (Highly Correlated with Mnt) |
# CatPurchase | |  | | REMOVE (Highly Correlated with NetPurchase) |
#
# <hr>

# %% [markdown]
# At this stage, we can identify certain variables that appear to be more important to retain, specifically `Mnt`, `Clothes`, `NetPurchase` and `Marital_Status`.
#
# However, there are other variables for which we are less certain about their significance: `Rcn`, `SmallAppliances`, `Toys`, and `Recomendation`.
#
# __`Step 24`__ Let's create two datasets:
# - One dataset that includes the variables that we are certain are important (name it as `keep_data`):
#     - Variables: Mnt, Clothes, NetPurchase, Marital_Status, DepVar <br><br>
# - Another dataset that includes the variables that are both important and those we are unsure about at this point (name it as `all_data`):
#     - Variables: Mnt, Clothes, NetPurchase, Rcn, SmallAppliances, Toys, Recomendation, Marital_Status, DepVar

# %%
keep_data = data[['Mnt','Clothes','NetPurchase','Marital_Status','DepVar']].copy()
all_data = data[['Mnt','Clothes','NetPurchase','Rcn','SmallAppliances','Toys','Recomendation','Marital_Status','DepVar']].copy()
